# %% [markdown]
# # vanishing gradient

# %% [markdown]
# ## sigmoid - gauss

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from common import layers
from collections import OrderedDict
from common import functions
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_1_size)
    network['W2'] = wieght_init * np.random.randn(hidden_layer_1_size, hidden_layer_2_size)
    network['W3'] = wieght_init * np.random.randn(hidden_layer_2_size, output_layer_size)

    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_f = functions.sigmoid
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_d_f = functions.d_sigmoid
    last_d_f = functions.d_softmax_with_loss
    
    
    # 出力層でのデルタ
    delta3 = last_d_f(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.09
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.08
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.09
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.04
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.15
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.12
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.12
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.09
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.15
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.22
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.15
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.12
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.09
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.14
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.07
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.12
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.08
#                 : 170. 正答率(テスト) = 0.0958
# Generation: 180. 正答率(トレーニング) = 0.05
#                 : 180. 正答率(テスト) = 0.098
# Generation: 190. 正答率(トレーニング) = 0.12
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.13
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.15
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.07
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.12
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.12
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.09
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.16
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.09
#                 : 270. 正答率(テスト) = 0.101
# Generation: 280. 正答率(トレーニング) = 0.15
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.14
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.12
#                 : 300. 正答率(テスト) = 0.101
# Generation: 310. 正答率(トレーニング) = 0.04
#                 : 310. 正答率(テスト) = 0.101
# Generation: 320. 正答率(トレーニング) = 0.12
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.14
#                 : 330. 正答率(テスト) = 0.1009
# Generation: 340. 正答率(トレーニング) = 0.08
#                 : 340. 正答率(テスト) = 0.1009
# Generation: 350. 正答率(トレーニング) = 0.12
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.07
#                 : 360. 正答率(テスト) = 0.0958
# Generation: 370. 正答率(トレーニング) = 0.07
#                 : 370. 正答率(テスト) = 0.1028
# Generation: 380. 正答率(トレーニング) = 0.13
#                 : 380. 正答率(テスト) = 0.101
# Generation: 390. 正答率(トレーニング) = 0.08
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.04
#                 : 400. 正答率(テスト) = 0.0892
# Generation: 410. 正答率(トレーニング) = 0.11
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.14
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.07
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.15
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.08
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.13
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.05
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.15
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.16
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.17
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.13
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.08
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.14
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.13
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.1
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.06
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.1
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.06
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.09
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.14
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.09
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.11
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.11
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.09
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.12
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.14
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.15
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.09
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.12
#                 : 690. 正答率(テスト) = 0.0974
# Generation: 700. 正答率(トレーニング) = 0.1
#                 : 700. 正答率(テスト) = 0.0958
# Generation: 710. 正答率(トレーニング) = 0.12
#                 : 710. 正答率(テスト) = 0.1028
# Generation: 720. 正答率(トレーニング) = 0.12
#                 : 720. 正答率(テスト) = 0.1028
# Generation: 730. 正答率(トレーニング) = 0.12
#                 : 730. 正答率(テスト) = 0.1028
# Generation: 740. 正答率(トレーニング) = 0.08
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.1
#                 : 750. 正答率(テスト) = 0.1028
# Generation: 760. 正答率(トレーニング) = 0.13
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.12
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.1
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.15
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.13
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.08
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.13
#                 : 820. 正答率(テスト) = 0.1135
# Generation: 830. 正答率(トレーニング) = 0.08
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.08
#                 : 840. 正答率(テスト) = 0.101
# Generation: 850. 正答率(トレーニング) = 0.1
#                 : 850. 正答率(テスト) = 0.1028
# Generation: 860. 正答率(トレーニング) = 0.08
#                 : 860. 正答率(テスト) = 0.101
# Generation: 870. 正答率(トレーニング) = 0.13
#                 : 870. 正答率(テスト) = 0.1028
# Generation: 880. 正答率(トレーニング) = 0.13
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.11
#                 : 890. 正答率(テスト) = 0.1028
# Generation: 900. 正答率(トレーニング) = 0.1
#                 : 900. 正答率(テスト) = 0.1028
# Generation: 910. 正答率(トレーニング) = 0.1
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.04
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.1
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.12
#                 : 940. 正答率(テスト) = 0.1028
# Generation: 950. 正答率(トレーニング) = 0.13
#                 : 950. 正答率(テスト) = 0.1028
# Generation: 960. 正答率(トレーニング) = 0.18
#                 : 960. 正答率(テスト) = 0.1028
# Generation: 970. 正答率(トレーニング) = 0.09
#                 : 970. 正答率(テスト) = 0.1028
# Generation: 980. 正答率(トレーニング) = 0.08
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.11
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.08
#                 : 1000. 正答率(テスト) = 0.1135
# Generation: 1010. 正答率(トレーニング) = 0.06
#                 : 1010. 正答率(テスト) = 0.1028
# Generation: 1020. 正答率(トレーニング) = 0.08
#                 : 1020. 正答率(テスト) = 0.1028
# Generation: 1030. 正答率(トレーニング) = 0.07
#                 : 1030. 正答率(テスト) = 0.1135
# Generation: 1040. 正答率(トレーニング) = 0.16
#                 : 1040. 正答率(テスト) = 0.1135
# Generation: 1050. 正答率(トレーニング) = 0.13
#                 : 1050. 正答率(テスト) = 0.1135
# Generation: 1060. 正答率(トレーニング) = 0.09
#                 : 1060. 正答率(テスト) = 0.1135
# Generation: 1070. 正答率(トレーニング) = 0.09
#                 : 1070. 正答率(テスト) = 0.1135
# Generation: 1080. 正答率(トレーニング) = 0.09
#                 : 1080. 正答率(テスト) = 0.1135
# Generation: 1090. 正答率(トレーニング) = 0.09
#                 : 1090. 正答率(テスト) = 0.1135
# Generation: 1100. 正答率(トレーニング) = 0.06
#                 : 1100. 正答率(テスト) = 0.1135
# Generation: 1110. 正答率(トレーニング) = 0.1
#                 : 1110. 正答率(テスト) = 0.1135
# Generation: 1120. 正答率(トレーニング) = 0.12
#                 : 1120. 正答率(テスト) = 0.1135
# Generation: 1130. 正答率(トレーニング) = 0.08
#                 : 1130. 正答率(テスト) = 0.0958
# Generation: 1140. 正答率(トレーニング) = 0.13
#                 : 1140. 正答率(テスト) = 0.1032
# Generation: 1150. 正答率(トレーニング) = 0.06
#                 : 1150. 正答率(テスト) = 0.101
# Generation: 1160. 正答率(トレーニング) = 0.08
#                 : 1160. 正答率(テスト) = 0.1135
# Generation: 1170. 正答率(トレーニング) = 0.08
#                 : 1170. 正答率(テスト) = 0.1135
# Generation: 1180. 正答率(トレーニング) = 0.07
#                 : 1180. 正答率(テスト) = 0.1028
# Generation: 1190. 正答率(トレーニング) = 0.15
#                 : 1190. 正答率(テスト) = 0.1135
# Generation: 1200. 正答率(トレーニング) = 0.12
#                 : 1200. 正答率(テスト) = 0.1135
# Generation: 1210. 正答率(トレーニング) = 0.1
#                 : 1210. 正答率(テスト) = 0.1135
# Generation: 1220. 正答率(トレーニング) = 0.1
#                 : 1220. 正答率(テスト) = 0.1135
# Generation: 1230. 正答率(トレーニング) = 0.1
#                 : 1230. 正答率(テスト) = 0.1135
# Generation: 1240. 正答率(トレーニング) = 0.17
#                 : 1240. 正答率(テスト) = 0.1009
# Generation: 1250. 正答率(トレーニング) = 0.09
#                 : 1250. 正答率(テスト) = 0.1135
# Generation: 1260. 正答率(トレーニング) = 0.11
#                 : 1260. 正答率(テスト) = 0.1009
# Generation: 1270. 正答率(トレーニング) = 0.14
#                 : 1270. 正答率(テスト) = 0.1135
# Generation: 1280. 正答率(トレーニング) = 0.11
#                 : 1280. 正答率(テスト) = 0.1032
# Generation: 1290. 正答率(トレーニング) = 0.14
#                 : 1290. 正答率(テスト) = 0.1135
# Generation: 1300. 正答率(トレーニング) = 0.03
#                 : 1300. 正答率(テスト) = 0.1028
# Generation: 1310. 正答率(トレーニング) = 0.09
#                 : 1310. 正答率(テスト) = 0.1135
# Generation: 1320. 正答率(トレーニング) = 0.06
#                 : 1320. 正答率(テスト) = 0.0958
# Generation: 1330. 正答率(トレーニング) = 0.08
#                 : 1330. 正答率(テスト) = 0.0974
# Generation: 1340. 正答率(トレーニング) = 0.16
#                 : 1340. 正答率(テスト) = 0.1135
# Generation: 1350. 正答率(トレーニング) = 0.1
#                 : 1350. 正答率(テスト) = 0.1135
# Generation: 1360. 正答率(トレーニング) = 0.09
#                 : 1360. 正答率(テスト) = 0.1135
# Generation: 1370. 正答率(トレーニング) = 0.21
#                 : 1370. 正答率(テスト) = 0.1135
# Generation: 1380. 正答率(トレーニング) = 0.08
#                 : 1380. 正答率(テスト) = 0.1135
# Generation: 1390. 正答率(トレーニング) = 0.09
#                 : 1390. 正答率(テスト) = 0.1135
# Generation: 1400. 正答率(トレーニング) = 0.09
#                 : 1400. 正答率(テスト) = 0.1135
# Generation: 1410. 正答率(トレーニング) = 0.11
#                 : 1410. 正答率(テスト) = 0.1135
# Generation: 1420. 正答率(トレーニング) = 0.17
#                 : 1420. 正答率(テスト) = 0.1135
# Generation: 1430. 正答率(トレーニング) = 0.1
#                 : 1430. 正答率(テスト) = 0.1135
# Generation: 1440. 正答率(トレーニング) = 0.08
#                 : 1440. 正答率(テスト) = 0.1028
# Generation: 1450. 正答率(トレーニング) = 0.11
#                 : 1450. 正答率(テスト) = 0.1135
# Generation: 1460. 正答率(トレーニング) = 0.18
#                 : 1460. 正答率(テスト) = 0.1135
# Generation: 1470. 正答率(トレーニング) = 0.1
#                 : 1470. 正答率(テスト) = 0.1135
# Generation: 1480. 正答率(トレーニング) = 0.12
#                 : 1480. 正答率(テスト) = 0.1135
# Generation: 1490. 正答率(トレーニング) = 0.1
#                 : 1490. 正答率(テスト) = 0.1135
# Generation: 1500. 正答率(トレーニング) = 0.11
#                 : 1500. 正答率(テスト) = 0.1135
# Generation: 1510. 正答率(トレーニング) = 0.06
#                 : 1510. 正答率(テスト) = 0.1135
# Generation: 1520. 正答率(トレーニング) = 0.12
#                 : 1520. 正答率(テスト) = 0.1135
# Generation: 1530. 正答率(トレーニング) = 0.13
#                 : 1530. 正答率(テスト) = 0.1135
# Generation: 1540. 正答率(トレーニング) = 0.11
#                 : 1540. 正答率(テスト) = 0.1135
# Generation: 1550. 正答率(トレーニング) = 0.13
#                 : 1550. 正答率(テスト) = 0.1135
# Generation: 1560. 正答率(トレーニング) = 0.13
#                 : 1560. 正答率(テスト) = 0.1135
# Generation: 1570. 正答率(トレーニング) = 0.07
#                 : 1570. 正答率(テスト) = 0.1135
# Generation: 1580. 正答率(トレーニング) = 0.07
#                 : 1580. 正答率(テスト) = 0.1135
# Generation: 1590. 正答率(トレーニング) = 0.1
#                 : 1590. 正答率(テスト) = 0.1135
# Generation: 1600. 正答率(トレーニング) = 0.15
#                 : 1600. 正答率(テスト) = 0.1135
# Generation: 1610. 正答率(トレーニング) = 0.07
#                 : 1610. 正答率(テスト) = 0.1135
# Generation: 1620. 正答率(トレーニング) = 0.11
#                 : 1620. 正答率(テスト) = 0.1028
# Generation: 1630. 正答率(トレーニング) = 0.19
#                 : 1630. 正答率(テスト) = 0.1135
# Generation: 1640. 正答率(トレーニング) = 0.14
#                 : 1640. 正答率(テスト) = 0.1135
# Generation: 1650. 正答率(トレーニング) = 0.08
#                 : 1650. 正答率(テスト) = 0.1135
# Generation: 1660. 正答率(トレーニング) = 0.05
#                 : 1660. 正答率(テスト) = 0.1028
# Generation: 1670. 正答率(トレーニング) = 0.1
#                 : 1670. 正答率(テスト) = 0.101
# Generation: 1680. 正答率(トレーニング) = 0.12
#                 : 1680. 正答率(テスト) = 0.101
# Generation: 1690. 正答率(トレーニング) = 0.11
#                 : 1690. 正答率(テスト) = 0.101
# Generation: 1700. 正答率(トレーニング) = 0.12
#                 : 1700. 正答率(テスト) = 0.1135
# Generation: 1710. 正答率(トレーニング) = 0.1
#                 : 1710. 正答率(テスト) = 0.101
# Generation: 1720. 正答率(トレーニング) = 0.12
#                 : 1720. 正答率(テスト) = 0.1135
# Generation: 1730. 正答率(トレーニング) = 0.09
#                 : 1730. 正答率(テスト) = 0.1135
# Generation: 1740. 正答率(トレーニング) = 0.13
#                 : 1740. 正答率(テスト) = 0.1135
# Generation: 1750. 正答率(トレーニング) = 0.08
#                 : 1750. 正答率(テスト) = 0.101
# Generation: 1760. 正答率(トレーニング) = 0.1
#                 : 1760. 正答率(テスト) = 0.101
# Generation: 1770. 正答率(トレーニング) = 0.15
#                 : 1770. 正答率(テスト) = 0.1135
# Generation: 1780. 正答率(トレーニング) = 0.14
#                 : 1780. 正答率(テスト) = 0.1135
# Generation: 1790. 正答率(トレーニング) = 0.13
#                 : 1790. 正答率(テスト) = 0.1135
# Generation: 1800. 正答率(トレーニング) = 0.08
#                 : 1800. 正答率(テスト) = 0.1135
# Generation: 1810. 正答率(トレーニング) = 0.12
#                 : 1810. 正答率(テスト) = 0.1135
# Generation: 1820. 正答率(トレーニング) = 0.11
#                 : 1820. 正答率(テスト) = 0.1135
# Generation: 1830. 正答率(トレーニング) = 0.15
#                 : 1830. 正答率(テスト) = 0.1028
# Generation: 1840. 正答率(トレーニング) = 0.11
#                 : 1840. 正答率(テスト) = 0.1135
# Generation: 1850. 正答率(トレーニング) = 0.12
#                 : 1850. 正答率(テスト) = 0.1135
# Generation: 1860. 正答率(トレーニング) = 0.14
#                 : 1860. 正答率(テスト) = 0.1135
# Generation: 1870. 正答率(トレーニング) = 0.13
#                 : 1870. 正答率(テスト) = 0.1135
# Generation: 1880. 正答率(トレーニング) = 0.17
#                 : 1880. 正答率(テスト) = 0.1135
# Generation: 1890. 正答率(トレーニング) = 0.15
#                 : 1890. 正答率(テスト) = 0.1135
# Generation: 1900. 正答率(トレーニング) = 0.14
#                 : 1900. 正答率(テスト) = 0.1135
# Generation: 1910. 正答率(トレーニング) = 0.1
#                 : 1910. 正答率(テスト) = 0.1135
# Generation: 1920. 正答率(トレーニング) = 0.11
#                 : 1920. 正答率(テスト) = 0.1135
# Generation: 1930. 正答率(トレーニング) = 0.14
#                 : 1930. 正答率(テスト) = 0.1135
# Generation: 1940. 正答率(トレーニング) = 0.1
#                 : 1940. 正答率(テスト) = 0.1135
# Generation: 1950. 正答率(トレーニング) = 0.09
#                 : 1950. 正答率(テスト) = 0.1135
# Generation: 1960. 正答率(トレーニング) = 0.11
#                 : 1960. 正答率(テスト) = 0.1135
# Generation: 1970. 正答率(トレーニング) = 0.11
#                 : 1970. 正答率(テスト) = 0.1135
# Generation: 1980. 正答率(トレーニング) = 0.16
#                 : 1980. 正答率(テスト) = 0.1135
# Generation: 1990. 正答率(トレーニング) = 0.06
#                 : 1990. 正答率(テスト) = 0.1135
# Generation: 2000. 正答率(トレーニング) = 0.13
#                 : 2000. 正答率(テスト) = 0.1135

# %% [markdown]
# 正解率が上がらず学習が進んでいない
# →勾配消失している？

# %% [markdown]
# ## ReLU - gauss

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 

    network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_1_size)
    network['W2'] = wieght_init * np.random.randn(hidden_layer_1_size, hidden_layer_2_size)
    network['W3'] = wieght_init * np.random.randn(hidden_layer_2_size, output_layer_size)
            
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    ###########  変更箇所  ##############

    hidden_f = functions.relu

    #################################
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    ###########  変更箇所  ##############
    
    hidden_d_f = functions.d_relu
    
    #################################
    
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.13
#                 : 10. 正答率(テスト) = 0.1032
# Generation: 20. 正答率(トレーニング) = 0.12
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.12
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.11
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.12
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.13
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.13
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.09
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.1
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.1
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.12
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.05
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.09
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.1
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.1
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.07
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.08
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.15
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.1
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.16
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.16
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.13
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.14
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.18
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.12
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.12
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.07
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.13
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.09
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.16
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.12
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.12
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.1
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.1
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.14
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.08
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.1
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.09
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.09
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.1
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.13
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.06
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.18
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.07
#                 : 440. 正答率(テスト) = 0.1164
# Generation: 450. 正答率(トレーニング) = 0.11
#                 : 450. 正答率(テスト) = 0.1661
# Generation: 460. 正答率(トレーニング) = 0.21
#                 : 460. 正答率(テスト) = 0.2037
# Generation: 470. 正答率(トレーニング) = 0.23
#                 : 470. 正答率(テスト) = 0.2407
# Generation: 480. 正答率(トレーニング) = 0.25
#                 : 480. 正答率(テスト) = 0.2269
# Generation: 490. 正答率(トレーニング) = 0.27
#                 : 490. 正答率(テスト) = 0.2336
# Generation: 500. 正答率(トレーニング) = 0.19
#                 : 500. 正答率(テスト) = 0.2534
# Generation: 510. 正答率(トレーニング) = 0.32
#                 : 510. 正答率(テスト) = 0.2592
# Generation: 520. 正答率(トレーニング) = 0.27
#                 : 520. 正答率(テスト) = 0.2604
# Generation: 530. 正答率(トレーニング) = 0.31
#                 : 530. 正答率(テスト) = 0.2686
# Generation: 540. 正答率(トレーニング) = 0.32
#                 : 540. 正答率(テスト) = 0.2713
# Generation: 550. 正答率(トレーニング) = 0.32
#                 : 550. 正答率(テスト) = 0.3174
# Generation: 560. 正答率(トレーニング) = 0.36
#                 : 560. 正答率(テスト) = 0.3328
# Generation: 570. 正答率(トレーニング) = 0.3
#                 : 570. 正答率(テスト) = 0.3468
# Generation: 580. 正答率(トレーニング) = 0.43
#                 : 580. 正答率(テスト) = 0.4366
# Generation: 590. 正答率(トレーニング) = 0.46
#                 : 590. 正答率(テスト) = 0.4067
# Generation: 600. 正答率(トレーニング) = 0.45
#                 : 600. 正答率(テスト) = 0.452
# Generation: 610. 正答率(トレーニング) = 0.36
#                 : 610. 正答率(テスト) = 0.4546
# Generation: 620. 正答率(トレーニング) = 0.47
#                 : 620. 正答率(テスト) = 0.4655
# Generation: 630. 正答率(トレーニング) = 0.49
#                 : 630. 正答率(テスト) = 0.4856
# Generation: 640. 正答率(トレーニング) = 0.48
#                 : 640. 正答率(テスト) = 0.4922
# Generation: 650. 正答率(トレーニング) = 0.46
#                 : 650. 正答率(テスト) = 0.4865
# Generation: 660. 正答率(トレーニング) = 0.52
#                 : 660. 正答率(テスト) = 0.506
# Generation: 670. 正答率(トレーニング) = 0.41
#                 : 670. 正答率(テスト) = 0.4933
# Generation: 680. 正答率(トレーニング) = 0.52
#                 : 680. 正答率(テスト) = 0.5583
# Generation: 690. 正答率(トレーニング) = 0.63
#                 : 690. 正答率(テスト) = 0.5766
# Generation: 700. 正答率(トレーニング) = 0.53
#                 : 700. 正答率(テスト) = 0.5753
# Generation: 710. 正答率(トレーニング) = 0.53
#                 : 710. 正答率(テスト) = 0.581
# Generation: 720. 正答率(トレーニング) = 0.52
#                 : 720. 正答率(テスト) = 0.6287
# Generation: 730. 正答率(トレーニング) = 0.57
#                 : 730. 正答率(テスト) = 0.5977
# Generation: 740. 正答率(トレーニング) = 0.7
#                 : 740. 正答率(テスト) = 0.7074
# Generation: 750. 正答率(トレーニング) = 0.69
#                 : 750. 正答率(テスト) = 0.6845
# Generation: 760. 正答率(トレーニング) = 0.68
#                 : 760. 正答率(テスト) = 0.724
# Generation: 770. 正答率(トレーニング) = 0.68
#                 : 770. 正答率(テスト) = 0.726
# Generation: 780. 正答率(トレーニング) = 0.78
#                 : 780. 正答率(テスト) = 0.7333
# Generation: 790. 正答率(トレーニング) = 0.79
#                 : 790. 正答率(テスト) = 0.74
# Generation: 800. 正答率(トレーニング) = 0.78
#                 : 800. 正答率(テスト) = 0.7521
# Generation: 810. 正答率(トレーニング) = 0.75
#                 : 810. 正答率(テスト) = 0.7702
# Generation: 820. 正答率(トレーニング) = 0.82
#                 : 820. 正答率(テスト) = 0.7758
# Generation: 830. 正答率(トレーニング) = 0.82
#                 : 830. 正答率(テスト) = 0.7731
# Generation: 840. 正答率(トレーニング) = 0.81
#                 : 840. 正答率(テスト) = 0.763
# Generation: 850. 正答率(トレーニング) = 0.78
#                 : 850. 正答率(テスト) = 0.7697
# Generation: 860. 正答率(トレーニング) = 0.78
#                 : 860. 正答率(テスト) = 0.7856
# Generation: 870. 正答率(トレーニング) = 0.72
#                 : 870. 正答率(テスト) = 0.7951
# Generation: 880. 正答率(トレーニング) = 0.77
#                 : 880. 正答率(テスト) = 0.796
# Generation: 890. 正答率(トレーニング) = 0.74
#                 : 890. 正答率(テスト) = 0.8018
# Generation: 900. 正答率(トレーニング) = 0.77
#                 : 900. 正答率(テスト) = 0.7725
# Generation: 910. 正答率(トレーニング) = 0.81
#                 : 910. 正答率(テスト) = 0.8172
# Generation: 920. 正答率(トレーニング) = 0.73
#                 : 920. 正答率(テスト) = 0.7902
# Generation: 930. 正答率(トレーニング) = 0.83
#                 : 930. 正答率(テスト) = 0.7821
# Generation: 940. 正答率(トレーニング) = 0.79
#                 : 940. 正答率(テスト) = 0.7939
# Generation: 950. 正答率(トレーニング) = 0.85
#                 : 950. 正答率(テスト) = 0.8154
# Generation: 960. 正答率(トレーニング) = 0.8
#                 : 960. 正答率(テスト) = 0.826
# Generation: 970. 正答率(トレーニング) = 0.75
#                 : 970. 正答率(テスト) = 0.7637
# Generation: 980. 正答率(トレーニング) = 0.77
#                 : 980. 正答率(テスト) = 0.8149
# Generation: 990. 正答率(トレーニング) = 0.7
#                 : 990. 正答率(テスト) = 0.8102
# Generation: 1000. 正答率(トレーニング) = 0.81
#                 : 1000. 正答率(テスト) = 0.8198
# Generation: 1010. 正答率(トレーニング) = 0.83
#                 : 1010. 正答率(テスト) = 0.832
# Generation: 1020. 正答率(トレーニング) = 0.85
#                 : 1020. 正答率(テスト) = 0.7927
# Generation: 1030. 正答率(トレーニング) = 0.83
#                 : 1030. 正答率(テスト) = 0.813
# Generation: 1040. 正答率(トレーニング) = 0.86
#                 : 1040. 正答率(テスト) = 0.8252
# Generation: 1050. 正答率(トレーニング) = 0.86
#                 : 1050. 正答率(テスト) = 0.8081
# Generation: 1060. 正答率(トレーニング) = 0.79
#                 : 1060. 正答率(テスト) = 0.8274
# Generation: 1070. 正答率(トレーニング) = 0.8
#                 : 1070. 正答率(テスト) = 0.8371
# Generation: 1080. 正答率(トレーニング) = 0.81
#                 : 1080. 正答率(テスト) = 0.8246
# Generation: 1090. 正答率(トレーニング) = 0.81
#                 : 1090. 正答率(テスト) = 0.8251
# Generation: 1100. 正答率(トレーニング) = 0.86
#                 : 1100. 正答率(テスト) = 0.8469
# Generation: 1110. 正答率(トレーニング) = 0.87
#                 : 1110. 正答率(テスト) = 0.8481
# Generation: 1120. 正答率(トレーニング) = 0.86
#                 : 1120. 正答率(テスト) = 0.8507
# Generation: 1130. 正答率(トレーニング) = 0.82
#                 : 1130. 正答率(テスト) = 0.8262
# Generation: 1140. 正答率(トレーニング) = 0.81
#                 : 1140. 正答率(テスト) = 0.8478
# Generation: 1150. 正答率(トレーニング) = 0.77
#                 : 1150. 正答率(テスト) = 0.8335
# Generation: 1160. 正答率(トレーニング) = 0.89
#                 : 1160. 正答率(テスト) = 0.8451
# Generation: 1170. 正答率(トレーニング) = 0.92
#                 : 1170. 正答率(テスト) = 0.8541
# Generation: 1180. 正答率(トレーニング) = 0.86
#                 : 1180. 正答率(テスト) = 0.8479
# Generation: 1190. 正答率(トレーニング) = 0.86
#                 : 1190. 正答率(テスト) = 0.8385
# Generation: 1200. 正答率(トレーニング) = 0.81
#                 : 1200. 正答率(テスト) = 0.844
# Generation: 1210. 正答率(トレーニング) = 0.81
#                 : 1210. 正答率(テスト) = 0.8428
# Generation: 1220. 正答率(トレーニング) = 0.82
#                 : 1220. 正答率(テスト) = 0.8468
# Generation: 1230. 正答率(トレーニング) = 0.77
#                 : 1230. 正答率(テスト) = 0.8474
# Generation: 1240. 正答率(トレーニング) = 0.86
#                 : 1240. 正答率(テスト) = 0.8599
# Generation: 1250. 正答率(トレーニング) = 0.85
#                 : 1250. 正答率(テスト) = 0.8574
# Generation: 1260. 正答率(トレーニング) = 0.84
#                 : 1260. 正答率(テスト) = 0.8608
# Generation: 1270. 正答率(トレーニング) = 0.86
#                 : 1270. 正答率(テスト) = 0.858
# Generation: 1280. 正答率(トレーニング) = 0.88
#                 : 1280. 正答率(テスト) = 0.8668
# Generation: 1290. 正答率(トレーニング) = 0.89
#                 : 1290. 正答率(テスト) = 0.8518
# Generation: 1300. 正答率(トレーニング) = 0.88
#                 : 1300. 正答率(テスト) = 0.8458
# Generation: 1310. 正答率(トレーニング) = 0.85
#                 : 1310. 正答率(テスト) = 0.8662
# Generation: 1320. 正答率(トレーニング) = 0.83
#                 : 1320. 正答率(テスト) = 0.8688
# Generation: 1330. 正答率(トレーニング) = 0.84
#                 : 1330. 正答率(テスト) = 0.8566
# Generation: 1340. 正答率(トレーニング) = 0.87
#                 : 1340. 正答率(テスト) = 0.8756
# Generation: 1350. 正答率(トレーニング) = 0.88
#                 : 1350. 正答率(テスト) = 0.867
# Generation: 1360. 正答率(トレーニング) = 0.92
#                 : 1360. 正答率(テスト) = 0.8725
# Generation: 1370. 正答率(トレーニング) = 0.88
#                 : 1370. 正答率(テスト) = 0.8673
# Generation: 1380. 正答率(トレーニング) = 0.84
#                 : 1380. 正答率(テスト) = 0.8633
# Generation: 1390. 正答率(トレーニング) = 0.86
#                 : 1390. 正答率(テスト) = 0.872
# Generation: 1400. 正答率(トレーニング) = 0.9
#                 : 1400. 正答率(テスト) = 0.8748
# Generation: 1410. 正答率(トレーニング) = 0.86
#                 : 1410. 正答率(テスト) = 0.8749
# Generation: 1420. 正答率(トレーニング) = 0.91
#                 : 1420. 正答率(テスト) = 0.8739
# Generation: 1430. 正答率(トレーニング) = 0.89
#                 : 1430. 正答率(テスト) = 0.8759
# Generation: 1440. 正答率(トレーニング) = 0.81
#                 : 1440. 正答率(テスト) = 0.8746
# Generation: 1450. 正答率(トレーニング) = 0.88
#                 : 1450. 正答率(テスト) = 0.8773
# Generation: 1460. 正答率(トレーニング) = 0.88
#                 : 1460. 正答率(テスト) = 0.885
# Generation: 1470. 正答率(トレーニング) = 0.89
#                 : 1470. 正答率(テスト) = 0.8846
# Generation: 1480. 正答率(トレーニング) = 0.9
#                 : 1480. 正答率(テスト) = 0.88
# Generation: 1490. 正答率(トレーニング) = 0.83
#                 : 1490. 正答率(テスト) = 0.8762
# Generation: 1500. 正答率(トレーニング) = 0.86
#                 : 1500. 正答率(テスト) = 0.8763
# Generation: 1510. 正答率(トレーニング) = 0.85
#                 : 1510. 正答率(テスト) = 0.8904
# Generation: 1520. 正答率(トレーニング) = 0.88
#                 : 1520. 正答率(テスト) = 0.888
# Generation: 1530. 正答率(トレーニング) = 0.87
#                 : 1530. 正答率(テスト) = 0.875
# Generation: 1540. 正答率(トレーニング) = 0.92
#                 : 1540. 正答率(テスト) = 0.8794
# Generation: 1550. 正答率(トレーニング) = 0.88
#                 : 1550. 正答率(テスト) = 0.8885
# Generation: 1560. 正答率(トレーニング) = 0.86
#                 : 1560. 正答率(テスト) = 0.8906
# Generation: 1570. 正答率(トレーニング) = 0.85
#                 : 1570. 正答率(テスト) = 0.8756
# Generation: 1580. 正答率(トレーニング) = 0.85
#                 : 1580. 正答率(テスト) = 0.8896
# Generation: 1590. 正答率(トレーニング) = 0.91
#                 : 1590. 正答率(テスト) = 0.8933
# Generation: 1600. 正答率(トレーニング) = 0.88
#                 : 1600. 正答率(テスト) = 0.8838
# Generation: 1610. 正答率(トレーニング) = 0.89
#                 : 1610. 正答率(テスト) = 0.8937
# Generation: 1620. 正答率(トレーニング) = 0.91
#                 : 1620. 正答率(テスト) = 0.8982
# Generation: 1630. 正答率(トレーニング) = 0.92
#                 : 1630. 正答率(テスト) = 0.8955
# Generation: 1640. 正答率(トレーニング) = 0.93
#                 : 1640. 正答率(テスト) = 0.895
# Generation: 1650. 正答率(トレーニング) = 0.9
#                 : 1650. 正答率(テスト) = 0.8936
# Generation: 1660. 正答率(トレーニング) = 0.93
#                 : 1660. 正答率(テスト) = 0.9006
# Generation: 1670. 正答率(トレーニング) = 0.89
#                 : 1670. 正答率(テスト) = 0.8845
# Generation: 1680. 正答率(トレーニング) = 0.93
#                 : 1680. 正答率(テスト) = 0.8963
# Generation: 1690. 正答率(トレーニング) = 0.89
#                 : 1690. 正答率(テスト) = 0.8997
# Generation: 1700. 正答率(トレーニング) = 0.9
#                 : 1700. 正答率(テスト) = 0.8983
# Generation: 1710. 正答率(トレーニング) = 0.89
#                 : 1710. 正答率(テスト) = 0.9005
# Generation: 1720. 正答率(トレーニング) = 0.95
#                 : 1720. 正答率(テスト) = 0.9046
# Generation: 1730. 正答率(トレーニング) = 0.83
#                 : 1730. 正答率(テスト) = 0.9033
# Generation: 1740. 正答率(トレーニング) = 0.87
#                 : 1740. 正答率(テスト) = 0.899
# Generation: 1750. 正答率(トレーニング) = 0.88
#                 : 1750. 正答率(テスト) = 0.8978
# Generation: 1760. 正答率(トレーニング) = 0.91
#                 : 1760. 正答率(テスト) = 0.908
# Generation: 1770. 正答率(トレーニング) = 0.89
#                 : 1770. 正答率(テスト) = 0.9028
# Generation: 1780. 正答率(トレーニング) = 0.88
#                 : 1780. 正答率(テスト) = 0.8953
# Generation: 1790. 正答率(トレーニング) = 0.85
#                 : 1790. 正答率(テスト) = 0.9056
# Generation: 1800. 正答率(トレーニング) = 0.9
#                 : 1800. 正答率(テスト) = 0.9016
# Generation: 1810. 正答率(トレーニング) = 0.96
#                 : 1810. 正答率(テスト) = 0.9062
# Generation: 1820. 正答率(トレーニング) = 0.87
#                 : 1820. 正答率(テスト) = 0.9053
# Generation: 1830. 正答率(トレーニング) = 0.91
#                 : 1830. 正答率(テスト) = 0.9093
# Generation: 1840. 正答率(トレーニング) = 0.93
#                 : 1840. 正答率(テスト) = 0.9063
# Generation: 1850. 正答率(トレーニング) = 0.9
#                 : 1850. 正答率(テスト) = 0.9071
# Generation: 1860. 正答率(トレーニング) = 0.91
#                 : 1860. 正答率(テスト) = 0.9108
# Generation: 1870. 正答率(トレーニング) = 0.85
#                 : 1870. 正答率(テスト) = 0.9058
# Generation: 1880. 正答率(トレーニング) = 0.92
#                 : 1880. 正答率(テスト) = 0.9094
# Generation: 1890. 正答率(トレーニング) = 0.89
#                 : 1890. 正答率(テスト) = 0.913
# Generation: 1900. 正答率(トレーニング) = 0.92
#                 : 1900. 正答率(テスト) = 0.9162
# Generation: 1910. 正答率(トレーニング) = 0.94
#                 : 1910. 正答率(テスト) = 0.9159
# Generation: 1920. 正答率(トレーニング) = 0.95
#                 : 1920. 正答率(テスト) = 0.9141
# Generation: 1930. 正答率(トレーニング) = 0.93
#                 : 1930. 正答率(テスト) = 0.9169
# Generation: 1940. 正答率(トレーニング) = 0.87
#                 : 1940. 正答率(テスト) = 0.9072
# Generation: 1950. 正答率(トレーニング) = 0.88
#                 : 1950. 正答率(テスト) = 0.9144
# Generation: 1960. 正答率(トレーニング) = 0.88
#                 : 1960. 正答率(テスト) = 0.9104
# Generation: 1970. 正答率(トレーニング) = 0.9
#                 : 1970. 正答率(テスト) = 0.9142
# Generation: 1980. 正答率(トレーニング) = 0.93
#                 : 1980. 正答率(テスト) = 0.9178
# Generation: 1990. 正答率(トレーニング) = 0.95
#                 : 1990. 正答率(テスト) = 0.9192
# Generation: 2000. 正答率(トレーニング) = 0.92
#                 : 2000. 正答率(テスト) = 0.9186

# %% [markdown]
# 活性化関数をReLUにしたことで学習がすすむようになっている

# %% [markdown]
# ## sigmoid - Xavier

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20
#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    
    ###########  変更箇所  ##############
    
    # Xavierの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_1_size) / (np.sqrt(input_layer_size))
    network['W2'] = np.random.randn(hidden_layer_1_size, hidden_layer_2_size) / (np.sqrt(hidden_layer_1_size))
    network['W3'] = np.random.randn(hidden_layer_2_size, output_layer_size) / (np.sqrt(hidden_layer_2_size))
    
    #################################
    
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_f = functions.sigmoid
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_d_f = functions.d_sigmoid
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.1
#                 : 10. 正答率(テスト) = 0.1176
# Generation: 20. 正答率(トレーニング) = 0.11
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.15
#                 : 30. 正答率(テスト) = 0.1768
# Generation: 40. 正答率(トレーニング) = 0.17
#                 : 40. 正答率(テスト) = 0.1769
# Generation: 50. 正答率(トレーニング) = 0.07
#                 : 50. 正答率(テスト) = 0.1187
# Generation: 60. 正答率(トレーニング) = 0.15
#                 : 60. 正答率(テスト) = 0.1434
# Generation: 70. 正答率(トレーニング) = 0.23
#                 : 70. 正答率(テスト) = 0.1376
# Generation: 80. 正答率(トレーニング) = 0.2
#                 : 80. 正答率(テスト) = 0.1967
# Generation: 90. 正答率(トレーニング) = 0.17
#                 : 90. 正答率(テスト) = 0.1193
# Generation: 100. 正答率(トレーニング) = 0.31
#                 : 100. 正答率(テスト) = 0.2845
# Generation: 110. 正答率(トレーニング) = 0.17
#                 : 110. 正答率(テスト) = 0.211
# Generation: 120. 正答率(トレーニング) = 0.34
#                 : 120. 正答率(テスト) = 0.3019
# Generation: 130. 正答率(トレーニング) = 0.43
#                 : 130. 正答率(テスト) = 0.4311
# Generation: 140. 正答率(トレーニング) = 0.44
#                 : 140. 正答率(テスト) = 0.3869
# Generation: 150. 正答率(トレーニング) = 0.34
#                 : 150. 正答率(テスト) = 0.2929
# Generation: 160. 正答率(トレーニング) = 0.27
#                 : 160. 正答率(テスト) = 0.2821
# Generation: 170. 正答率(トレーニング) = 0.28
#                 : 170. 正答率(テスト) = 0.296
# Generation: 180. 正答率(トレーニング) = 0.36
#                 : 180. 正答率(テスト) = 0.3987
# Generation: 190. 正答率(トレーニング) = 0.3
#                 : 190. 正答率(テスト) = 0.294
# Generation: 200. 正答率(トレーニング) = 0.23
#                 : 200. 正答率(テスト) = 0.1916
# Generation: 210. 正答率(トレーニング) = 0.24
#                 : 210. 正答率(テスト) = 0.2869
# Generation: 220. 正答率(トレーニング) = 0.51
#                 : 220. 正答率(テスト) = 0.3985
# Generation: 230. 正答率(トレーニング) = 0.49
#                 : 230. 正答率(テスト) = 0.4751
# Generation: 240. 正答率(トレーニング) = 0.48
#                 : 240. 正答率(テスト) = 0.4138
# Generation: 250. 正答率(トレーニング) = 0.39
#                 : 250. 正答率(テスト) = 0.3301
# Generation: 260. 正答率(トレーニング) = 0.43
#                 : 260. 正答率(テスト) = 0.4279
# Generation: 270. 正答率(トレーニング) = 0.44
#                 : 270. 正答率(テスト) = 0.473
# Generation: 280. 正答率(トレーニング) = 0.3
#                 : 280. 正答率(テスト) = 0.4161
# Generation: 290. 正答率(トレーニング) = 0.49
#                 : 290. 正答率(テスト) = 0.4611
# Generation: 300. 正答率(トレーニング) = 0.48
#                 : 300. 正答率(テスト) = 0.5133
# Generation: 310. 正答率(トレーニング) = 0.5
#                 : 310. 正答率(テスト) = 0.4694
# Generation: 320. 正答率(トレーニング) = 0.47
#                 : 320. 正答率(テスト) = 0.4192
# Generation: 330. 正答率(トレーニング) = 0.41
#                 : 330. 正答率(テスト) = 0.4149
# Generation: 340. 正答率(トレーニング) = 0.46
#                 : 340. 正答率(テスト) = 0.4436
# Generation: 350. 正答率(トレーニング) = 0.44
#                 : 350. 正答率(テスト) = 0.4576
# Generation: 360. 正答率(トレーニング) = 0.41
#                 : 360. 正答率(テスト) = 0.4718
# Generation: 370. 正答率(トレーニング) = 0.49
#                 : 370. 正答率(テスト) = 0.5157
# Generation: 380. 正答率(トレーニング) = 0.57
#                 : 380. 正答率(テスト) = 0.491
# Generation: 390. 正答率(トレーニング) = 0.42
#                 : 390. 正答率(テスト) = 0.4469
# Generation: 400. 正答率(トレーニング) = 0.55
#                 : 400. 正答率(テスト) = 0.5483
# Generation: 410. 正答率(トレーニング) = 0.46
#                 : 410. 正答率(テスト) = 0.5008
# Generation: 420. 正答率(トレーニング) = 0.44
#                 : 420. 正答率(テスト) = 0.5163
# Generation: 430. 正答率(トレーニング) = 0.37
#                 : 430. 正答率(テスト) = 0.5154
# Generation: 440. 正答率(トレーニング) = 0.48
#                 : 440. 正答率(テスト) = 0.5202
# Generation: 450. 正答率(トレーニング) = 0.58
#                 : 450. 正答率(テスト) = 0.5194
# Generation: 460. 正答率(トレーニング) = 0.48
#                 : 460. 正答率(テスト) = 0.5252
# Generation: 470. 正答率(トレーニング) = 0.65
#                 : 470. 正答率(テスト) = 0.5412
# Generation: 480. 正答率(トレーニング) = 0.6
#                 : 480. 正答率(テスト) = 0.5145
# Generation: 490. 正答率(トレーニング) = 0.51
#                 : 490. 正答率(テスト) = 0.5347
# Generation: 500. 正答率(トレーニング) = 0.54
#                 : 500. 正答率(テスト) = 0.5473
# Generation: 510. 正答率(トレーニング) = 0.59
#                 : 510. 正答率(テスト) = 0.5637
# Generation: 520. 正答率(トレーニング) = 0.51
#                 : 520. 正答率(テスト) = 0.5528
# Generation: 530. 正答率(トレーニング) = 0.56
#                 : 530. 正答率(テスト) = 0.5876
# Generation: 540. 正答率(トレーニング) = 0.62
#                 : 540. 正答率(テスト) = 0.5817
# Generation: 550. 正答率(トレーニング) = 0.57
#                 : 550. 正答率(テスト) = 0.5807
# Generation: 560. 正答率(トレーニング) = 0.53
#                 : 560. 正答率(テスト) = 0.5797
# Generation: 570. 正答率(トレーニング) = 0.63
#                 : 570. 正答率(テスト) = 0.5795
# Generation: 580. 正答率(トレーニング) = 0.6
#                 : 580. 正答率(テスト) = 0.5725
# Generation: 590. 正答率(トレーニング) = 0.54
#                 : 590. 正答率(テスト) = 0.5769
# Generation: 600. 正答率(トレーニング) = 0.63
#                 : 600. 正答率(テスト) = 0.5895
# Generation: 610. 正答率(トレーニング) = 0.55
#                 : 610. 正答率(テスト) = 0.5916
# Generation: 620. 正答率(トレーニング) = 0.57
#                 : 620. 正答率(テスト) = 0.5921
# Generation: 630. 正答率(トレーニング) = 0.51
#                 : 630. 正答率(テスト) = 0.6111
# Generation: 640. 正答率(トレーニング) = 0.6
#                 : 640. 正答率(テスト) = 0.6122
# Generation: 650. 正答率(トレーニング) = 0.58
#                 : 650. 正答率(テスト) = 0.6072
# Generation: 660. 正答率(トレーニング) = 0.54
#                 : 660. 正答率(テスト) = 0.6097
# Generation: 670. 正答率(トレーニング) = 0.59
#                 : 670. 正答率(テスト) = 0.6089
# Generation: 680. 正答率(トレーニング) = 0.65
#                 : 680. 正答率(テスト) = 0.6289
# Generation: 690. 正答率(トレーニング) = 0.66
#                 : 690. 正答率(テスト) = 0.6393
# Generation: 700. 正答率(トレーニング) = 0.76
#                 : 700. 正答率(テスト) = 0.6366
# Generation: 710. 正答率(トレーニング) = 0.63
#                 : 710. 正答率(テスト) = 0.6413
# Generation: 720. 正答率(トレーニング) = 0.6
#                 : 720. 正答率(テスト) = 0.6461
# Generation: 730. 正答率(トレーニング) = 0.66
#                 : 730. 正答率(テスト) = 0.6403
# Generation: 740. 正答率(トレーニング) = 0.62
#                 : 740. 正答率(テスト) = 0.636
# Generation: 750. 正答率(トレーニング) = 0.58
#                 : 750. 正答率(テスト) = 0.6425
# Generation: 760. 正答率(トレーニング) = 0.63
#                 : 760. 正答率(テスト) = 0.6362
# Generation: 770. 正答率(トレーニング) = 0.62
#                 : 770. 正答率(テスト) = 0.6534
# Generation: 780. 正答率(トレーニング) = 0.68
#                 : 780. 正答率(テスト) = 0.6561
# Generation: 790. 正答率(トレーニング) = 0.6
#                 : 790. 正答率(テスト) = 0.6718
# Generation: 800. 正答率(トレーニング) = 0.63
#                 : 800. 正答率(テスト) = 0.6688
# Generation: 810. 正答率(トレーニング) = 0.7
#                 : 810. 正答率(テスト) = 0.669
# Generation: 820. 正答率(トレーニング) = 0.67
#                 : 820. 正答率(テスト) = 0.6766
# Generation: 830. 正答率(トレーニング) = 0.69
#                 : 830. 正答率(テスト) = 0.6788
# Generation: 840. 正答率(トレーニング) = 0.7
#                 : 840. 正答率(テスト) = 0.6845
# Generation: 850. 正答率(トレーニング) = 0.66
#                 : 850. 正答率(テスト) = 0.6782
# Generation: 860. 正答率(トレーニング) = 0.77
#                 : 860. 正答率(テスト) = 0.6838
# Generation: 870. 正答率(トレーニング) = 0.59
#                 : 870. 正答率(テスト) = 0.684
# Generation: 880. 正答率(トレーニング) = 0.64
#                 : 880. 正答率(テスト) = 0.6872
# Generation: 890. 正答率(トレーニング) = 0.75
#                 : 890. 正答率(テスト) = 0.6822
# Generation: 900. 正答率(トレーニング) = 0.61
#                 : 900. 正答率(テスト) = 0.6802
# Generation: 910. 正答率(トレーニング) = 0.65
#                 : 910. 正答率(テスト) = 0.6926
# Generation: 920. 正答率(トレーニング) = 0.72
#                 : 920. 正答率(テスト) = 0.699
# Generation: 930. 正答率(トレーニング) = 0.71
#                 : 930. 正答率(テスト) = 0.6978
# Generation: 940. 正答率(トレーニング) = 0.69
#                 : 940. 正答率(テスト) = 0.7014
# Generation: 950. 正答率(トレーニング) = 0.64
#                 : 950. 正答率(テスト) = 0.7056
# Generation: 960. 正答率(トレーニング) = 0.7
#                 : 960. 正答率(テスト) = 0.7018
# Generation: 970. 正答率(トレーニング) = 0.7
#                 : 970. 正答率(テスト) = 0.7078
# Generation: 980. 正答率(トレーニング) = 0.73
#                 : 980. 正答率(テスト) = 0.7041
# Generation: 990. 正答率(トレーニング) = 0.72
#                 : 990. 正答率(テスト) = 0.7059
# Generation: 1000. 正答率(トレーニング) = 0.71
#                 : 1000. 正答率(テスト) = 0.706
# Generation: 1010. 正答率(トレーニング) = 0.68
#                 : 1010. 正答率(テスト) = 0.7066
# Generation: 1020. 正答率(トレーニング) = 0.72
#                 : 1020. 正答率(テスト) = 0.7058
# Generation: 1030. 正答率(トレーニング) = 0.74
#                 : 1030. 正答率(テスト) = 0.7173
# Generation: 1040. 正答率(トレーニング) = 0.73
#                 : 1040. 正答率(テスト) = 0.7182
# Generation: 1050. 正答率(トレーニング) = 0.65
#                 : 1050. 正答率(テスト) = 0.7185
# Generation: 1060. 正答率(トレーニング) = 0.7
#                 : 1060. 正答率(テスト) = 0.7172
# Generation: 1070. 正答率(トレーニング) = 0.69
#                 : 1070. 正答率(テスト) = 0.721
# Generation: 1080. 正答率(トレーニング) = 0.79
#                 : 1080. 正答率(テスト) = 0.7186
# Generation: 1090. 正答率(トレーニング) = 0.7
#                 : 1090. 正答率(テスト) = 0.7231
# Generation: 1100. 正答率(トレーニング) = 0.7
#                 : 1100. 正答率(テスト) = 0.722
# Generation: 1110. 正答率(トレーニング) = 0.72
#                 : 1110. 正答率(テスト) = 0.7207
# Generation: 1120. 正答率(トレーニング) = 0.74
#                 : 1120. 正答率(テスト) = 0.7218
# Generation: 1130. 正答率(トレーニング) = 0.71
#                 : 1130. 正答率(テスト) = 0.7257
# Generation: 1140. 正答率(トレーニング) = 0.71
#                 : 1140. 正答率(テスト) = 0.7319
# Generation: 1150. 正答率(トレーニング) = 0.7
#                 : 1150. 正答率(テスト) = 0.7288
# Generation: 1160. 正答率(トレーニング) = 0.73
#                 : 1160. 正答率(テスト) = 0.7275
# Generation: 1170. 正答率(トレーニング) = 0.78
#                 : 1170. 正答率(テスト) = 0.7332
# Generation: 1180. 正答率(トレーニング) = 0.75
#                 : 1180. 正答率(テスト) = 0.731
# Generation: 1190. 正答率(トレーニング) = 0.76
#                 : 1190. 正答率(テスト) = 0.7325
# Generation: 1200. 正答率(トレーニング) = 0.61
#                 : 1200. 正答率(テスト) = 0.7342
# Generation: 1210. 正答率(トレーニング) = 0.75
#                 : 1210. 正答率(テスト) = 0.7378
# Generation: 1220. 正答率(トレーニング) = 0.73
#                 : 1220. 正答率(テスト) = 0.7379
# Generation: 1230. 正答率(トレーニング) = 0.74
#                 : 1230. 正答率(テスト) = 0.7437
# Generation: 1240. 正答率(トレーニング) = 0.82
#                 : 1240. 正答率(テスト) = 0.7434
# Generation: 1250. 正答率(トレーニング) = 0.7
#                 : 1250. 正答率(テスト) = 0.7414
# Generation: 1260. 正答率(トレーニング) = 0.76
#                 : 1260. 正答率(テスト) = 0.7431
# Generation: 1270. 正答率(トレーニング) = 0.77
#                 : 1270. 正答率(テスト) = 0.7447
# Generation: 1280. 正答率(トレーニング) = 0.77
#                 : 1280. 正答率(テスト) = 0.7467
# Generation: 1290. 正答率(トレーニング) = 0.76
#                 : 1290. 正答率(テスト) = 0.7518
# Generation: 1300. 正答率(トレーニング) = 0.71
#                 : 1300. 正答率(テスト) = 0.7525
# Generation: 1310. 正答率(トレーニング) = 0.73
#                 : 1310. 正答率(テスト) = 0.7513
# Generation: 1320. 正答率(トレーニング) = 0.84
#                 : 1320. 正答率(テスト) = 0.7502
# Generation: 1330. 正答率(トレーニング) = 0.73
#                 : 1330. 正答率(テスト) = 0.7542
# Generation: 1340. 正答率(トレーニング) = 0.75
#                 : 1340. 正答率(テスト) = 0.7583
# Generation: 1350. 正答率(トレーニング) = 0.69
#                 : 1350. 正答率(テスト) = 0.7568
# Generation: 1360. 正答率(トレーニング) = 0.76
#                 : 1360. 正答率(テスト) = 0.7552
# Generation: 1370. 正答率(トレーニング) = 0.74
#                 : 1370. 正答率(テスト) = 0.7561
# Generation: 1380. 正答率(トレーニング) = 0.77
#                 : 1380. 正答率(テスト) = 0.7597
# Generation: 1390. 正答率(トレーニング) = 0.74
#                 : 1390. 正答率(テスト) = 0.756
# Generation: 1400. 正答率(トレーニング) = 0.76
#                 : 1400. 正答率(テスト) = 0.7563
# Generation: 1410. 正答率(トレーニング) = 0.76
#                 : 1410. 正答率(テスト) = 0.7528
# Generation: 1420. 正答率(トレーニング) = 0.76
#                 : 1420. 正答率(テスト) = 0.754
# Generation: 1430. 正答率(トレーニング) = 0.77
#                 : 1430. 正答率(テスト) = 0.7583
# Generation: 1440. 正答率(トレーニング) = 0.7
#                 : 1440. 正答率(テスト) = 0.7578
# Generation: 1450. 正答率(トレーニング) = 0.77
#                 : 1450. 正答率(テスト) = 0.761
# Generation: 1460. 正答率(トレーニング) = 0.7
#                 : 1460. 正答率(テスト) = 0.7598
# Generation: 1470. 正答率(トレーニング) = 0.71
#                 : 1470. 正答率(テスト) = 0.7609
# Generation: 1480. 正答率(トレーニング) = 0.77
#                 : 1480. 正答率(テスト) = 0.7637
# Generation: 1490. 正答率(トレーニング) = 0.77
#                 : 1490. 正答率(テスト) = 0.7661
# Generation: 1500. 正答率(トレーニング) = 0.79
#                 : 1500. 正答率(テスト) = 0.768
# Generation: 1510. 正答率(トレーニング) = 0.72
#                 : 1510. 正答率(テスト) = 0.7679
# Generation: 1520. 正答率(トレーニング) = 0.73
#                 : 1520. 正答率(テスト) = 0.7696
# Generation: 1530. 正答率(トレーニング) = 0.83
#                 : 1530. 正答率(テスト) = 0.7662
# Generation: 1540. 正答率(トレーニング) = 0.75
#                 : 1540. 正答率(テスト) = 0.7659
# Generation: 1550. 正答率(トレーニング) = 0.68
#                 : 1550. 正答率(テスト) = 0.7702
# Generation: 1560. 正答率(トレーニング) = 0.77
#                 : 1560. 正答率(テスト) = 0.7742
# Generation: 1570. 正答率(トレーニング) = 0.75
#                 : 1570. 正答率(テスト) = 0.7754
# Generation: 1580. 正答率(トレーニング) = 0.75
#                 : 1580. 正答率(テスト) = 0.7725
# Generation: 1590. 正答率(トレーニング) = 0.75
#                 : 1590. 正答率(テスト) = 0.7756
# Generation: 1600. 正答率(トレーニング) = 0.75
#                 : 1600. 正答率(テスト) = 0.7692
# Generation: 1610. 正答率(トレーニング) = 0.84
#                 : 1610. 正答率(テスト) = 0.7687
# Generation: 1620. 正答率(トレーニング) = 0.72
#                 : 1620. 正答率(テスト) = 0.769
# Generation: 1630. 正答率(トレーニング) = 0.81
#                 : 1630. 正答率(テスト) = 0.77
# Generation: 1640. 正答率(トレーニング) = 0.77
#                 : 1640. 正答率(テスト) = 0.7785
# Generation: 1650. 正答率(トレーニング) = 0.77
#                 : 1650. 正答率(テスト) = 0.7804
# Generation: 1660. 正答率(トレーニング) = 0.76
#                 : 1660. 正答率(テスト) = 0.7771
# Generation: 1670. 正答率(トレーニング) = 0.75
#                 : 1670. 正答率(テスト) = 0.7777
# Generation: 1680. 正答率(トレーニング) = 0.76
#                 : 1680. 正答率(テスト) = 0.7841
# Generation: 1690. 正答率(トレーニング) = 0.77
#                 : 1690. 正答率(テスト) = 0.7861
# Generation: 1700. 正答率(トレーニング) = 0.84
#                 : 1700. 正答率(テスト) = 0.7839
# Generation: 1710. 正答率(トレーニング) = 0.81
#                 : 1710. 正答率(テスト) = 0.7883
# Generation: 1720. 正答率(トレーニング) = 0.83
#                 : 1720. 正答率(テスト) = 0.7827
# Generation: 1730. 正答率(トレーニング) = 0.79
#                 : 1730. 正答率(テスト) = 0.7859
# Generation: 1740. 正答率(トレーニング) = 0.8
#                 : 1740. 正答率(テスト) = 0.7834
# Generation: 1750. 正答率(トレーニング) = 0.83
#                 : 1750. 正答率(テスト) = 0.7886
# Generation: 1760. 正答率(トレーニング) = 0.75
#                 : 1760. 正答率(テスト) = 0.7839
# Generation: 1770. 正答率(トレーニング) = 0.75
#                 : 1770. 正答率(テスト) = 0.7886
# Generation: 1780. 正答率(トレーニング) = 0.81
#                 : 1780. 正答率(テスト) = 0.7908
# Generation: 1790. 正答率(トレーニング) = 0.79
#                 : 1790. 正答率(テスト) = 0.7841
# Generation: 1800. 正答率(トレーニング) = 0.77
#                 : 1800. 正答率(テスト) = 0.7888
# Generation: 1810. 正答率(トレーニング) = 0.8
#                 : 1810. 正答率(テスト) = 0.7867
# Generation: 1820. 正答率(トレーニング) = 0.79
#                 : 1820. 正答率(テスト) = 0.7923
# Generation: 1830. 正答率(トレーニング) = 0.78
#                 : 1830. 正答率(テスト) = 0.7906
# Generation: 1840. 正答率(トレーニング) = 0.77
#                 : 1840. 正答率(テスト) = 0.7913
# Generation: 1850. 正答率(トレーニング) = 0.78
#                 : 1850. 正答率(テスト) = 0.7854
# Generation: 1860. 正答率(トレーニング) = 0.73
#                 : 1860. 正答率(テスト) = 0.7901
# Generation: 1870. 正答率(トレーニング) = 0.83
#                 : 1870. 正答率(テスト) = 0.7945
# Generation: 1880. 正答率(トレーニング) = 0.76
#                 : 1880. 正答率(テスト) = 0.7926
# Generation: 1890. 正答率(トレーニング) = 0.78
#                 : 1890. 正答率(テスト) = 0.7953
# Generation: 1900. 正答率(トレーニング) = 0.76
#                 : 1900. 正答率(テスト) = 0.7948
# Generation: 1910. 正答率(トレーニング) = 0.69
#                 : 1910. 正答率(テスト) = 0.7932
# Generation: 1920. 正答率(トレーニング) = 0.83
#                 : 1920. 正答率(テスト) = 0.7918
# Generation: 1930. 正答率(トレーニング) = 0.79
#                 : 1930. 正答率(テスト) = 0.795
# Generation: 1940. 正答率(トレーニング) = 0.7
#                 : 1940. 正答率(テスト) = 0.7972
# Generation: 1950. 正答率(トレーニング) = 0.82
#                 : 1950. 正答率(テスト) = 0.7979
# Generation: 1960. 正答率(トレーニング) = 0.8
#                 : 1960. 正答率(テスト) = 0.7985
# Generation: 1970. 正答率(トレーニング) = 0.75
#                 : 1970. 正答率(テスト) = 0.801
# Generation: 1980. 正答率(トレーニング) = 0.81
#                 : 1980. 正答率(テスト) = 0.7977
# Generation: 1990. 正答率(トレーニング) = 0.82
#                 : 1990. 正答率(テスト) = 0.7988
# Generation: 2000. 正答率(トレーニング) = 0.84
#                 : 2000. 正答率(テスト) = 0.7999

# %% [markdown]
# 活性化関数がsigmoidでもXavier初期化することで学習が進むようになっている
# ただし、ReLUに比べると正解率は低い

# %% [markdown]
# ## ReLU - He

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 

    ###########  変更箇所  ##############

    # Heの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_1_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    network['W2'] = np.random.randn(hidden_layer_1_size, hidden_layer_2_size) / np.sqrt(hidden_layer_1_size) * np.sqrt(2)
    network['W3'] = np.random.randn(hidden_layer_2_size, output_layer_size) / np.sqrt(hidden_layer_2_size) * np.sqrt(2)
        
    #################################
    
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    ###########  変更箇所  ##############
    
    hidden_f = functions.relu
    
    #################################
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    ###########  変更箇所  ##############
    
    hidden_d_f = functions.d_relu
    
    #################################
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.27
#                 : 10. 正答率(テスト) = 0.3228
# Generation: 20. 正答率(トレーニング) = 0.49
#                 : 20. 正答率(テスト) = 0.4892
# Generation: 30. 正答率(トレーニング) = 0.61
#                 : 30. 正答率(テスト) = 0.6477
# Generation: 40. 正答率(トレーニング) = 0.68
#                 : 40. 正答率(テスト) = 0.6789
# Generation: 50. 正答率(トレーニング) = 0.58
#                 : 50. 正答率(テスト) = 0.656
# Generation: 60. 正答率(トレーニング) = 0.75
#                 : 60. 正答率(テスト) = 0.8154
# Generation: 70. 正答率(トレーニング) = 0.88
#                 : 70. 正答率(テスト) = 0.8305
# Generation: 80. 正答率(トレーニング) = 0.79
#                 : 80. 正答率(テスト) = 0.852
# Generation: 90. 正答率(トレーニング) = 0.88
#                 : 90. 正答率(テスト) = 0.8461
# Generation: 100. 正答率(トレーニング) = 0.81
#                 : 100. 正答率(テスト) = 0.8458
# Generation: 110. 正答率(トレーニング) = 0.88
#                 : 110. 正答率(テスト) = 0.8641
# Generation: 120. 正答率(トレーニング) = 0.83
#                 : 120. 正答率(テスト) = 0.8747
# Generation: 130. 正答率(トレーニング) = 0.91
#                 : 130. 正答率(テスト) = 0.8652
# Generation: 140. 正答率(トレーニング) = 0.92
#                 : 140. 正答率(テスト) = 0.8744
# Generation: 150. 正答率(トレーニング) = 0.85
#                 : 150. 正答率(テスト) = 0.8891
# Generation: 160. 正答率(トレーニング) = 0.82
#                 : 160. 正答率(テスト) = 0.8896
# Generation: 170. 正答率(トレーニング) = 0.86
#                 : 170. 正答率(テスト) = 0.8966
# Generation: 180. 正答率(トレーニング) = 0.87
#                 : 180. 正答率(テスト) = 0.8925
# Generation: 190. 正答率(トレーニング) = 0.88
#                 : 190. 正答率(テスト) = 0.8915
# Generation: 200. 正答率(トレーニング) = 0.87
#                 : 200. 正答率(テスト) = 0.8775
# Generation: 210. 正答率(トレーニング) = 0.82
#                 : 210. 正答率(テスト) = 0.8947
# Generation: 220. 正答率(トレーニング) = 0.87
#                 : 220. 正答率(テスト) = 0.9031
# Generation: 230. 正答率(トレーニング) = 0.85
#                 : 230. 正答率(テスト) = 0.896
# Generation: 240. 正答率(トレーニング) = 0.87
#                 : 240. 正答率(テスト) = 0.9014
# Generation: 250. 正答率(トレーニング) = 0.96
#                 : 250. 正答率(テスト) = 0.8994
# Generation: 260. 正答率(トレーニング) = 0.97
#                 : 260. 正答率(テスト) = 0.9006
# Generation: 270. 正答率(トレーニング) = 0.9
#                 : 270. 正答率(テスト) = 0.8871
# Generation: 280. 正答率(トレーニング) = 0.89
#                 : 280. 正答率(テスト) = 0.8951
# Generation: 290. 正答率(トレーニング) = 0.94
#                 : 290. 正答率(テスト) = 0.9043
# Generation: 300. 正答率(トレーニング) = 0.91
#                 : 300. 正答率(テスト) = 0.9016
# Generation: 310. 正答率(トレーニング) = 0.92
#                 : 310. 正答率(テスト) = 0.9084
# Generation: 320. 正答率(トレーニング) = 0.91
#                 : 320. 正答率(テスト) = 0.9135
# Generation: 330. 正答率(トレーニング) = 0.9
#                 : 330. 正答率(テスト) = 0.896
# Generation: 340. 正答率(トレーニング) = 0.9
#                 : 340. 正答率(テスト) = 0.9009
# Generation: 350. 正答率(トレーニング) = 0.95
#                 : 350. 正答率(テスト) = 0.912
# Generation: 360. 正答率(トレーニング) = 0.9
#                 : 360. 正答率(テスト) = 0.9121
# Generation: 370. 正答率(トレーニング) = 0.94
#                 : 370. 正答率(テスト) = 0.9125
# Generation: 380. 正答率(トレーニング) = 0.89
#                 : 380. 正答率(テスト) = 0.9013
# Generation: 390. 正答率(トレーニング) = 0.89
#                 : 390. 正答率(テスト) = 0.916
# Generation: 400. 正答率(トレーニング) = 0.91
#                 : 400. 正答率(テスト) = 0.9168
# Generation: 410. 正答率(トレーニング) = 0.95
#                 : 410. 正答率(テスト) = 0.9133
# Generation: 420. 正答率(トレーニング) = 0.91
#                 : 420. 正答率(テスト) = 0.9134
# Generation: 430. 正答率(トレーニング) = 0.95
#                 : 430. 正答率(テスト) = 0.9197
# Generation: 440. 正答率(トレーニング) = 0.94
#                 : 440. 正答率(テスト) = 0.9183
# Generation: 450. 正答率(トレーニング) = 0.94
#                 : 450. 正答率(テスト) = 0.919
# Generation: 460. 正答率(トレーニング) = 0.95
#                 : 460. 正答率(テスト) = 0.9228
# Generation: 470. 正答率(トレーニング) = 0.86
#                 : 470. 正答率(テスト) = 0.9195
# Generation: 480. 正答率(トレーニング) = 0.92
#                 : 480. 正答率(テスト) = 0.9205
# Generation: 490. 正答率(トレーニング) = 0.97
#                 : 490. 正答率(テスト) = 0.9245
# Generation: 500. 正答率(トレーニング) = 0.91
#                 : 500. 正答率(テスト) = 0.9155
# Generation: 510. 正答率(トレーニング) = 0.92
#                 : 510. 正答率(テスト) = 0.926
# Generation: 520. 正答率(トレーニング) = 0.93
#                 : 520. 正答率(テスト) = 0.9225
# Generation: 530. 正答率(トレーニング) = 0.94
#                 : 530. 正答率(テスト) = 0.917
# Generation: 540. 正答率(トレーニング) = 0.94
#                 : 540. 正答率(テスト) = 0.9243
# Generation: 550. 正答率(トレーニング) = 0.95
#                 : 550. 正答率(テスト) = 0.9283
# Generation: 560. 正答率(トレーニング) = 0.91
#                 : 560. 正答率(テスト) = 0.9213
# Generation: 570. 正答率(トレーニング) = 0.92
#                 : 570. 正答率(テスト) = 0.9272
# Generation: 580. 正答率(トレーニング) = 0.89
#                 : 580. 正答率(テスト) = 0.9255
# Generation: 590. 正答率(トレーニング) = 0.94
#                 : 590. 正答率(テスト) = 0.9193
# Generation: 600. 正答率(トレーニング) = 0.88
#                 : 600. 正答率(テスト) = 0.9257
# Generation: 610. 正答率(トレーニング) = 0.96
#                 : 610. 正答率(テスト) = 0.9282
# Generation: 620. 正答率(トレーニング) = 0.94
#                 : 620. 正答率(テスト) = 0.9297
# Generation: 630. 正答率(トレーニング) = 0.95
#                 : 630. 正答率(テスト) = 0.9234
# Generation: 640. 正答率(トレーニング) = 0.92
#                 : 640. 正答率(テスト) = 0.9323
# Generation: 650. 正答率(トレーニング) = 0.89
#                 : 650. 正答率(テスト) = 0.9279
# Generation: 660. 正答率(トレーニング) = 0.95
#                 : 660. 正答率(テスト) = 0.9281
# Generation: 670. 正答率(トレーニング) = 0.95
#                 : 670. 正答率(テスト) = 0.9255
# Generation: 680. 正答率(トレーニング) = 0.94
#                 : 680. 正答率(テスト) = 0.9291
# Generation: 690. 正答率(トレーニング) = 0.97
#                 : 690. 正答率(テスト) = 0.9338
# Generation: 700. 正答率(トレーニング) = 0.94
#                 : 700. 正答率(テスト) = 0.9321
# Generation: 710. 正答率(トレーニング) = 0.92
#                 : 710. 正答率(テスト) = 0.936
# Generation: 720. 正答率(トレーニング) = 0.95
#                 : 720. 正答率(テスト) = 0.9324
# Generation: 730. 正答率(トレーニング) = 0.96
#                 : 730. 正答率(テスト) = 0.9356
# Generation: 740. 正答率(トレーニング) = 0.95
#                 : 740. 正答率(テスト) = 0.9321
# Generation: 750. 正答率(トレーニング) = 0.93
#                 : 750. 正答率(テスト) = 0.9277
# Generation: 760. 正答率(トレーニング) = 0.96
#                 : 760. 正答率(テスト) = 0.9292
# Generation: 770. 正答率(トレーニング) = 0.94
#                 : 770. 正答率(テスト) = 0.9327
# Generation: 780. 正答率(トレーニング) = 0.94
#                 : 780. 正答率(テスト) = 0.9285
# Generation: 790. 正答率(トレーニング) = 0.94
#                 : 790. 正答率(テスト) = 0.9332
# Generation: 800. 正答率(トレーニング) = 0.94
#                 : 800. 正答率(テスト) = 0.9301
# Generation: 810. 正答率(トレーニング) = 0.94
#                 : 810. 正答率(テスト) = 0.9363
# Generation: 820. 正答率(トレーニング) = 0.95
#                 : 820. 正答率(テスト) = 0.9347
# Generation: 830. 正答率(トレーニング) = 0.91
#                 : 830. 正答率(テスト) = 0.9371
# Generation: 840. 正答率(トレーニング) = 0.96
#                 : 840. 正答率(テスト) = 0.9362
# Generation: 850. 正答率(トレーニング) = 0.97
#                 : 850. 正答率(テスト) = 0.9361
# Generation: 860. 正答率(トレーニング) = 0.93
#                 : 860. 正答率(テスト) = 0.9362
# Generation: 870. 正答率(トレーニング) = 0.94
#                 : 870. 正答率(テスト) = 0.9392
# Generation: 880. 正答率(トレーニング) = 0.93
#                 : 880. 正答率(テスト) = 0.9359
# Generation: 890. 正答率(トレーニング) = 0.93
#                 : 890. 正答率(テスト) = 0.9311
# Generation: 900. 正答率(トレーニング) = 0.92
#                 : 900. 正答率(テスト) = 0.9339
# Generation: 910. 正答率(トレーニング) = 0.91
#                 : 910. 正答率(テスト) = 0.9403
# Generation: 920. 正答率(トレーニング) = 0.97
#                 : 920. 正答率(テスト) = 0.9394
# Generation: 930. 正答率(トレーニング) = 0.92
#                 : 930. 正答率(テスト) = 0.939
# Generation: 940. 正答率(トレーニング) = 0.95
#                 : 940. 正答率(テスト) = 0.9403
# Generation: 950. 正答率(トレーニング) = 0.89
#                 : 950. 正答率(テスト) = 0.9314
# Generation: 960. 正答率(トレーニング) = 0.95
#                 : 960. 正答率(テスト) = 0.9411
# Generation: 970. 正答率(トレーニング) = 0.93
#                 : 970. 正答率(テスト) = 0.938
# Generation: 980. 正答率(トレーニング) = 0.95
#                 : 980. 正答率(テスト) = 0.9412
# Generation: 990. 正答率(トレーニング) = 0.92
#                 : 990. 正答率(テスト) = 0.932
# Generation: 1000. 正答率(トレーニング) = 0.93
#                 : 1000. 正答率(テスト) = 0.9408
# Generation: 1010. 正答率(トレーニング) = 0.96
#                 : 1010. 正答率(テスト) = 0.9397
# Generation: 1020. 正答率(トレーニング) = 0.92
#                 : 1020. 正答率(テスト) = 0.9425
# Generation: 1030. 正答率(トレーニング) = 0.97
#                 : 1030. 正答率(テスト) = 0.9428
# Generation: 1040. 正答率(トレーニング) = 0.97
#                 : 1040. 正答率(テスト) = 0.9443
# Generation: 1050. 正答率(トレーニング) = 0.94
#                 : 1050. 正答率(テスト) = 0.9415
# Generation: 1060. 正答率(トレーニング) = 0.96
#                 : 1060. 正答率(テスト) = 0.9367
# Generation: 1070. 正答率(トレーニング) = 0.96
#                 : 1070. 正答率(テスト) = 0.9419
# Generation: 1080. 正答率(トレーニング) = 0.95
#                 : 1080. 正答率(テスト) = 0.9448
# Generation: 1090. 正答率(トレーニング) = 0.98
#                 : 1090. 正答率(テスト) = 0.9454
# Generation: 1100. 正答率(トレーニング) = 0.92
#                 : 1100. 正答率(テスト) = 0.9447
# Generation: 1110. 正答率(トレーニング) = 0.95
#                 : 1110. 正答率(テスト) = 0.9448
# Generation: 1120. 正答率(トレーニング) = 0.89
#                 : 1120. 正答率(テスト) = 0.9418
# Generation: 1130. 正答率(トレーニング) = 0.96
#                 : 1130. 正答率(テスト) = 0.9402
# Generation: 1140. 正答率(トレーニング) = 0.94
#                 : 1140. 正答率(テスト) = 0.942
# Generation: 1150. 正答率(トレーニング) = 0.91
#                 : 1150. 正答率(テスト) = 0.9391
# Generation: 1160. 正答率(トレーニング) = 0.9
#                 : 1160. 正答率(テスト) = 0.9453
# Generation: 1170. 正答率(トレーニング) = 0.96
#                 : 1170. 正答率(テスト) = 0.9461
# Generation: 1180. 正答率(トレーニング) = 0.98
#                 : 1180. 正答率(テスト) = 0.9454
# Generation: 1190. 正答率(トレーニング) = 0.97
#                 : 1190. 正答率(テスト) = 0.9446
# Generation: 1200. 正答率(トレーニング) = 0.98
#                 : 1200. 正答率(テスト) = 0.9454
# Generation: 1210. 正答率(トレーニング) = 0.95
#                 : 1210. 正答率(テスト) = 0.9386
# Generation: 1220. 正答率(トレーニング) = 0.94
#                 : 1220. 正答率(テスト) = 0.9478
# Generation: 1230. 正答率(トレーニング) = 0.94
#                 : 1230. 正答率(テスト) = 0.9404
# Generation: 1240. 正答率(トレーニング) = 0.95
#                 : 1240. 正答率(テスト) = 0.9449
# Generation: 1250. 正答率(トレーニング) = 0.95
#                 : 1250. 正答率(テスト) = 0.9414
# Generation: 1260. 正答率(トレーニング) = 0.94
#                 : 1260. 正答率(テスト) = 0.9466
# Generation: 1270. 正答率(トレーニング) = 0.93
#                 : 1270. 正答率(テスト) = 0.9453
# Generation: 1280. 正答率(トレーニング) = 0.99
#                 : 1280. 正答率(テスト) = 0.9473
# Generation: 1290. 正答率(トレーニング) = 0.98
#                 : 1290. 正答率(テスト) = 0.9414
# Generation: 1300. 正答率(トレーニング) = 0.92
#                 : 1300. 正答率(テスト) = 0.9478
# Generation: 1310. 正答率(トレーニング) = 0.97
#                 : 1310. 正答率(テスト) = 0.9492
# Generation: 1320. 正答率(トレーニング) = 0.94
#                 : 1320. 正答率(テスト) = 0.9437
# Generation: 1330. 正答率(トレーニング) = 0.98
#                 : 1330. 正答率(テスト) = 0.9457
# Generation: 1340. 正答率(トレーニング) = 0.98
#                 : 1340. 正答率(テスト) = 0.9477
# Generation: 1350. 正答率(トレーニング) = 0.98
#                 : 1350. 正答率(テスト) = 0.944
# Generation: 1360. 正答率(トレーニング) = 0.97
#                 : 1360. 正答率(テスト) = 0.9481
# Generation: 1370. 正答率(トレーニング) = 0.96
#                 : 1370. 正答率(テスト) = 0.9504
# Generation: 1380. 正答率(トレーニング) = 0.94
#                 : 1380. 正答率(テスト) = 0.9459
# Generation: 1390. 正答率(トレーニング) = 0.92
#                 : 1390. 正答率(テスト) = 0.9448
# Generation: 1400. 正答率(トレーニング) = 0.95
#                 : 1400. 正答率(テスト) = 0.949
# Generation: 1410. 正答率(トレーニング) = 0.98
#                 : 1410. 正答率(テスト) = 0.9482
# Generation: 1420. 正答率(トレーニング) = 0.92
#                 : 1420. 正答率(テスト) = 0.9493
# Generation: 1430. 正答率(トレーニング) = 0.88
#                 : 1430. 正答率(テスト) = 0.9472
# Generation: 1440. 正答率(トレーニング) = 0.96
#                 : 1440. 正答率(テスト) = 0.9431
# Generation: 1450. 正答率(トレーニング) = 0.89
#                 : 1450. 正答率(テスト) = 0.9468
# Generation: 1460. 正答率(トレーニング) = 0.94
#                 : 1460. 正答率(テスト) = 0.9484
# Generation: 1470. 正答率(トレーニング) = 0.96
#                 : 1470. 正答率(テスト) = 0.9426
# Generation: 1480. 正答率(トレーニング) = 0.93
#                 : 1480. 正答率(テスト) = 0.9455
# Generation: 1490. 正答率(トレーニング) = 0.94
#                 : 1490. 正答率(テスト) = 0.9482
# Generation: 1500. 正答率(トレーニング) = 0.96
#                 : 1500. 正答率(テスト) = 0.9493
# Generation: 1510. 正答率(トレーニング) = 0.93
#                 : 1510. 正答率(テスト) = 0.9401
# Generation: 1520. 正答率(トレーニング) = 0.96
#                 : 1520. 正答率(テスト) = 0.9484
# Generation: 1530. 正答率(トレーニング) = 0.96
#                 : 1530. 正答率(テスト) = 0.9514
# Generation: 1540. 正答率(トレーニング) = 0.94
#                 : 1540. 正答率(テスト) = 0.9486
# Generation: 1550. 正答率(トレーニング) = 0.95
#                 : 1550. 正答率(テスト) = 0.9445
# Generation: 1560. 正答率(トレーニング) = 0.95
#                 : 1560. 正答率(テスト) = 0.9492
# Generation: 1570. 正答率(トレーニング) = 0.98
#                 : 1570. 正答率(テスト) = 0.9494
# Generation: 1580. 正答率(トレーニング) = 0.96
#                 : 1580. 正答率(テスト) = 0.9517
# Generation: 1590. 正答率(トレーニング) = 0.98
#                 : 1590. 正答率(テスト) = 0.946
# Generation: 1600. 正答率(トレーニング) = 0.92
#                 : 1600. 正答率(テスト) = 0.9511
# Generation: 1610. 正答率(トレーニング) = 0.91
#                 : 1610. 正答率(テスト) = 0.9505
# Generation: 1620. 正答率(トレーニング) = 0.93
#                 : 1620. 正答率(テスト) = 0.9487
# Generation: 1630. 正答率(トレーニング) = 0.97
#                 : 1630. 正答率(テスト) = 0.9502
# Generation: 1640. 正答率(トレーニング) = 0.94
#                 : 1640. 正答率(テスト) = 0.9457
# Generation: 1650. 正答率(トレーニング) = 0.96
#                 : 1650. 正答率(テスト) = 0.9496
# Generation: 1660. 正答率(トレーニング) = 0.93
#                 : 1660. 正答率(テスト) = 0.9513
# Generation: 1670. 正答率(トレーニング) = 0.97
#                 : 1670. 正答率(テスト) = 0.9527
# Generation: 1680. 正答率(トレーニング) = 0.91
#                 : 1680. 正答率(テスト) = 0.9535
# Generation: 1690. 正答率(トレーニング) = 0.95
#                 : 1690. 正答率(テスト) = 0.9504
# Generation: 1700. 正答率(トレーニング) = 0.96
#                 : 1700. 正答率(テスト) = 0.9511
# Generation: 1710. 正答率(トレーニング) = 0.94
#                 : 1710. 正答率(テスト) = 0.9477
# Generation: 1720. 正答率(トレーニング) = 0.92
#                 : 1720. 正答率(テスト) = 0.9506
# Generation: 1730. 正答率(トレーニング) = 0.94
#                 : 1730. 正答率(テスト) = 0.9492
# Generation: 1740. 正答率(トレーニング) = 0.94
#                 : 1740. 正答率(テスト) = 0.9461
# Generation: 1750. 正答率(トレーニング) = 0.97
#                 : 1750. 正答率(テスト) = 0.9516
# Generation: 1760. 正答率(トレーニング) = 0.95
#                 : 1760. 正答率(テスト) = 0.9527
# Generation: 1770. 正答率(トレーニング) = 0.94
#                 : 1770. 正答率(テスト) = 0.9487
# Generation: 1780. 正答率(トレーニング) = 0.97
#                 : 1780. 正答率(テスト) = 0.9524
# Generation: 1790. 正答率(トレーニング) = 0.94
#                 : 1790. 正答率(テスト) = 0.9514
# Generation: 1800. 正答率(トレーニング) = 0.92
#                 : 1800. 正答率(テスト) = 0.9516
# Generation: 1810. 正答率(トレーニング) = 0.95
#                 : 1810. 正答率(テスト) = 0.953
# Generation: 1820. 正答率(トレーニング) = 0.96
#                 : 1820. 正答率(テスト) = 0.9458
# Generation: 1830. 正答率(トレーニング) = 0.98
#                 : 1830. 正答率(テスト) = 0.9529
# Generation: 1840. 正答率(トレーニング) = 0.94
#                 : 1840. 正答率(テスト) = 0.9497
# Generation: 1850. 正答率(トレーニング) = 0.95
#                 : 1850. 正答率(テスト) = 0.9484
# Generation: 1860. 正答率(トレーニング) = 0.94
#                 : 1860. 正答率(テスト) = 0.9535
# Generation: 1870. 正答率(トレーニング) = 0.95
#                 : 1870. 正答率(テスト) = 0.9554
# Generation: 1880. 正答率(トレーニング) = 0.97
#                 : 1880. 正答率(テスト) = 0.9545
# Generation: 1890. 正答率(トレーニング) = 0.98
#                 : 1890. 正答率(テスト) = 0.9511
# Generation: 1900. 正答率(トレーニング) = 0.95
#                 : 1900. 正答率(テスト) = 0.9524
# Generation: 1910. 正答率(トレーニング) = 0.98
#                 : 1910. 正答率(テスト) = 0.9521
# Generation: 1920. 正答率(トレーニング) = 0.95
#                 : 1920. 正答率(テスト) = 0.9538
# Generation: 1930. 正答率(トレーニング) = 0.99
#                 : 1930. 正答率(テスト) = 0.9546
# Generation: 1940. 正答率(トレーニング) = 0.93
#                 : 1940. 正答率(テスト) = 0.9439
# Generation: 1950. 正答率(トレーニング) = 1.0
#                 : 1950. 正答率(テスト) = 0.9545
# Generation: 1960. 正答率(トレーニング) = 0.98
#                 : 1960. 正答率(テスト) = 0.9539
# Generation: 1970. 正答率(トレーニング) = 0.93
#                 : 1970. 正答率(テスト) = 0.9516
# Generation: 1980. 正答率(トレーニング) = 0.93
#                 : 1980. 正答率(テスト) = 0.9535
# Generation: 1990. 正答率(トレーニング) = 0.95
#                 : 1990. 正答率(テスト) = 0.9524
# Generation: 2000. 正答率(トレーニング) = 0.97
#                 : 2000. 正答率(テスト) = 0.9513

# %% [markdown]
# He初期化+ReLUの場合、学習曲線は最もよい
# 学習の立ち上がりがよく、精度も高い
