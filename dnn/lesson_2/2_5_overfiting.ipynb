# %% [markdown]
# # overfiting

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer


(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = optimizer.SGD(learning_rate=0.01)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15666666666666668
#                 : 10. 正答率(テスト) = 0.1211
# Generation: 20. 正答率(トレーニング) = 0.21
#                 : 20. 正答率(テスト) = 0.1539
# Generation: 30. 正答率(トレーニング) = 0.30333333333333334
#                 : 30. 正答率(テスト) = 0.2115
# Generation: 40. 正答率(トレーニング) = 0.3933333333333333
#                 : 40. 正答率(テスト) = 0.2719
# Generation: 50. 正答率(トレーニング) = 0.5033333333333333
#                 : 50. 正答率(テスト) = 0.3489
# Generation: 60. 正答率(トレーニング) = 0.5566666666666666
#                 : 60. 正答率(テスト) = 0.3931
# Generation: 70. 正答率(トレーニング) = 0.5933333333333334
#                 : 70. 正答率(テスト) = 0.4386
# Generation: 80. 正答率(トレーニング) = 0.65
#                 : 80. 正答率(テスト) = 0.4682
# Generation: 90. 正答率(トレーニング) = 0.75
#                 : 90. 正答率(テスト) = 0.5231
# Generation: 100. 正答率(トレーニング) = 0.7533333333333333
#                 : 100. 正答率(テスト) = 0.543
# Generation: 110. 正答率(トレーニング) = 0.79
#                 : 110. 正答率(テスト) = 0.5603
# Generation: 120. 正答率(トレーニング) = 0.8333333333333334
#                 : 120. 正答率(テスト) = 0.6078
# Generation: 130. 正答率(トレーニング) = 0.8366666666666667
#                 : 130. 正答率(テスト) = 0.6198
# Generation: 140. 正答率(トレーニング) = 0.8666666666666667
#                 : 140. 正答率(テスト) = 0.6335
# Generation: 150. 正答率(トレーニング) = 0.8833333333333333
#                 : 150. 正答率(テスト) = 0.6655
# Generation: 160. 正答率(トレーニング) = 0.88
#                 : 160. 正答率(テスト) = 0.6707
# Generation: 170. 正答率(トレーニング) = 0.9
#                 : 170. 正答率(テスト) = 0.6819
# Generation: 180. 正答率(トレーニング) = 0.9166666666666666
#                 : 180. 正答率(テスト) = 0.6832
# Generation: 190. 正答率(トレーニング) = 0.9333333333333333
#                 : 190. 正答率(テスト) = 0.6919
# Generation: 200. 正答率(トレーニング) = 0.9366666666666666
#                 : 200. 正答率(テスト) = 0.6972
# Generation: 210. 正答率(トレーニング) = 0.94
#                 : 210. 正答率(テスト) = 0.7019
# Generation: 220. 正答率(トレーニング) = 0.9533333333333334
#                 : 220. 正答率(テスト) = 0.7109
# Generation: 230. 正答率(トレーニング) = 0.96
#                 : 230. 正答率(テスト) = 0.7104
# Generation: 240. 正答率(トレーニング) = 0.96
#                 : 240. 正答率(テスト) = 0.7109
# Generation: 250. 正答率(トレーニング) = 0.9566666666666667
#                 : 250. 正答率(テスト) = 0.7162
# Generation: 260. 正答率(トレーニング) = 0.97
#                 : 260. 正答率(テスト) = 0.7232
# Generation: 270. 正答率(トレーニング) = 0.9766666666666667
#                 : 270. 正答率(テスト) = 0.7219
# Generation: 280. 正答率(トレーニング) = 0.98
#                 : 280. 正答率(テスト) = 0.7255
# Generation: 290. 正答率(トレーニング) = 0.9866666666666667
#                 : 290. 正答率(テスト) = 0.7279
# Generation: 300. 正答率(トレーニング) = 0.9833333333333333
#                 : 300. 正答率(テスト) = 0.7262
# Generation: 310. 正答率(トレーニング) = 0.9866666666666667
#                 : 310. 正答率(テスト) = 0.7297
# Generation: 320. 正答率(トレーニング) = 0.9866666666666667
#                 : 320. 正答率(テスト) = 0.7303
# Generation: 330. 正答率(トレーニング) = 0.99
#                 : 330. 正答率(テスト) = 0.7261
# Generation: 340. 正答率(トレーニング) = 0.9933333333333333
#                 : 340. 正答率(テスト) = 0.7334
# Generation: 350. 正答率(トレーニング) = 0.9933333333333333
#                 : 350. 正答率(テスト) = 0.7304
# Generation: 360. 正答率(トレーニング) = 0.9933333333333333
#                 : 360. 正答率(テスト) = 0.7333
# Generation: 370. 正答率(トレーニング) = 0.9966666666666667
#                 : 370. 正答率(テスト) = 0.7367
# Generation: 380. 正答率(トレーニング) = 0.9966666666666667
#                 : 380. 正答率(テスト) = 0.737
# Generation: 390. 正答率(トレーニング) = 0.9966666666666667
#                 : 390. 正答率(テスト) = 0.7396
# Generation: 400. 正答率(トレーニング) = 0.9966666666666667
#                 : 400. 正答率(テスト) = 0.7399
# Generation: 410. 正答率(トレーニング) = 0.9966666666666667
#                 : 410. 正答率(テスト) = 0.7378
# Generation: 420. 正答率(トレーニング) = 0.9966666666666667
#                 : 420. 正答率(テスト) = 0.7419
# Generation: 430. 正答率(トレーニング) = 1.0
#                 : 430. 正答率(テスト) = 0.7366
# Generation: 440. 正答率(トレーニング) = 1.0
#                 : 440. 正答率(テスト) = 0.7395
# Generation: 450. 正答率(トレーニング) = 1.0
#                 : 450. 正答率(テスト) = 0.7382
# Generation: 460. 正答率(トレーニング) = 1.0
#                 : 460. 正答率(テスト) = 0.7423
# Generation: 470. 正答率(トレーニング) = 1.0
#                 : 470. 正答率(テスト) = 0.7396
# Generation: 480. 正答率(トレーニング) = 1.0
#                 : 480. 正答率(テスト) = 0.7419
# Generation: 490. 正答率(トレーニング) = 1.0
#                 : 490. 正答率(テスト) = 0.7425
# Generation: 500. 正答率(トレーニング) = 1.0
#                 : 500. 正答率(テスト) = 0.7447
# Generation: 510. 正答率(トレーニング) = 1.0
#                 : 510. 正答率(テスト) = 0.7415
# Generation: 520. 正答率(トレーニング) = 1.0
#                 : 520. 正答率(テスト) = 0.7442
# Generation: 530. 正答率(トレーニング) = 1.0
#                 : 530. 正答率(テスト) = 0.7419
# Generation: 540. 正答率(トレーニング) = 1.0
#                 : 540. 正答率(テスト) = 0.7466
# Generation: 550. 正答率(トレーニング) = 1.0
#                 : 550. 正答率(テスト) = 0.7422
# Generation: 560. 正答率(トレーニング) = 1.0
#                 : 560. 正答率(テスト) = 0.745
# Generation: 570. 正答率(トレーニング) = 1.0
#                 : 570. 正答率(テスト) = 0.7456
# Generation: 580. 正答率(トレーニング) = 1.0
#                 : 580. 正答率(テスト) = 0.7425
# Generation: 590. 正答率(トレーニング) = 1.0
#                 : 590. 正答率(テスト) = 0.7444
# Generation: 600. 正答率(トレーニング) = 1.0
#                 : 600. 正答率(テスト) = 0.7456
# Generation: 610. 正答率(トレーニング) = 1.0
#                 : 610. 正答率(テスト) = 0.744
# Generation: 620. 正答率(トレーニング) = 1.0
#                 : 620. 正答率(テスト) = 0.7465
# Generation: 630. 正答率(トレーニング) = 1.0
#                 : 630. 正答率(テスト) = 0.7434
# Generation: 640. 正答率(トレーニング) = 1.0
#                 : 640. 正答率(テスト) = 0.7444
# Generation: 650. 正答率(トレーニング) = 1.0
#                 : 650. 正答率(テスト) = 0.7471
# Generation: 660. 正答率(トレーニング) = 1.0
#                 : 660. 正答率(テスト) = 0.746
# Generation: 670. 正答率(トレーニング) = 1.0
#                 : 670. 正答率(テスト) = 0.745
# Generation: 680. 正答率(トレーニング) = 1.0
#                 : 680. 正答率(テスト) = 0.7479
# Generation: 690. 正答率(トレーニング) = 1.0
#                 : 690. 正答率(テスト) = 0.747
# Generation: 700. 正答率(トレーニング) = 1.0
#                 : 700. 正答率(テスト) = 0.7483
# Generation: 710. 正答率(トレーニング) = 1.0
#                 : 710. 正答率(テスト) = 0.7465
# Generation: 720. 正答率(トレーニング) = 1.0
#                 : 720. 正答率(テスト) = 0.7486
# Generation: 730. 正答率(トレーニング) = 1.0
#                 : 730. 正答率(テスト) = 0.7482
# Generation: 740. 正答率(トレーニング) = 1.0
#                 : 740. 正答率(テスト) = 0.7469
# Generation: 750. 正答率(トレーニング) = 1.0
#                 : 750. 正答率(テスト) = 0.7471
# Generation: 760. 正答率(トレーニング) = 1.0
#                 : 760. 正答率(テスト) = 0.747
# Generation: 770. 正答率(トレーニング) = 1.0
#                 : 770. 正答率(テスト) = 0.7466
# Generation: 780. 正答率(トレーニング) = 1.0
#                 : 780. 正答率(テスト) = 0.7475
# Generation: 790. 正答率(トレーニング) = 1.0
#                 : 790. 正答率(テスト) = 0.7488
# Generation: 800. 正答率(トレーニング) = 1.0
#                 : 800. 正答率(テスト) = 0.7468
# Generation: 810. 正答率(トレーニング) = 1.0
#                 : 810. 正答率(テスト) = 0.7478
# Generation: 820. 正答率(トレーニング) = 1.0
#                 : 820. 正答率(テスト) = 0.7484
# Generation: 830. 正答率(トレーニング) = 1.0
#                 : 830. 正答率(テスト) = 0.7481
# Generation: 840. 正答率(トレーニング) = 1.0
#                 : 840. 正答率(テスト) = 0.7478
# Generation: 850. 正答率(トレーニング) = 1.0
#                 : 850. 正答率(テスト) = 0.7476
# Generation: 860. 正答率(トレーニング) = 1.0
#                 : 860. 正答率(テスト) = 0.7474
# Generation: 870. 正答率(トレーニング) = 1.0
#                 : 870. 正答率(テスト) = 0.7476
# Generation: 880. 正答率(トレーニング) = 1.0
#                 : 880. 正答率(テスト) = 0.7466
# Generation: 890. 正答率(トレーニング) = 1.0
#                 : 890. 正答率(テスト) = 0.7467
# Generation: 900. 正答率(トレーニング) = 1.0
#                 : 900. 正答率(テスト) = 0.7484
# Generation: 910. 正答率(トレーニング) = 1.0
#                 : 910. 正答率(テスト) = 0.749
# Generation: 920. 正答率(トレーニング) = 1.0
#                 : 920. 正答率(テスト) = 0.7483
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.7498
# Generation: 940. 正答率(トレーニング) = 1.0
#                 : 940. 正答率(テスト) = 0.7492
# Generation: 950. 正答率(トレーニング) = 1.0
#                 : 950. 正答率(テスト) = 0.7479
# Generation: 960. 正答率(トレーニング) = 1.0
#                 : 960. 正答率(テスト) = 0.7491
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.749
# Generation: 980. 正答率(トレーニング) = 1.0
#                 : 980. 正答率(テスト) = 0.7495
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.75
# Generation: 1000. 正答率(トレーニング) = 1.0
#                 : 1000. 正答率(テスト) = 0.7489

# %% [markdown]
# ## weight decay
# ### L2

# %%
from common import optimizer

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]


network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10
hidden_layer_num = network.hidden_layer_num

# 正則化強度設定 ======================================
weight_decay_lambda = 0.1
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * network.params['W' + str(idx)]
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += 0.5 * weight_decay_lambda * np.sqrt(np.sum(network.params['W' + str(idx)] ** 2))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15666666666666668
#                 : 10. 正答率(テスト) = 0.1055
# Generation: 20. 正答率(トレーニング) = 0.24
#                 : 20. 正答率(テスト) = 0.1615
# Generation: 30. 正答率(トレーニング) = 0.3233333333333333
#                 : 30. 正答率(テスト) = 0.2153
# Generation: 40. 正答率(トレーニング) = 0.37333333333333335
#                 : 40. 正答率(テスト) = 0.2621
# Generation: 50. 正答率(トレーニング) = 0.45
#                 : 50. 正答率(テスト) = 0.3017
# Generation: 60. 正答率(トレーニング) = 0.5033333333333333
#                 : 60. 正答率(テスト) = 0.3441
# Generation: 70. 正答率(トレーニング) = 0.5733333333333334
#                 : 70. 正答率(テスト) = 0.3838
# Generation: 80. 正答率(トレーニング) = 0.61
#                 : 80. 正答率(テスト) = 0.4113
# Generation: 90. 正答率(トレーニング) = 0.65
#                 : 90. 正答率(テスト) = 0.4496
# Generation: 100. 正答率(トレーニング) = 0.6533333333333333
#                 : 100. 正答率(テスト) = 0.4619
# Generation: 110. 正答率(トレーニング) = 0.6966666666666667
#                 : 110. 正答率(テスト) = 0.4851
# Generation: 120. 正答率(トレーニング) = 0.7266666666666667
#                 : 120. 正答率(テスト) = 0.5138
# Generation: 130. 正答率(トレーニング) = 0.7366666666666667
#                 : 130. 正答率(テスト) = 0.5336
# Generation: 140. 正答率(トレーニング) = 0.74
#                 : 140. 正答率(テスト) = 0.5629
# Generation: 150. 正答率(トレーニング) = 0.7733333333333333
#                 : 150. 正答率(テスト) = 0.5818
# Generation: 160. 正答率(トレーニング) = 0.7833333333333333
#                 : 160. 正答率(テスト) = 0.5964
# Generation: 170. 正答率(トレーニング) = 0.7866666666666666
#                 : 170. 正答率(テスト) = 0.6039
# Generation: 180. 正答率(トレーニング) = 0.8
#                 : 180. 正答率(テスト) = 0.6139
# Generation: 190. 正答率(トレーニング) = 0.7966666666666666
#                 : 190. 正答率(テスト) = 0.6278
# Generation: 200. 正答率(トレーニング) = 0.7966666666666666
#                 : 200. 正答率(テスト) = 0.6288
# Generation: 210. 正答率(トレーニング) = 0.81
#                 : 210. 正答率(テスト) = 0.6363
# Generation: 220. 正答率(トレーニング) = 0.8166666666666667
#                 : 220. 正答率(テスト) = 0.6412
# Generation: 230. 正答率(トレーニング) = 0.8133333333333334
#                 : 230. 正答率(テスト) = 0.6504
# Generation: 240. 正答率(トレーニング) = 0.8266666666666667
#                 : 240. 正答率(テスト) = 0.6637
# Generation: 250. 正答率(トレーニング) = 0.8266666666666667
#                 : 250. 正答率(テスト) = 0.6543
# Generation: 260. 正答率(トレーニング) = 0.8366666666666667
#                 : 260. 正答率(テスト) = 0.664
# Generation: 270. 正答率(トレーニング) = 0.86
#                 : 270. 正答率(テスト) = 0.6737
# Generation: 280. 正答率(トレーニング) = 0.8433333333333334
#                 : 280. 正答率(テスト) = 0.6751
# Generation: 290. 正答率(トレーニング) = 0.86
#                 : 290. 正答率(テスト) = 0.6781
# Generation: 300. 正答率(トレーニング) = 0.8666666666666667
#                 : 300. 正答率(テスト) = 0.6774
# Generation: 310. 正答率(トレーニング) = 0.8633333333333333
#                 : 310. 正答率(テスト) = 0.6832
# Generation: 320. 正答率(トレーニング) = 0.8833333333333333
#                 : 320. 正答率(テスト) = 0.6933
# Generation: 330. 正答率(トレーニング) = 0.89
#                 : 330. 正答率(テスト) = 0.6912
# Generation: 340. 正答率(トレーニング) = 0.8866666666666667
#                 : 340. 正答率(テスト) = 0.6867
# Generation: 350. 正答率(トレーニング) = 0.8933333333333333
#                 : 350. 正答率(テスト) = 0.6989
# Generation: 360. 正答率(トレーニング) = 0.8966666666666666
#                 : 360. 正答率(テスト) = 0.7054
# Generation: 370. 正答率(トレーニング) = 0.8866666666666667
#                 : 370. 正答率(テスト) = 0.7084
# Generation: 380. 正答率(トレーニング) = 0.8966666666666666
#                 : 380. 正答率(テスト) = 0.7053
# Generation: 390. 正答率(トレーニング) = 0.8966666666666666
#                 : 390. 正答率(テスト) = 0.7082
# Generation: 400. 正答率(トレーニング) = 0.8966666666666666
#                 : 400. 正答率(テスト) = 0.7124
# Generation: 410. 正答率(トレーニング) = 0.9
#                 : 410. 正答率(テスト) = 0.7006
# Generation: 420. 正答率(トレーニング) = 0.9033333333333333
#                 : 420. 正答率(テスト) = 0.7106
# Generation: 430. 正答率(トレーニング) = 0.9
#                 : 430. 正答率(テスト) = 0.7121
# Generation: 440. 正答率(トレーニング) = 0.89
#                 : 440. 正答率(テスト) = 0.7045
# Generation: 450. 正答率(トレーニング) = 0.8933333333333333
#                 : 450. 正答率(テスト) = 0.7077
# Generation: 460. 正答率(トレーニング) = 0.9
#                 : 460. 正答率(テスト) = 0.714
# Generation: 470. 正答率(トレーニング) = 0.9
#                 : 470. 正答率(テスト) = 0.7103
# Generation: 480. 正答率(トレーニング) = 0.91
#                 : 480. 正答率(テスト) = 0.7095
# Generation: 490. 正答率(トレーニング) = 0.8966666666666666
#                 : 490. 正答率(テスト) = 0.7042
# Generation: 500. 正答率(トレーニング) = 0.9
#                 : 500. 正答率(テスト) = 0.7161
# Generation: 510. 正答率(トレーニング) = 0.9
#                 : 510. 正答率(テスト) = 0.7156
# Generation: 520. 正答率(トレーニング) = 0.9066666666666666
#                 : 520. 正答率(テスト) = 0.7153
# Generation: 530. 正答率(トレーニング) = 0.9033333333333333
#                 : 530. 正答率(テスト) = 0.7197
# Generation: 540. 正答率(トレーニング) = 0.8833333333333333
#                 : 540. 正答率(テスト) = 0.705
# Generation: 550. 正答率(トレーニング) = 0.9033333333333333
#                 : 550. 正答率(テスト) = 0.7196
# Generation: 560. 正答率(トレーニング) = 0.9
#                 : 560. 正答率(テスト) = 0.7102
# Generation: 570. 正答率(トレーニング) = 0.9133333333333333
#                 : 570. 正答率(テスト) = 0.7227
# Generation: 580. 正答率(トレーニング) = 0.91
#                 : 580. 正答率(テスト) = 0.7182
# Generation: 590. 正答率(トレーニング) = 0.9133333333333333
#                 : 590. 正答率(テスト) = 0.7131
# Generation: 600. 正答率(トレーニング) = 0.9066666666666666
#                 : 600. 正答率(テスト) = 0.7231
# Generation: 610. 正答率(トレーニング) = 0.9033333333333333
#                 : 610. 正答率(テスト) = 0.7178
# Generation: 620. 正答率(トレーニング) = 0.8933333333333333
#                 : 620. 正答率(テスト) = 0.7081
# Generation: 630. 正答率(トレーニング) = 0.91
#                 : 630. 正答率(テスト) = 0.7187
# Generation: 640. 正答率(トレーニング) = 0.9
#                 : 640. 正答率(テスト) = 0.7148
# Generation: 650. 正答率(トレーニング) = 0.9133333333333333
#                 : 650. 正答率(テスト) = 0.7258
# Generation: 660. 正答率(トレーニング) = 0.91
#                 : 660. 正答率(テスト) = 0.7144
# Generation: 670. 正答率(トレーニング) = 0.92
#                 : 670. 正答率(テスト) = 0.7291
# Generation: 680. 正答率(トレーニング) = 0.9066666666666666
#                 : 680. 正答率(テスト) = 0.7226
# Generation: 690. 正答率(トレーニング) = 0.8966666666666666
#                 : 690. 正答率(テスト) = 0.7177
# Generation: 700. 正答率(トレーニング) = 0.9033333333333333
#                 : 700. 正答率(テスト) = 0.7185
# Generation: 710. 正答率(トレーニング) = 0.91
#                 : 710. 正答率(テスト) = 0.7214
# Generation: 720. 正答率(トレーニング) = 0.9133333333333333
#                 : 720. 正答率(テスト) = 0.7262
# Generation: 730. 正答率(トレーニング) = 0.9
#                 : 730. 正答率(テスト) = 0.7126
# Generation: 740. 正答率(トレーニング) = 0.8933333333333333
#                 : 740. 正答率(テスト) = 0.719
# Generation: 750. 正答率(トレーニング) = 0.92
#                 : 750. 正答率(テスト) = 0.7296
# Generation: 760. 正答率(トレーニング) = 0.91
#                 : 760. 正答率(テスト) = 0.7221
# Generation: 770. 正答率(トレーニング) = 0.9
#                 : 770. 正答率(テスト) = 0.7125
# Generation: 780. 正答率(トレーニング) = 0.8933333333333333
#                 : 780. 正答率(テスト) = 0.7158
# Generation: 790. 正答率(トレーニング) = 0.8966666666666666
#                 : 790. 正答率(テスト) = 0.7142
# Generation: 800. 正答率(トレーニング) = 0.91
#                 : 800. 正答率(テスト) = 0.7234
# Generation: 810. 正答率(トレーニング) = 0.9
#                 : 810. 正答率(テスト) = 0.718
# Generation: 820. 正答率(トレーニング) = 0.9033333333333333
#                 : 820. 正答率(テスト) = 0.7165
# Generation: 830. 正答率(トレーニング) = 0.9066666666666666
#                 : 830. 正答率(テスト) = 0.7237
# Generation: 840. 正答率(トレーニング) = 0.91
#                 : 840. 正答率(テスト) = 0.718
# Generation: 850. 正答率(トレーニング) = 0.9066666666666666
#                 : 850. 正答率(テスト) = 0.7222
# Generation: 860. 正答率(トレーニング) = 0.9066666666666666
#                 : 860. 正答率(テスト) = 0.722
# Generation: 870. 正答率(トレーニング) = 0.9
#                 : 870. 正答率(テスト) = 0.7125
# Generation: 880. 正答率(トレーニング) = 0.91
#                 : 880. 正答率(テスト) = 0.7179
# Generation: 890. 正答率(トレーニング) = 0.91
#                 : 890. 正答率(テスト) = 0.7192
# Generation: 900. 正答率(トレーニング) = 0.9133333333333333
#                 : 900. 正答率(テスト) = 0.7226
# Generation: 910. 正答率(トレーニング) = 0.9133333333333333
#                 : 910. 正答率(テスト) = 0.7252
# Generation: 920. 正答率(トレーニング) = 0.9
#                 : 920. 正答率(テスト) = 0.7158
# Generation: 930. 正答率(トレーニング) = 0.9
#                 : 930. 正答率(テスト) = 0.7123
# Generation: 940. 正答率(トレーニング) = 0.9033333333333333
#                 : 940. 正答率(テスト) = 0.7139
# Generation: 950. 正答率(トレーニング) = 0.9033333333333333
#                 : 950. 正答率(テスト) = 0.7113
# Generation: 960. 正答率(トレーニング) = 0.9033333333333333
#                 : 960. 正答率(テスト) = 0.7195
# Generation: 970. 正答率(トレーニング) = 0.89
#                 : 970. 正答率(テスト) = 0.7115
# Generation: 980. 正答率(トレーニング) = 0.9066666666666666
#                 : 980. 正答率(テスト) = 0.7119
# Generation: 990. 正答率(トレーニング) = 0.9066666666666666
#                 : 990. 正答率(テスト) = 0.7134
# Generation: 1000. 正答率(トレーニング) = 0.9033333333333333
#                 : 1000. 正答率(テスト) = 0.7119

# %% [markdown]
# ### L1

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10
hidden_layer_num = network.hidden_layer_num

# 正則化強度設定 ======================================
weight_decay_lambda = 0.005
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * np.sign(network.params['W' + str(idx)])
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += weight_decay_lambda * np.sum(np.abs(network.params['W' + str(idx)]))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               
                
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.55
#                 : 10. 正答率(テスト) = 0.3834
# Generation: 20. 正答率(トレーニング) = 0.23
#                 : 20. 正答率(テスト) = 0.2214
# Generation: 30. 正答率(トレーニング) = 0.72
#                 : 30. 正答率(テスト) = 0.5211
# Generation: 40. 正答率(トレーニング) = 0.6366666666666667
#                 : 40. 正答率(テスト) = 0.5524
# Generation: 50. 正答率(トレーニング) = 0.8466666666666667
#                 : 50. 正答率(テスト) = 0.6615
# Generation: 60. 正答率(トレーニング) = 0.8933333333333333
#                 : 60. 正答率(テスト) = 0.7249
# Generation: 70. 正答率(トレーニング) = 0.72
#                 : 70. 正答率(テスト) = 0.5919
# Generation: 80. 正答率(トレーニング) = 0.8866666666666667
#                 : 80. 正答率(テスト) = 0.7279
# Generation: 90. 正答率(トレーニング) = 0.91
#                 : 90. 正答率(テスト) = 0.7567
# Generation: 100. 正答率(トレーニング) = 0.77
#                 : 100. 正答率(テスト) = 0.6047
# Generation: 110. 正答率(トレーニング) = 0.8833333333333333
#                 : 110. 正答率(テスト) = 0.6827
# Generation: 120. 正答率(トレーニング) = 0.9
#                 : 120. 正答率(テスト) = 0.7365
# Generation: 130. 正答率(トレーニング) = 0.61
#                 : 130. 正答率(テスト) = 0.4971
# Generation: 140. 正答率(トレーニング) = 0.92
#                 : 140. 正答率(テスト) = 0.7398
# Generation: 150. 正答率(トレーニング) = 0.8266666666666667
#                 : 150. 正答率(テスト) = 0.6529
# Generation: 160. 正答率(トレーニング) = 0.8766666666666667
#                 : 160. 正答率(テスト) = 0.6364
# Generation: 170. 正答率(トレーニング) = 0.87
#                 : 170. 正答率(テスト) = 0.7026
# Generation: 180. 正答率(トレーニング) = 0.92
#                 : 180. 正答率(テスト) = 0.7252
# Generation: 190. 正答率(トレーニング) = 0.9066666666666666
#                 : 190. 正答率(テスト) = 0.7217
# Generation: 200. 正答率(トレーニング) = 0.8333333333333334
#                 : 200. 正答率(テスト) = 0.6806
# Generation: 210. 正答率(トレーニング) = 0.6633333333333333
#                 : 210. 正答率(テスト) = 0.5464
# Generation: 220. 正答率(トレーニング) = 0.61
#                 : 220. 正答率(テスト) = 0.4896
# Generation: 230. 正答率(トレーニング) = 0.56
#                 : 230. 正答率(テスト) = 0.4889
# Generation: 240. 正答率(トレーニング) = 0.5033333333333333
#                 : 240. 正答率(テスト) = 0.4116
# Generation: 250. 正答率(トレーニング) = 0.91
#                 : 250. 正答率(テスト) = 0.7118
# Generation: 260. 正答率(トレーニング) = 0.8666666666666667
#                 : 260. 正答率(テスト) = 0.7044
# Generation: 270. 正答率(トレーニング) = 0.9166666666666666
#                 : 270. 正答率(テスト) = 0.735
# Generation: 280. 正答率(トレーニング) = 0.89
#                 : 280. 正答率(テスト) = 0.6931
# Generation: 290. 正答率(トレーニング) = 0.9066666666666666
#                 : 290. 正答率(テスト) = 0.7093
# Generation: 300. 正答率(トレーニング) = 0.9233333333333333
#                 : 300. 正答率(テスト) = 0.7199
# Generation: 310. 正答率(トレーニング) = 0.9133333333333333
#                 : 310. 正答率(テスト) = 0.7121
# Generation: 320. 正答率(トレーニング) = 0.9166666666666666
#                 : 320. 正答率(テスト) = 0.7134
# Generation: 330. 正答率(トレーニング) = 0.8666666666666667
#                 : 330. 正答率(テスト) = 0.6609
# Generation: 340. 正答率(トレーニング) = 0.6366666666666667
#                 : 340. 正答率(テスト) = 0.5274
# Generation: 350. 正答率(トレーニング) = 0.6266666666666667
#                 : 350. 正答率(テスト) = 0.5082
# Generation: 360. 正答率(トレーニング) = 0.9033333333333333
#                 : 360. 正答率(テスト) = 0.7054
# Generation: 370. 正答率(トレーニング) = 0.8766666666666667
#                 : 370. 正答率(テスト) = 0.7008
# Generation: 380. 正答率(トレーニング) = 0.7333333333333333
#                 : 380. 正答率(テスト) = 0.548
# Generation: 390. 正答率(トレーニング) = 0.8866666666666667
#                 : 390. 正答率(テスト) = 0.6853
# Generation: 400. 正答率(トレーニング) = 0.8566666666666667
#                 : 400. 正答率(テスト) = 0.6721
# Generation: 410. 正答率(トレーニング) = 0.8433333333333334
#                 : 410. 正答率(テスト) = 0.6252
# Generation: 420. 正答率(トレーニング) = 0.9366666666666666
#                 : 420. 正答率(テスト) = 0.7396
# Generation: 430. 正答率(トレーニング) = 0.8833333333333333
#                 : 430. 正答率(テスト) = 0.6634
# Generation: 440. 正答率(トレーニング) = 0.9366666666666666
#                 : 440. 正答率(テスト) = 0.7301
# Generation: 450. 正答率(トレーニング) = 0.8633333333333333
#                 : 450. 正答率(テスト) = 0.6525
# Generation: 460. 正答率(トレーニング) = 0.9
#                 : 460. 正答率(テスト) = 0.6898
# Generation: 470. 正答率(トレーニング) = 0.83
#                 : 470. 正答率(テスト) = 0.6418
# Generation: 480. 正答率(トレーニング) = 0.5166666666666667
#                 : 480. 正答率(テスト) = 0.4243
# Generation: 490. 正答率(トレーニング) = 0.9433333333333334
#                 : 490. 正答率(テスト) = 0.718
# Generation: 500. 正答率(トレーニング) = 0.93
#                 : 500. 正答率(テスト) = 0.7142
# Generation: 510. 正答率(トレーニング) = 0.7033333333333334
#                 : 510. 正答率(テスト) = 0.5435
# Generation: 520. 正答率(トレーニング) = 0.92
#                 : 520. 正答率(テスト) = 0.6918
# Generation: 530. 正答率(トレーニング) = 0.8433333333333334
#                 : 530. 正答率(テスト) = 0.6249
# Generation: 540. 正答率(トレーニング) = 0.9533333333333334
#                 : 540. 正答率(テスト) = 0.706
# Generation: 550. 正答率(トレーニング) = 0.95
#                 : 550. 正答率(テスト) = 0.7238
# Generation: 560. 正答率(トレーニング) = 0.8866666666666667
#                 : 560. 正答率(テスト) = 0.686
# Generation: 570. 正答率(トレーニング) = 0.9533333333333334
#                 : 570. 正答率(テスト) = 0.7253
# Generation: 580. 正答率(トレーニング) = 0.8566666666666667
#                 : 580. 正答率(テスト) = 0.6488
# Generation: 590. 正答率(トレーニング) = 0.9433333333333334
#                 : 590. 正答率(テスト) = 0.7178
# Generation: 600. 正答率(トレーニング) = 0.6733333333333333
#                 : 600. 正答率(テスト) = 0.5273
# Generation: 610. 正答率(トレーニング) = 0.9366666666666666
#                 : 610. 正答率(テスト) = 0.6922
# Generation: 620. 正答率(トレーニング) = 0.91
#                 : 620. 正答率(テスト) = 0.6944
# Generation: 630. 正答率(トレーニング) = 0.96
#                 : 630. 正答率(テスト) = 0.7323
# Generation: 640. 正答率(トレーニング) = 0.9633333333333334
#                 : 640. 正答率(テスト) = 0.727
# Generation: 650. 正答率(トレーニング) = 0.97
#                 : 650. 正答率(テスト) = 0.7248
# Generation: 660. 正答率(トレーニング) = 0.9333333333333333
#                 : 660. 正答率(テスト) = 0.7046
# Generation: 670. 正答率(トレーニング) = 0.9433333333333334
#                 : 670. 正答率(テスト) = 0.7073
# Generation: 680. 正答率(トレーニング) = 0.9666666666666667
#                 : 680. 正答率(テスト) = 0.728
# Generation: 690. 正答率(トレーニング) = 0.91
#                 : 690. 正答率(テスト) = 0.6564
# Generation: 700. 正答率(トレーニング) = 0.9733333333333334
#                 : 700. 正答率(テスト) = 0.7289
# Generation: 710. 正答率(トレーニング) = 0.6066666666666667
#                 : 710. 正答率(テスト) = 0.4828
# Generation: 720. 正答率(トレーニング) = 0.9733333333333334
#                 : 720. 正答率(テスト) = 0.725
# Generation: 730. 正答率(トレーニング) = 0.5833333333333334
#                 : 730. 正答率(テスト) = 0.4717
# Generation: 740. 正答率(トレーニング) = 0.97
#                 : 740. 正答率(テスト) = 0.7257
# Generation: 750. 正答率(トレーニング) = 0.9666666666666667
#                 : 750. 正答率(テスト) = 0.6971
# Generation: 760. 正答率(トレーニング) = 0.95
#                 : 760. 正答率(テスト) = 0.6854
# Generation: 770. 正答率(トレーニング) = 0.9433333333333334
#                 : 770. 正答率(テスト) = 0.6843
# Generation: 780. 正答率(トレーニング) = 0.9666666666666667
#                 : 780. 正答率(テスト) = 0.7135
# Generation: 790. 正答率(トレーニング) = 0.9833333333333333
#                 : 790. 正答率(テスト) = 0.7205
# Generation: 800. 正答率(トレーニング) = 0.9666666666666667
#                 : 800. 正答率(テスト) = 0.7027
# Generation: 810. 正答率(トレーニング) = 0.98
#                 : 810. 正答率(テスト) = 0.7248
# Generation: 820. 正答率(トレーニング) = 0.98
#                 : 820. 正答率(テスト) = 0.7232
# Generation: 830. 正答率(トレーニング) = 0.4033333333333333
#                 : 830. 正答率(テスト) = 0.332
# Generation: 840. 正答率(トレーニング) = 0.8266666666666667
#                 : 840. 正答率(テスト) = 0.5989
# Generation: 850. 正答率(トレーニング) = 0.91
#                 : 850. 正答率(テスト) = 0.6449
# Generation: 860. 正答率(トレーニング) = 0.91
#                 : 860. 正答率(テスト) = 0.668
# Generation: 870. 正答率(トレーニング) = 0.97
#                 : 870. 正答率(テスト) = 0.7082
# Generation: 880. 正答率(トレーニング) = 0.24
#                 : 880. 正答率(テスト) = 0.2249
# Generation: 890. 正答率(トレーニング) = 0.6733333333333333
#                 : 890. 正答率(テスト) = 0.5149
# Generation: 900. 正答率(トレーニング) = 0.82
#                 : 900. 正答率(テスト) = 0.5977
# Generation: 910. 正答率(トレーニング) = 0.8533333333333334
#                 : 910. 正答率(テスト) = 0.611
# Generation: 920. 正答率(トレーニング) = 0.73
#                 : 920. 正答率(テスト) = 0.5527
# Generation: 930. 正答率(トレーニング) = 0.8666666666666667
#                 : 930. 正答率(テスト) = 0.6629
# Generation: 940. 正答率(トレーニング) = 0.9333333333333333
#                 : 940. 正答率(テスト) = 0.691
# Generation: 950. 正答率(トレーニング) = 0.8433333333333334
#                 : 950. 正答率(テスト) = 0.6196
# Generation: 960. 正答率(トレーニング) = 0.93
#                 : 960. 正答率(テスト) = 0.6739
# Generation: 970. 正答率(トレーニング) = 0.61
#                 : 970. 正答率(テスト) = 0.4331
# Generation: 980. 正答率(トレーニング) = 0.97
#                 : 980. 正答率(テスト) = 0.7066
# Generation: 990. 正答率(トレーニング) = 0.74
#                 : 990. 正答率(テスト) = 0.5933
# Generation: 1000. 正答率(トレーニング) = 0.97
#                 : 1000. 正答率(テスト) = 0.7049

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------
# ## [try] weigth_decay_lambdaの値を変更して正則化の強さを確認しよう
# ----------------------------------------------------------------------------------------------------------------------------------------

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10
hidden_layer_num = network.hidden_layer_num

# 正則化強度設定 ======================================
weight_decay_lambda = 0.5
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * np.sign(network.params['W' + str(idx)])
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += weight_decay_lambda * np.sum(np.abs(network.params['W' + str(idx)]))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               
                
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.11333333333333333
#                 : 10. 正答率(テスト) = 0.101
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.13
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.13
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.13
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.13
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.13
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.13
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.13
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.13
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.13
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.13
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.13
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.13
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.13
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.13
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.13
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.13
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.13
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.13
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.13
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.13
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.13
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.13
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.13
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.13
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.13
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.13
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.13
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.13
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.13
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.13
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.13
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.13
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.13
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.13
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.13
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.13
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.13
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.13
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.13
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.13
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.13
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.13
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.13
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.13
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.13
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.13
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.13
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.13
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.13
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.13
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.13
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.13
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.13
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.13
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.13
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.13
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.13
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.13
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.13
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.13
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.13
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.13
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.13
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.13
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.13
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.13
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.13
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.13
#                 : 710. 正答率(テスト) = 0.1135
# Generation: 720. 正答率(トレーニング) = 0.13
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.13
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.13
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.13
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.13
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.13
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.13
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.13
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.13
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.13
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.13
#                 : 820. 正答率(テスト) = 0.1135
# Generation: 830. 正答率(トレーニング) = 0.13
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.13
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.13
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.13
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.13
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.13
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.13
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.13
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.13
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.13
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.13
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.13
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.13
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.13
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.13
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.13
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.13
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.13
#                 : 1000. 正答率(テスト) = 0.1135

# %% [markdown]
# weight_decay_lambdaを100倍に(0.005->0.5)
# 正則化が強すぎて学習が全く進まない

# %% [markdown]
# ## Dropout

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.15
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda, use_dropout = use_dropout, dropout_ratio = dropout_ratio)
optimizer = optimizer.SGD(learning_rate=0.01)
# optimizer = optimizer.Momentum(learning_rate=0.01, momentum=0.9)
# optimizer = optimizer.AdaGrad(learning_rate=0.01)
# optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)    
    
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.10333333333333333
#                 : 10. 正答率(テスト) = 0.1066
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1167
# Generation: 30. 正答率(トレーニング) = 0.16
#                 : 30. 正答率(テスト) = 0.1317
# Generation: 40. 正答率(トレーニング) = 0.18333333333333332
#                 : 40. 正答率(テスト) = 0.1535
# Generation: 50. 正答率(トレーニング) = 0.19666666666666666
#                 : 50. 正答率(テスト) = 0.1708
# Generation: 60. 正答率(トレーニング) = 0.2
#                 : 60. 正答率(テスト) = 0.1804
# Generation: 70. 正答率(トレーニング) = 0.22333333333333333
#                 : 70. 正答率(テスト) = 0.1975
# Generation: 80. 正答率(トレーニング) = 0.25
#                 : 80. 正答率(テスト) = 0.2185
# Generation: 90. 正答率(トレーニング) = 0.28
#                 : 90. 正答率(テスト) = 0.2382
# Generation: 100. 正答率(トレーニング) = 0.30333333333333334
#                 : 100. 正答率(テスト) = 0.2519
# Generation: 110. 正答率(トレーニング) = 0.33666666666666667
#                 : 110. 正答率(テスト) = 0.2653
# Generation: 120. 正答率(トレーニング) = 0.34
#                 : 120. 正答率(テスト) = 0.268
# Generation: 130. 正答率(トレーニング) = 0.34
#                 : 130. 正答率(テスト) = 0.266
# Generation: 140. 正答率(トレーニング) = 0.35
#                 : 140. 正答率(テスト) = 0.2691
# Generation: 150. 正答率(トレーニング) = 0.38333333333333336
#                 : 150. 正答率(テスト) = 0.2822
# Generation: 160. 正答率(トレーニング) = 0.39
#                 : 160. 正答率(テスト) = 0.2961
# Generation: 170. 正答率(トレーニング) = 0.41
#                 : 170. 正答率(テスト) = 0.3109
# Generation: 180. 正答率(トレーニング) = 0.43333333333333335
#                 : 180. 正答率(テスト) = 0.3246
# Generation: 190. 正答率(トレーニング) = 0.4266666666666667
#                 : 190. 正答率(テスト) = 0.3218
# Generation: 200. 正答率(トレーニング) = 0.43333333333333335
#                 : 200. 正答率(テスト) = 0.3273
# Generation: 210. 正答率(トレーニング) = 0.4266666666666667
#                 : 210. 正答率(テスト) = 0.328
# Generation: 220. 正答率(トレーニング) = 0.4266666666666667
#                 : 220. 正答率(テスト) = 0.3242
# Generation: 230. 正答率(トレーニング) = 0.43666666666666665
#                 : 230. 正答率(テスト) = 0.3384
# Generation: 240. 正答率(トレーニング) = 0.4633333333333333
#                 : 240. 正答率(テスト) = 0.3447
# Generation: 250. 正答率(トレーニング) = 0.4766666666666667
#                 : 250. 正答率(テスト) = 0.3527
# Generation: 260. 正答率(トレーニング) = 0.4666666666666667
#                 : 260. 正答率(テスト) = 0.3591
# Generation: 270. 正答率(トレーニング) = 0.48
#                 : 270. 正答率(テスト) = 0.3719
# Generation: 280. 正答率(トレーニング) = 0.46
#                 : 280. 正答率(テスト) = 0.3639
# Generation: 290. 正答率(トレーニング) = 0.4633333333333333
#                 : 290. 正答率(テスト) = 0.3783
# Generation: 300. 正答率(トレーニング) = 0.49
#                 : 300. 正答率(テスト) = 0.4033
# Generation: 310. 正答率(トレーニング) = 0.4866666666666667
#                 : 310. 正答率(テスト) = 0.4067
# Generation: 320. 正答率(トレーニング) = 0.51
#                 : 320. 正答率(テスト) = 0.4244
# Generation: 330. 正答率(トレーニング) = 0.54
#                 : 330. 正答率(テスト) = 0.4344
# Generation: 340. 正答率(トレーニング) = 0.5233333333333333
#                 : 340. 正答率(テスト) = 0.4388
# Generation: 350. 正答率(トレーニング) = 0.5233333333333333
#                 : 350. 正答率(テスト) = 0.4385
# Generation: 360. 正答率(トレーニング) = 0.5233333333333333
#                 : 360. 正答率(テスト) = 0.4411
# Generation: 370. 正答率(トレーニング) = 0.53
#                 : 370. 正答率(テスト) = 0.4483
# Generation: 380. 正答率(トレーニング) = 0.5333333333333333
#                 : 380. 正答率(テスト) = 0.4511
# Generation: 390. 正答率(トレーニング) = 0.54
#                 : 390. 正答率(テスト) = 0.4549
# Generation: 400. 正答率(トレーニング) = 0.5366666666666666
#                 : 400. 正答率(テスト) = 0.4571
# Generation: 410. 正答率(トレーニング) = 0.54
#                 : 410. 正答率(テスト) = 0.4581
# Generation: 420. 正答率(トレーニング) = 0.5333333333333333
#                 : 420. 正答率(テスト) = 0.4543
# Generation: 430. 正答率(トレーニング) = 0.5466666666666666
#                 : 430. 正答率(テスト) = 0.4601
# Generation: 440. 正答率(トレーニング) = 0.5633333333333334
#                 : 440. 正答率(テスト) = 0.4752
# Generation: 450. 正答率(トレーニング) = 0.5766666666666667
#                 : 450. 正答率(テスト) = 0.4655
# Generation: 460. 正答率(トレーニング) = 0.59
#                 : 460. 正答率(テスト) = 0.4829
# Generation: 470. 正答率(トレーニング) = 0.6066666666666667
#                 : 470. 正答率(テスト) = 0.4926
# Generation: 480. 正答率(トレーニング) = 0.6366666666666667
#                 : 480. 正答率(テスト) = 0.5068
# Generation: 490. 正答率(トレーニング) = 0.6266666666666667
#                 : 490. 正答率(テスト) = 0.5095
# Generation: 500. 正答率(トレーニング) = 0.6766666666666666
#                 : 500. 正答率(テスト) = 0.5347
# Generation: 510. 正答率(トレーニング) = 0.6933333333333334
#                 : 510. 正答率(テスト) = 0.543
# Generation: 520. 正答率(トレーニング) = 0.73
#                 : 520. 正答率(テスト) = 0.5581
# Generation: 530. 正答率(トレーニング) = 0.7266666666666667
#                 : 530. 正答率(テスト) = 0.5582
# Generation: 540. 正答率(トレーニング) = 0.75
#                 : 540. 正答率(テスト) = 0.5714
# Generation: 550. 正答率(トレーニング) = 0.7366666666666667
#                 : 550. 正答率(テスト) = 0.5724
# Generation: 560. 正答率(トレーニング) = 0.74
#                 : 560. 正答率(テスト) = 0.5905
# Generation: 570. 正答率(トレーニング) = 0.77
#                 : 570. 正答率(テスト) = 0.6021
# Generation: 580. 正答率(トレーニング) = 0.7666666666666667
#                 : 580. 正答率(テスト) = 0.6142
# Generation: 590. 正答率(トレーニング) = 0.78
#                 : 590. 正答率(テスト) = 0.631
# Generation: 600. 正答率(トレーニング) = 0.7866666666666666
#                 : 600. 正答率(テスト) = 0.6292
# Generation: 610. 正答率(トレーニング) = 0.7733333333333333
#                 : 610. 正答率(テスト) = 0.6076
# Generation: 620. 正答率(トレーニング) = 0.7966666666666666
#                 : 620. 正答率(テスト) = 0.6237
# Generation: 630. 正答率(トレーニング) = 0.8066666666666666
#                 : 630. 正答率(テスト) = 0.642
# Generation: 640. 正答率(トレーニング) = 0.8
#                 : 640. 正答率(テスト) = 0.6354
# Generation: 650. 正答率(トレーニング) = 0.79
#                 : 650. 正答率(テスト) = 0.637
# Generation: 660. 正答率(トレーニング) = 0.76
#                 : 660. 正答率(テスト) = 0.6251
# Generation: 670. 正答率(トレーニング) = 0.8066666666666666
#                 : 670. 正答率(テスト) = 0.6365
# Generation: 680. 正答率(トレーニング) = 0.81
#                 : 680. 正答率(テスト) = 0.649
# Generation: 690. 正答率(トレーニング) = 0.8166666666666667
#                 : 690. 正答率(テスト) = 0.6487
# Generation: 700. 正答率(トレーニング) = 0.8333333333333334
#                 : 700. 正答率(テスト) = 0.6619
# Generation: 710. 正答率(トレーニング) = 0.8266666666666667
#                 : 710. 正答率(テスト) = 0.6624
# Generation: 720. 正答率(トレーニング) = 0.84
#                 : 720. 正答率(テスト) = 0.6724
# Generation: 730. 正答率(トレーニング) = 0.84
#                 : 730. 正答率(テスト) = 0.6843
# Generation: 740. 正答率(トレーニング) = 0.85
#                 : 740. 正答率(テスト) = 0.6932
# Generation: 750. 正答率(トレーニング) = 0.85
#                 : 750. 正答率(テスト) = 0.6959
# Generation: 760. 正答率(トレーニング) = 0.8466666666666667
#                 : 760. 正答率(テスト) = 0.6912
# Generation: 770. 正答率(トレーニング) = 0.8633333333333333
#                 : 770. 正答率(テスト) = 0.6871
# Generation: 780. 正答率(トレーニング) = 0.8466666666666667
#                 : 780. 正答率(テスト) = 0.6996
# Generation: 790. 正答率(トレーニング) = 0.85
#                 : 790. 正答率(テスト) = 0.7098
# Generation: 800. 正答率(トレーニング) = 0.86
#                 : 800. 正答率(テスト) = 0.6992
# Generation: 810. 正答率(トレーニング) = 0.8633333333333333
#                 : 810. 正答率(テスト) = 0.7043
# Generation: 820. 正答率(トレーニング) = 0.8533333333333334
#                 : 820. 正答率(テスト) = 0.7067
# Generation: 830. 正答率(トレーニング) = 0.88
#                 : 830. 正答率(テスト) = 0.7098
# Generation: 840. 正答率(トレーニング) = 0.8666666666666667
#                 : 840. 正答率(テスト) = 0.7078
# Generation: 850. 正答率(トレーニング) = 0.87
#                 : 850. 正答率(テスト) = 0.7132
# Generation: 860. 正答率(トレーニング) = 0.8566666666666667
#                 : 860. 正答率(テスト) = 0.7121
# Generation: 870. 正答率(トレーニング) = 0.87
#                 : 870. 正答率(テスト) = 0.7182
# Generation: 880. 正答率(トレーニング) = 0.8733333333333333
#                 : 880. 正答率(テスト) = 0.7195
# Generation: 890. 正答率(トレーニング) = 0.88
#                 : 890. 正答率(テスト) = 0.7252
# Generation: 900. 正答率(トレーニング) = 0.87
#                 : 900. 正答率(テスト) = 0.7211
# Generation: 910. 正答率(トレーニング) = 0.8866666666666667
#                 : 910. 正答率(テスト) = 0.7259
# Generation: 920. 正答率(トレーニング) = 0.89
#                 : 920. 正答率(テスト) = 0.7194
# Generation: 930. 正答率(トレーニング) = 0.9033333333333333
#                 : 930. 正答率(テスト) = 0.7209
# Generation: 940. 正答率(トレーニング) = 0.8966666666666666
#                 : 940. 正答率(テスト) = 0.7186
# Generation: 950. 正答率(トレーニング) = 0.8966666666666666
#                 : 950. 正答率(テスト) = 0.7232
# Generation: 960. 正答率(トレーニング) = 0.8966666666666666
#                 : 960. 正答率(テスト) = 0.7277
# Generation: 970. 正答率(トレーニング) = 0.9
#                 : 970. 正答率(テスト) = 0.7282
# Generation: 980. 正答率(トレーニング) = 0.9033333333333333
#                 : 980. 正答率(テスト) = 0.7324
# Generation: 990. 正答率(トレーニング) = 0.89
#                 : 990. 正答率(テスト) = 0.7316
# Generation: 1000. 正答率(トレーニング) = 0.9033333333333333
#                 : 1000. 正答率(テスト) = 0.7338

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] dropout_ratioの値を変更してみよう

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.90
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda, use_dropout = use_dropout, dropout_ratio = dropout_ratio)
optimizer = optimizer.SGD(learning_rate=0.01)
# optimizer = optimizer.Momentum(learning_rate=0.01, momentum=0.9)
# optimizer = optimizer.AdaGrad(learning_rate=0.01)
# optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)    
    
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.13
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.13
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.13
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.13
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.13
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.13
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.13
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.13
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.13
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.13
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.13
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.13
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.13
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.13
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.13
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.13
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.13
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.13
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.13
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.13
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.13
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.13
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.13
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.13
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.13
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.13
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.13
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.13
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.13
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.13
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.13
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.13
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.13
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.13
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.13
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.13
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.13
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.13
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.13
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.13
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.13
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.13
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.13
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.13
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.13
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.13
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.13
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.13
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.13
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.13
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.13
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.13
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.13
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.13
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.13
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.13
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.13
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.13
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.13
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.13
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.13
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.13
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.13
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.13
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.13
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.13
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.13
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.13
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.13
#                 : 710. 正答率(テスト) = 0.1135
# Generation: 720. 正答率(トレーニング) = 0.13
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.13
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.13
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.13
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.13
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.13
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.13
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.13
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.13
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.13
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.13
#                 : 820. 正答率(テスト) = 0.1135
# Generation: 830. 正答率(トレーニング) = 0.13
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.13
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.13
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.13
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.13
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.13
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.13
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.13
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.13
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.13
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.13
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.13
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.13
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.13
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.13
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.13
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.13
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.13
#                 : 1000. 正答率(テスト) = 0.1135

# %% [markdown]
# dropout_ratio=0.9に
# dropout_ratioが高すぎても学習が進まなくなってしまう

# %% [markdown]
# ## [try] optimizerとdropout_ratioの値を変更してみよう
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.15
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda, use_dropout = use_dropout, dropout_ratio = dropout_ratio)
# optimizer = optimizer.SGD(learning_rate=0.01)
# optimizer = optimizer.Momentum(learning_rate=0.01, momentum=0.9)
# optimizer = optimizer.AdaGrad(learning_rate=0.01)
optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)    
    
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.17
#                 : 10. 正答率(テスト) = 0.1425
# Generation: 20. 正答率(トレーニング) = 0.29333333333333333
#                 : 20. 正答率(テスト) = 0.2259
# Generation: 30. 正答率(トレーニング) = 0.22666666666666666
#                 : 30. 正答率(テスト) = 0.169
# Generation: 40. 正答率(トレーニング) = 0.14666666666666667
#                 : 40. 正答率(テスト) = 0.1423
# Generation: 50. 正答率(トレーニング) = 0.13
#                 : 50. 正答率(テスト) = 0.115
# Generation: 60. 正答率(トレーニング) = 0.13
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.13
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.13
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.13
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.13
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.13
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.13
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.13
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.13
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.13
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.13
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.13
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.13
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.13
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.13
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.13
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.13
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.13
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.13
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.13
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.13
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.13
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.13
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.13
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.13
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.13
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.13
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.13
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.13
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.13
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.13
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.13
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.13
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.13
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.13
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.13
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.13
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.13
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.13
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.13
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.13
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.13
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.13
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.13
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.13
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.13
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.13
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.13
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.13
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.13
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.13
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.13
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.13
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.13
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.13
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.13
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.13
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.13
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.13
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.13
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.13
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.13
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.13
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.13
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.13
#                 : 710. 正答率(テスト) = 0.1135
# Generation: 720. 正答率(トレーニング) = 0.13
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.13
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.13
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.13
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.13
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.13
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.13
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.13
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.13
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.13
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.13
#                 : 820. 正答率(テスト) = 0.1135
# Generation: 830. 正答率(トレーニング) = 0.13
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.13
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.13
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.13
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.13
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.13
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.13
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.13
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.13
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.13
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.13
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.13
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.13
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.13
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.13
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.13
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.13
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.13
#                 : 1000. 正答率(テスト) = 0.1135

# %% [markdown]
# dropout_ratio=0.15 & Adam
# dropout0.15程度でも学習が進まなくなってしまう。
# 最初に少し立ち上がりが見えるのは何か？

# %% [markdown]
# ## Dropout + L1

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.08
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        use_dropout = use_dropout, dropout_ratio = dropout_ratio)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []
hidden_layer_num = network.hidden_layer_num

plot_interval=10

# 正則化強度設定 ======================================
weight_decay_lambda=0.004
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * np.sign(network.params['W' + str(idx)])
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += weight_decay_lambda * np.sum(np.abs(network.params['W' + str(idx)]))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.08333333333333333
#                 : 10. 正答率(テスト) = 0.1099
# Generation: 20. 正答率(トレーニング) = 0.11
#                 : 20. 正答率(テスト) = 0.1274
# Generation: 30. 正答率(トレーニング) = 0.13666666666666666
#                 : 30. 正答率(テスト) = 0.1449
# Generation: 40. 正答率(トレーニング) = 0.15333333333333332
#                 : 40. 正答率(テスト) = 0.159
# Generation: 50. 正答率(トレーニング) = 0.19666666666666666
#                 : 50. 正答率(テスト) = 0.177
# Generation: 60. 正答率(トレーニング) = 0.21666666666666667
#                 : 60. 正答率(テスト) = 0.1944
# Generation: 70. 正答率(トレーニング) = 0.25666666666666665
#                 : 70. 正答率(テスト) = 0.2093
# Generation: 80. 正答率(トレーニング) = 0.29
#                 : 80. 正答率(テスト) = 0.2263
# Generation: 90. 正答率(トレーニング) = 0.33666666666666667
#                 : 90. 正答率(テスト) = 0.2464
# Generation: 100. 正答率(トレーニング) = 0.36
#                 : 100. 正答率(テスト) = 0.2662
# Generation: 110. 正答率(トレーニング) = 0.4033333333333333
#                 : 110. 正答率(テスト) = 0.2939
# Generation: 120. 正答率(トレーニング) = 0.44
#                 : 120. 正答率(テスト) = 0.3148
# Generation: 130. 正答率(トレーニング) = 0.51
#                 : 130. 正答率(テスト) = 0.3556
# Generation: 140. 正答率(トレーニング) = 0.5333333333333333
#                 : 140. 正答率(テスト) = 0.3763
# Generation: 150. 正答率(トレーニング) = 0.5233333333333333
#                 : 150. 正答率(テスト) = 0.3816
# Generation: 160. 正答率(トレーニング) = 0.54
#                 : 160. 正答率(テスト) = 0.393
# Generation: 170. 正答率(トレーニング) = 0.5466666666666666
#                 : 170. 正答率(テスト) = 0.3956
# Generation: 180. 正答率(トレーニング) = 0.55
#                 : 180. 正答率(テスト) = 0.4015
# Generation: 190. 正答率(トレーニング) = 0.5433333333333333
#                 : 190. 正答率(テスト) = 0.4
# Generation: 200. 正答率(トレーニング) = 0.5433333333333333
#                 : 200. 正答率(テスト) = 0.4122
# Generation: 210. 正答率(トレーニング) = 0.5566666666666666
#                 : 210. 正答率(テスト) = 0.4258
# Generation: 220. 正答率(トレーニング) = 0.57
#                 : 220. 正答率(テスト) = 0.4451
# Generation: 230. 正答率(トレーニング) = 0.57
#                 : 230. 正答率(テスト) = 0.4518
# Generation: 240. 正答率(トレーニング) = 0.5933333333333334
#                 : 240. 正答率(テスト) = 0.4576
# Generation: 250. 正答率(トレーニング) = 0.5733333333333334
#                 : 250. 正答率(テスト) = 0.4433
# Generation: 260. 正答率(トレーニング) = 0.62
#                 : 260. 正答率(テスト) = 0.4697
# Generation: 270. 正答率(トレーニング) = 0.6066666666666667
#                 : 270. 正答率(テスト) = 0.4621
# Generation: 280. 正答率(トレーニング) = 0.6233333333333333
#                 : 280. 正答率(テスト) = 0.4801
# Generation: 290. 正答率(トレーニング) = 0.6366666666666667
#                 : 290. 正答率(テスト) = 0.4867
# Generation: 300. 正答率(トレーニング) = 0.6466666666666666
#                 : 300. 正答率(テスト) = 0.4882
# Generation: 310. 正答率(トレーニング) = 0.6633333333333333
#                 : 310. 正答率(テスト) = 0.5025
# Generation: 320. 正答率(トレーニング) = 0.6566666666666666
#                 : 320. 正答率(テスト) = 0.5023
# Generation: 330. 正答率(トレーニング) = 0.68
#                 : 330. 正答率(テスト) = 0.5222
# Generation: 340. 正答率(トレーニング) = 0.6766666666666666
#                 : 340. 正答率(テスト) = 0.5238
# Generation: 350. 正答率(トレーニング) = 0.6933333333333334
#                 : 350. 正答率(テスト) = 0.5313
# Generation: 360. 正答率(トレーニング) = 0.6933333333333334
#                 : 360. 正答率(テスト) = 0.5348
# Generation: 370. 正答率(トレーニング) = 0.7
#                 : 370. 正答率(テスト) = 0.5466
# Generation: 380. 正答率(トレーニング) = 0.7166666666666667
#                 : 380. 正答率(テスト) = 0.5639
# Generation: 390. 正答率(トレーニング) = 0.7233333333333334
#                 : 390. 正答率(テスト) = 0.5602
# Generation: 400. 正答率(トレーニング) = 0.7433333333333333
#                 : 400. 正答率(テスト) = 0.5807
# Generation: 410. 正答率(トレーニング) = 0.7633333333333333
#                 : 410. 正答率(テスト) = 0.5967
# Generation: 420. 正答率(トレーニング) = 0.7666666666666667
#                 : 420. 正答率(テスト) = 0.5984
# Generation: 430. 正答率(トレーニング) = 0.7633333333333333
#                 : 430. 正答率(テスト) = 0.6031
# Generation: 440. 正答率(トレーニング) = 0.7833333333333333
#                 : 440. 正答率(テスト) = 0.6108
# Generation: 450. 正答率(トレーニング) = 0.8
#                 : 450. 正答率(テスト) = 0.6244
# Generation: 460. 正答率(トレーニング) = 0.7966666666666666
#                 : 460. 正答率(テスト) = 0.6295
# Generation: 470. 正答率(トレーニング) = 0.82
#                 : 470. 正答率(テスト) = 0.6367
# Generation: 480. 正答率(トレーニング) = 0.81
#                 : 480. 正答率(テスト) = 0.6338
# Generation: 490. 正答率(トレーニング) = 0.82
#                 : 490. 正答率(テスト) = 0.6393
# Generation: 500. 正答率(トレーニング) = 0.8333333333333334
#                 : 500. 正答率(テスト) = 0.6529
# Generation: 510. 正答率(トレーニング) = 0.8466666666666667
#                 : 510. 正答率(テスト) = 0.6573
# Generation: 520. 正答率(トレーニング) = 0.8366666666666667
#                 : 520. 正答率(テスト) = 0.6543
# Generation: 530. 正答率(トレーニング) = 0.8433333333333334
#                 : 530. 正答率(テスト) = 0.6614
# Generation: 540. 正答率(トレーニング) = 0.8433333333333334
#                 : 540. 正答率(テスト) = 0.665
# Generation: 550. 正答率(トレーニング) = 0.8666666666666667
#                 : 550. 正答率(テスト) = 0.6748
# Generation: 560. 正答率(トレーニング) = 0.86
#                 : 560. 正答率(テスト) = 0.6752
# Generation: 570. 正答率(トレーニング) = 0.8533333333333334
#                 : 570. 正答率(テスト) = 0.6779
# Generation: 580. 正答率(トレーニング) = 0.8533333333333334
#                 : 580. 正答率(テスト) = 0.6722
# Generation: 590. 正答率(トレーニング) = 0.8733333333333333
#                 : 590. 正答率(テスト) = 0.6762
# Generation: 600. 正答率(トレーニング) = 0.8666666666666667
#                 : 600. 正答率(テスト) = 0.6832
# Generation: 610. 正答率(トレーニング) = 0.8633333333333333
#                 : 610. 正答率(テスト) = 0.6861
# Generation: 620. 正答率(トレーニング) = 0.87
#                 : 620. 正答率(テスト) = 0.683
# Generation: 630. 正答率(トレーニング) = 0.8766666666666667
#                 : 630. 正答率(テスト) = 0.6914
# Generation: 640. 正答率(トレーニング) = 0.8733333333333333
#                 : 640. 正答率(テスト) = 0.6894
# Generation: 650. 正答率(トレーニング) = 0.8833333333333333
#                 : 650. 正答率(テスト) = 0.6919
# Generation: 660. 正答率(トレーニング) = 0.8766666666666667
#                 : 660. 正答率(テスト) = 0.6945
# Generation: 670. 正答率(トレーニング) = 0.8733333333333333
#                 : 670. 正答率(テスト) = 0.6935
# Generation: 680. 正答率(トレーニング) = 0.8866666666666667
#                 : 680. 正答率(テスト) = 0.696
# Generation: 690. 正答率(トレーニング) = 0.8833333333333333
#                 : 690. 正答率(テスト) = 0.7018
# Generation: 700. 正答率(トレーニング) = 0.89
#                 : 700. 正答率(テスト) = 0.7014
# Generation: 710. 正答率(トレーニング) = 0.8833333333333333
#                 : 710. 正答率(テスト) = 0.6994
# Generation: 720. 正答率(トレーニング) = 0.9
#                 : 720. 正答率(テスト) = 0.7049
# Generation: 730. 正答率(トレーニング) = 0.8966666666666666
#                 : 730. 正答率(テスト) = 0.7052
# Generation: 740. 正答率(トレーニング) = 0.9
#                 : 740. 正答率(テスト) = 0.7006
# Generation: 750. 正答率(トレーニング) = 0.8966666666666666
#                 : 750. 正答率(テスト) = 0.6999
# Generation: 760. 正答率(トレーニング) = 0.9066666666666666
#                 : 760. 正答率(テスト) = 0.7025
# Generation: 770. 正答率(トレーニング) = 0.9
#                 : 770. 正答率(テスト) = 0.7043
# Generation: 780. 正答率(トレーニング) = 0.9066666666666666
#                 : 780. 正答率(テスト) = 0.7015
# Generation: 790. 正答率(トレーニング) = 0.9066666666666666
#                 : 790. 正答率(テスト) = 0.706
# Generation: 800. 正答率(トレーニング) = 0.9066666666666666
#                 : 800. 正答率(テスト) = 0.7065
# Generation: 810. 正答率(トレーニング) = 0.9
#                 : 810. 正答率(テスト) = 0.7096
# Generation: 820. 正答率(トレーニング) = 0.91
#                 : 820. 正答率(テスト) = 0.7102
# Generation: 830. 正答率(トレーニング) = 0.9133333333333333
#                 : 830. 正答率(テスト) = 0.7156
# Generation: 840. 正答率(トレーニング) = 0.9133333333333333
#                 : 840. 正答率(テスト) = 0.7158
# Generation: 850. 正答率(トレーニング) = 0.92
#                 : 850. 正答率(テスト) = 0.7143
# Generation: 860. 正答率(トレーニング) = 0.9166666666666666
#                 : 860. 正答率(テスト) = 0.7179
# Generation: 870. 正答率(トレーニング) = 0.92
#                 : 870. 正答率(テスト) = 0.7164
# Generation: 880. 正答率(トレーニング) = 0.9133333333333333
#                 : 880. 正答率(テスト) = 0.7178
# Generation: 890. 正答率(トレーニング) = 0.92
#                 : 890. 正答率(テスト) = 0.7144
# Generation: 900. 正答率(トレーニング) = 0.92
#                 : 900. 正答率(テスト) = 0.7186
# Generation: 910. 正答率(トレーニング) = 0.92
#                 : 910. 正答率(テスト) = 0.7139
# Generation: 920. 正答率(トレーニング) = 0.92
#                 : 920. 正答率(テスト) = 0.7183
# Generation: 930. 正答率(トレーニング) = 0.9233333333333333
#                 : 930. 正答率(テスト) = 0.7231
# Generation: 940. 正答率(トレーニング) = 0.9233333333333333
#                 : 940. 正答率(テスト) = 0.7209
# Generation: 950. 正答率(トレーニング) = 0.9233333333333333
#                 : 950. 正答率(テスト) = 0.7255
# Generation: 960. 正答率(トレーニング) = 0.9266666666666666
#                 : 960. 正答率(テスト) = 0.7228
# Generation: 970. 正答率(トレーニング) = 0.9266666666666666
#                 : 970. 正答率(テスト) = 0.7238
# Generation: 980. 正答率(トレーニング) = 0.9233333333333333
#                 : 980. 正答率(テスト) = 0.7218
# Generation: 990. 正答率(トレーニング) = 0.9233333333333333
#                 : 990. 正答率(テスト) = 0.7238
# Generation: 1000. 正答率(トレーニング) = 0.9266666666666666
#                 : 1000. 正答率(テスト) = 0.7263
