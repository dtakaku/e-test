# %% [markdown]
# # batch normalization

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer

# バッチ正則化 layer
class BatchNormalization:
    '''
    gamma: スケール係数
    beta: オフセット
    momentum: 慣性
    running_mean: テスト時に使用する平均
    running_var: テスト時に使用する分散
    '''
    def __init__(self, gamma, beta, momentum=0.9, running_mean=None, running_var=None):
        self.gamma = gamma
        self.beta = beta
        self.momentum = momentum
        self.input_shape = None

        self.running_mean = running_mean
        self.running_var = running_var  
        
        # backward時に使用する中間データ
        self.batch_size = None
        self.xc = None
        self.std = None
        self.dgamma = None
        self.dbeta = None

    def forward(self, x, train_flg=True):
        if self.running_mean is None:
            N, D = x.shape
            self.running_mean = np.zeros(D)
            self.running_var = np.zeros(D)
                        
        if train_flg:
            mu = x.mean(axis=0) # 平均
            xc = x - mu # xをセンタリング
            var = np.mean(xc**2, axis=0) # 分散
            std = np.sqrt(var + 10e-7) # スケーリング
            xn = xc / std
            
            self.batch_size = x.shape[0]
            self.xc = xc
            self.xn = xn
            self.std = std
            self.running_mean = self.momentum * self.running_mean + (1-self.momentum) * mu # 平均値の加重平均
            self.running_var = self.momentum * self.running_var + (1-self.momentum) * var #分散値の加重平均
        else:
            xc = x - self.running_mean
            xn = xc / ((np.sqrt(self.running_var + 10e-7)))
            
        out = self.gamma * xn + self.beta 
        
        return out

    def backward(self, dout):
        dbeta = dout.sum(axis=0)
        dgamma = np.sum(self.xn * dout, axis=0)
        dxn = self.gamma * dout
        dxc = dxn / self.std
        dstd = -np.sum((dxn * self.xc) / (self.std * self.std), axis=0)
        dvar = 0.5 * dstd / self.std
        dxc += (2.0 / self.batch_size) * self.xc * dvar
        dmu = np.sum(dxc, axis=0)
        dx = dxc - dmu / self.batch_size
        
        self.dgamma = dgamma
        self.dbeta = dbeta

        return dx

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='sigmoid', weight_init_std='Xavier', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15
#                 : 10. 正答率(テスト) = 0.1355
# Generation: 20. 正答率(トレーニング) = 0.2
#                 : 20. 正答率(テスト) = 0.2156
# Generation: 30. 正答率(トレーニング) = 0.32
#                 : 30. 正答率(テスト) = 0.3025
# Generation: 40. 正答率(トレーニング) = 0.36
#                 : 40. 正答率(テスト) = 0.3396
# Generation: 50. 正答率(トレーニング) = 0.32
#                 : 50. 正答率(テスト) = 0.3632
# Generation: 60. 正答率(トレーニング) = 0.31
#                 : 60. 正答率(テスト) = 0.3787
# Generation: 70. 正答率(トレーニング) = 0.37
#                 : 70. 正答率(テスト) = 0.3948
# Generation: 80. 正答率(トレーニング) = 0.4
#                 : 80. 正答率(テスト) = 0.4061
# Generation: 90. 正答率(トレーニング) = 0.39
#                 : 90. 正答率(テスト) = 0.4184
# Generation: 100. 正答率(トレーニング) = 0.48
#                 : 100. 正答率(テスト) = 0.4331
# Generation: 110. 正答率(トレーニング) = 0.44
#                 : 110. 正答率(テスト) = 0.4456
# Generation: 120. 正答率(トレーニング) = 0.37
#                 : 120. 正答率(テスト) = 0.4576
# Generation: 130. 正答率(トレーニング) = 0.39
#                 : 130. 正答率(テスト) = 0.4721
# Generation: 140. 正答率(トレーニング) = 0.46
#                 : 140. 正答率(テスト) = 0.4886
# Generation: 150. 正答率(トレーニング) = 0.49
#                 : 150. 正答率(テスト) = 0.5045
# Generation: 160. 正答率(トレーニング) = 0.51
#                 : 160. 正答率(テスト) = 0.5217
# Generation: 170. 正答率(トレーニング) = 0.49
#                 : 170. 正答率(テスト) = 0.5402
# Generation: 180. 正答率(トレーニング) = 0.52
#                 : 180. 正答率(テスト) = 0.5467
# Generation: 190. 正答率(トレーニング) = 0.52
#                 : 190. 正答率(テスト) = 0.5599
# Generation: 200. 正答率(トレーニング) = 0.6
#                 : 200. 正答率(テスト) = 0.5701
# Generation: 210. 正答率(トレーニング) = 0.54
#                 : 210. 正答率(テスト) = 0.583
# Generation: 220. 正答率(トレーニング) = 0.59
#                 : 220. 正答率(テスト) = 0.5972
# Generation: 230. 正答率(トレーニング) = 0.51
#                 : 230. 正答率(テスト) = 0.6085
# Generation: 240. 正答率(トレーニング) = 0.64
#                 : 240. 正答率(テスト) = 0.6182
# Generation: 250. 正答率(トレーニング) = 0.7
#                 : 250. 正答率(テスト) = 0.627
# Generation: 260. 正答率(トレーニング) = 0.72
#                 : 260. 正答率(テスト) = 0.6322
# Generation: 270. 正答率(トレーニング) = 0.56
#                 : 270. 正答率(テスト) = 0.6391
# Generation: 280. 正答率(トレーニング) = 0.63
#                 : 280. 正答率(テスト) = 0.6387
# Generation: 290. 正答率(トレーニング) = 0.66
#                 : 290. 正答率(テスト) = 0.6456
# Generation: 300. 正答率(トレーニング) = 0.68
#                 : 300. 正答率(テスト) = 0.656
# Generation: 310. 正答率(トレーニング) = 0.63
#                 : 310. 正答率(テスト) = 0.6634
# Generation: 320. 正答率(トレーニング) = 0.62
#                 : 320. 正答率(テスト) = 0.674
# Generation: 330. 正答率(トレーニング) = 0.63
#                 : 330. 正答率(テスト) = 0.6792
# Generation: 340. 正答率(トレーニング) = 0.71
#                 : 340. 正答率(テスト) = 0.686
# Generation: 350. 正答率(トレーニング) = 0.68
#                 : 350. 正答率(テスト) = 0.689
# Generation: 360. 正答率(トレーニング) = 0.64
#                 : 360. 正答率(テスト) = 0.6915
# Generation: 370. 正答率(トレーニング) = 0.69
#                 : 370. 正答率(テスト) = 0.6954
# Generation: 380. 正答率(トレーニング) = 0.77
#                 : 380. 正答率(テスト) = 0.7001
# Generation: 390. 正答率(トレーニング) = 0.67
#                 : 390. 正答率(テスト) = 0.7058
# Generation: 400. 正答率(トレーニング) = 0.69
#                 : 400. 正答率(テスト) = 0.7144
# Generation: 410. 正答率(トレーニング) = 0.68
#                 : 410. 正答率(テスト) = 0.7158
# Generation: 420. 正答率(トレーニング) = 0.75
#                 : 420. 正答率(テスト) = 0.7251
# Generation: 430. 正答率(トレーニング) = 0.79
#                 : 430. 正答率(テスト) = 0.7336
# Generation: 440. 正答率(トレーニング) = 0.65
#                 : 440. 正答率(テスト) = 0.7344
# Generation: 450. 正答率(トレーニング) = 0.62
#                 : 450. 正答率(テスト) = 0.7358
# Generation: 460. 正答率(トレーニング) = 0.66
#                 : 460. 正答率(テスト) = 0.7411
# Generation: 470. 正答率(トレーニング) = 0.83
#                 : 470. 正答率(テスト) = 0.7496
# Generation: 480. 正答率(トレーニング) = 0.72
#                 : 480. 正答率(テスト) = 0.7513
# Generation: 490. 正答率(トレーニング) = 0.72
#                 : 490. 正答率(テスト) = 0.7526
# Generation: 500. 正答率(トレーニング) = 0.7
#                 : 500. 正答率(テスト) = 0.7568
# Generation: 510. 正答率(トレーニング) = 0.82
#                 : 510. 正答率(テスト) = 0.7601
# Generation: 520. 正答率(トレーニング) = 0.72
#                 : 520. 正答率(テスト) = 0.7624
# Generation: 530. 正答率(トレーニング) = 0.77
#                 : 530. 正答率(テスト) = 0.7629
# Generation: 540. 正答率(トレーニング) = 0.77
#                 : 540. 正答率(テスト) = 0.7642
# Generation: 550. 正答率(トレーニング) = 0.73
#                 : 550. 正答率(テスト) = 0.7701
# Generation: 560. 正答率(トレーニング) = 0.75
#                 : 560. 正答率(テスト) = 0.7725
# Generation: 570. 正答率(トレーニング) = 0.77
#                 : 570. 正答率(テスト) = 0.7768
# Generation: 580. 正答率(トレーニング) = 0.71
#                 : 580. 正答率(テスト) = 0.7738
# Generation: 590. 正答率(トレーニング) = 0.83
#                 : 590. 正答率(テスト) = 0.7743
# Generation: 600. 正答率(トレーニング) = 0.83
#                 : 600. 正答率(テスト) = 0.7782
# Generation: 610. 正答率(トレーニング) = 0.71
#                 : 610. 正答率(テスト) = 0.7785
# Generation: 620. 正答率(トレーニング) = 0.79
#                 : 620. 正答率(テスト) = 0.7804
# Generation: 630. 正答率(トレーニング) = 0.7
#                 : 630. 正答率(テスト) = 0.7878
# Generation: 640. 正答率(トレーニング) = 0.79
#                 : 640. 正答率(テスト) = 0.7825
# Generation: 650. 正答率(トレーニング) = 0.76
#                 : 650. 正答率(テスト) = 0.7885
# Generation: 660. 正答率(トレーニング) = 0.86
#                 : 660. 正答率(テスト) = 0.7919
# Generation: 670. 正答率(トレーニング) = 0.76
#                 : 670. 正答率(テスト) = 0.786
# Generation: 680. 正答率(トレーニング) = 0.78
#                 : 680. 正答率(テスト) = 0.791
# Generation: 690. 正答率(トレーニング) = 0.78
#                 : 690. 正答率(テスト) = 0.7952
# Generation: 700. 正答率(トレーニング) = 0.79
#                 : 700. 正答率(テスト) = 0.79
# Generation: 710. 正答率(トレーニング) = 0.77
#                 : 710. 正答率(テスト) = 0.7944
# Generation: 720. 正答率(トレーニング) = 0.79
#                 : 720. 正答率(テスト) = 0.7952
# Generation: 730. 正答率(トレーニング) = 0.85
#                 : 730. 正答率(テスト) = 0.7958
# Generation: 740. 正答率(トレーニング) = 0.78
#                 : 740. 正答率(テスト) = 0.7996
# Generation: 750. 正答率(トレーニング) = 0.82
#                 : 750. 正答率(テスト) = 0.7985
# Generation: 760. 正答率(トレーニング) = 0.8
#                 : 760. 正答率(テスト) = 0.8011
# Generation: 770. 正答率(トレーニング) = 0.81
#                 : 770. 正答率(テスト) = 0.8011
# Generation: 780. 正答率(トレーニング) = 0.76
#                 : 780. 正答率(テスト) = 0.8028
# Generation: 790. 正答率(トレーニング) = 0.79
#                 : 790. 正答率(テスト) = 0.8015
# Generation: 800. 正答率(トレーニング) = 0.81
#                 : 800. 正答率(テスト) = 0.8084
# Generation: 810. 正答率(トレーニング) = 0.81
#                 : 810. 正答率(テスト) = 0.8075
# Generation: 820. 正答率(トレーニング) = 0.74
#                 : 820. 正答率(テスト) = 0.8091
# Generation: 830. 正答率(トレーニング) = 0.81
#                 : 830. 正答率(テスト) = 0.8116
# Generation: 840. 正答率(トレーニング) = 0.82
#                 : 840. 正答率(テスト) = 0.8148
# Generation: 850. 正答率(トレーニング) = 0.92
#                 : 850. 正答率(テスト) = 0.8145
# Generation: 860. 正答率(トレーニング) = 0.77
#                 : 860. 正答率(テスト) = 0.8158
# Generation: 870. 正答率(トレーニング) = 0.79
#                 : 870. 正答率(テスト) = 0.8164
# Generation: 880. 正答率(トレーニング) = 0.73
#                 : 880. 正答率(テスト) = 0.8142
# Generation: 890. 正答率(トレーニング) = 0.76
#                 : 890. 正答率(テスト) = 0.8141
# Generation: 900. 正答率(トレーニング) = 0.81
#                 : 900. 正答率(テスト) = 0.8151
# Generation: 910. 正答率(トレーニング) = 0.76
#                 : 910. 正答率(テスト) = 0.8171
# Generation: 920. 正答率(トレーニング) = 0.87
#                 : 920. 正答率(テスト) = 0.8195
# Generation: 930. 正答率(トレーニング) = 0.8
#                 : 930. 正答率(テスト) = 0.8184
# Generation: 940. 正答率(トレーニング) = 0.86
#                 : 940. 正答率(テスト) = 0.8166
# Generation: 950. 正答率(トレーニング) = 0.77
#                 : 950. 正答率(テスト) = 0.8158
# Generation: 960. 正答率(トレーニング) = 0.88
#                 : 960. 正答率(テスト) = 0.8156
# Generation: 970. 正答率(トレーニング) = 0.78
#                 : 970. 正答率(テスト) = 0.8157
# Generation: 980. 正答率(トレーニング) = 0.81
#                 : 980. 正答率(テスト) = 0.8146
# Generation: 990. 正答率(トレーニング) = 0.7
#                 : 990. 正答率(テスト) = 0.8202
# Generation: 1000. 正答率(トレーニング) = 0.81
#                 : 1000. 正答率(テスト) = 0.8187

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 活性化関数や重みの初期値を変えてみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### ReLU - He初期化 - BatchNormあり
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='relu', weight_init_std='He', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15
#                 : 10. 正答率(テスト) = 0.1991
# Generation: 20. 正答率(トレーニング) = 0.31
#                 : 20. 正答率(テスト) = 0.2894
# Generation: 30. 正答率(トレーニング) = 0.31
#                 : 30. 正答率(テスト) = 0.3447
# Generation: 40. 正答率(トレーニング) = 0.35
#                 : 40. 正答率(テスト) = 0.4033
# Generation: 50. 正答率(トレーニング) = 0.5
#                 : 50. 正答率(テスト) = 0.4575
# Generation: 60. 正答率(トレーニング) = 0.55
#                 : 60. 正答率(テスト) = 0.5091
# Generation: 70. 正答率(トレーニング) = 0.61
#                 : 70. 正答率(テスト) = 0.5427
# Generation: 80. 正答率(トレーニング) = 0.62
#                 : 80. 正答率(テスト) = 0.5646
# Generation: 90. 正答率(トレーニング) = 0.71
#                 : 90. 正答率(テスト) = 0.5859
# Generation: 100. 正答率(トレーニング) = 0.56
#                 : 100. 正答率(テスト) = 0.6081
# Generation: 110. 正答率(トレーニング) = 0.75
#                 : 110. 正答率(テスト) = 0.6248
# Generation: 120. 正答率(トレーニング) = 0.62
#                 : 120. 正答率(テスト) = 0.6433
# Generation: 130. 正答率(トレーニング) = 0.69
#                 : 130. 正答率(テスト) = 0.657
# Generation: 140. 正答率(トレーニング) = 0.65
#                 : 140. 正答率(テスト) = 0.6667
# Generation: 150. 正答率(トレーニング) = 0.65
#                 : 150. 正答率(テスト) = 0.6764
# Generation: 160. 正答率(トレーニング) = 0.68
#                 : 160. 正答率(テスト) = 0.6868
# Generation: 170. 正答率(トレーニング) = 0.66
#                 : 170. 正答率(テスト) = 0.6978
# Generation: 180. 正答率(トレーニング) = 0.71
#                 : 180. 正答率(テスト) = 0.7063
# Generation: 190. 正答率(トレーニング) = 0.71
#                 : 190. 正答率(テスト) = 0.7148
# Generation: 200. 正答率(トレーニング) = 0.75
#                 : 200. 正答率(テスト) = 0.7222
# Generation: 210. 正答率(トレーニング) = 0.71
#                 : 210. 正答率(テスト) = 0.7298
# Generation: 220. 正答率(トレーニング) = 0.73
#                 : 220. 正答率(テスト) = 0.7353
# Generation: 230. 正答率(トレーニング) = 0.77
#                 : 230. 正答率(テスト) = 0.7417
# Generation: 240. 正答率(トレーニング) = 0.73
#                 : 240. 正答率(テスト) = 0.7503
# Generation: 250. 正答率(トレーニング) = 0.78
#                 : 250. 正答率(テスト) = 0.7551
# Generation: 260. 正答率(トレーニング) = 0.75
#                 : 260. 正答率(テスト) = 0.7613
# Generation: 270. 正答率(トレーニング) = 0.74
#                 : 270. 正答率(テスト) = 0.7644
# Generation: 280. 正答率(トレーニング) = 0.72
#                 : 280. 正答率(テスト) = 0.77
# Generation: 290. 正答率(トレーニング) = 0.82
#                 : 290. 正答率(テスト) = 0.7776
# Generation: 300. 正答率(トレーニング) = 0.77
#                 : 300. 正答率(テスト) = 0.7826
# Generation: 310. 正答率(トレーニング) = 0.79
#                 : 310. 正答率(テスト) = 0.7836
# Generation: 320. 正答率(トレーニング) = 0.81
#                 : 320. 正答率(テスト) = 0.786
# Generation: 330. 正答率(トレーニング) = 0.78
#                 : 330. 正答率(テスト) = 0.7902
# Generation: 340. 正答率(トレーニング) = 0.77
#                 : 340. 正答率(テスト) = 0.7916
# Generation: 350. 正答率(トレーニング) = 0.85
#                 : 350. 正答率(テスト) = 0.7951
# Generation: 360. 正答率(トレーニング) = 0.78
#                 : 360. 正答率(テスト) = 0.7967
# Generation: 370. 正答率(トレーニング) = 0.83
#                 : 370. 正答率(テスト) = 0.8015
# Generation: 380. 正答率(トレーニング) = 0.8
#                 : 380. 正答率(テスト) = 0.8078
# Generation: 390. 正答率(トレーニング) = 0.8
#                 : 390. 正答率(テスト) = 0.8104
# Generation: 400. 正答率(トレーニング) = 0.78
#                 : 400. 正答率(テスト) = 0.8124
# Generation: 410. 正答率(トレーニング) = 0.82
#                 : 410. 正答率(テスト) = 0.8147
# Generation: 420. 正答率(トレーニング) = 0.8
#                 : 420. 正答率(テスト) = 0.8165
# Generation: 430. 正答率(トレーニング) = 0.87
#                 : 430. 正答率(テスト) = 0.8203
# Generation: 440. 正答率(トレーニング) = 0.76
#                 : 440. 正答率(テスト) = 0.8203
# Generation: 450. 正答率(トレーニング) = 0.82
#                 : 450. 正答率(テスト) = 0.8232
# Generation: 460. 正答率(トレーニング) = 0.82
#                 : 460. 正答率(テスト) = 0.8297
# Generation: 470. 正答率(トレーニング) = 0.79
#                 : 470. 正答率(テスト) = 0.8317
# Generation: 480. 正答率(トレーニング) = 0.89
#                 : 480. 正答率(テスト) = 0.8334
# Generation: 490. 正答率(トレーニング) = 0.85
#                 : 490. 正答率(テスト) = 0.8336
# Generation: 500. 正答率(トレーニング) = 0.76
#                 : 500. 正答率(テスト) = 0.8365
# Generation: 510. 正答率(トレーニング) = 0.83
#                 : 510. 正答率(テスト) = 0.8423
# Generation: 520. 正答率(トレーニング) = 0.86
#                 : 520. 正答率(テスト) = 0.8452
# Generation: 530. 正答率(トレーニング) = 0.87
#                 : 530. 正答率(テスト) = 0.8468
# Generation: 540. 正答率(トレーニング) = 0.88
#                 : 540. 正答率(テスト) = 0.851
# Generation: 550. 正答率(トレーニング) = 0.86
#                 : 550. 正答率(テスト) = 0.8499
# Generation: 560. 正答率(トレーニング) = 0.85
#                 : 560. 正答率(テスト) = 0.8534
# Generation: 570. 正答率(トレーニング) = 0.88
#                 : 570. 正答率(テスト) = 0.8539
# Generation: 580. 正答率(トレーニング) = 0.9
#                 : 580. 正答率(テスト) = 0.8585
# Generation: 590. 正答率(トレーニング) = 0.87
#                 : 590. 正答率(テスト) = 0.8617
# Generation: 600. 正答率(トレーニング) = 0.86
#                 : 600. 正答率(テスト) = 0.8627
# Generation: 610. 正答率(トレーニング) = 0.81
#                 : 610. 正答率(テスト) = 0.8641
# Generation: 620. 正答率(トレーニング) = 0.88
#                 : 620. 正答率(テスト) = 0.864
# Generation: 630. 正答率(トレーニング) = 0.88
#                 : 630. 正答率(テスト) = 0.8658
# Generation: 640. 正答率(トレーニング) = 0.81
#                 : 640. 正答率(テスト) = 0.8665
# Generation: 650. 正答率(トレーニング) = 0.88
#                 : 650. 正答率(テスト) = 0.8699
# Generation: 660. 正答率(トレーニング) = 0.84
#                 : 660. 正答率(テスト) = 0.87
# Generation: 670. 正答率(トレーニング) = 0.95
#                 : 670. 正答率(テスト) = 0.8715
# Generation: 680. 正答率(トレーニング) = 0.87
#                 : 680. 正答率(テスト) = 0.8724
# Generation: 690. 正答率(トレーニング) = 0.89
#                 : 690. 正答率(テスト) = 0.8743
# Generation: 700. 正答率(トレーニング) = 0.85
#                 : 700. 正答率(テスト) = 0.8746
# Generation: 710. 正答率(トレーニング) = 0.89
#                 : 710. 正答率(テスト) = 0.8748
# Generation: 720. 正答率(トレーニング) = 0.81
#                 : 720. 正答率(テスト) = 0.8758
# Generation: 730. 正答率(トレーニング) = 0.88
#                 : 730. 正答率(テスト) = 0.8783
# Generation: 740. 正答率(トレーニング) = 0.91
#                 : 740. 正答率(テスト) = 0.8767
# Generation: 750. 正答率(トレーニング) = 0.87
#                 : 750. 正答率(テスト) = 0.8777
# Generation: 760. 正答率(トレーニング) = 0.9
#                 : 760. 正答率(テスト) = 0.8773
# Generation: 770. 正答率(トレーニング) = 0.93
#                 : 770. 正答率(テスト) = 0.8823
# Generation: 780. 正答率(トレーニング) = 0.94
#                 : 780. 正答率(テスト) = 0.881
# Generation: 790. 正答率(トレーニング) = 0.92
#                 : 790. 正答率(テスト) = 0.8821
# Generation: 800. 正答率(トレーニング) = 0.81
#                 : 800. 正答率(テスト) = 0.8845
# Generation: 810. 正答率(トレーニング) = 0.88
#                 : 810. 正答率(テスト) = 0.885
# Generation: 820. 正答率(トレーニング) = 0.78
#                 : 820. 正答率(テスト) = 0.8839
# Generation: 830. 正答率(トレーニング) = 0.93
#                 : 830. 正答率(テスト) = 0.8864
# Generation: 840. 正答率(トレーニング) = 0.82
#                 : 840. 正答率(テスト) = 0.8854
# Generation: 850. 正答率(トレーニング) = 0.83
#                 : 850. 正答率(テスト) = 0.8858
# Generation: 860. 正答率(トレーニング) = 0.88
#                 : 860. 正答率(テスト) = 0.8862
# Generation: 870. 正答率(トレーニング) = 0.9
#                 : 870. 正答率(テスト) = 0.8872
# Generation: 880. 正答率(トレーニング) = 0.85
#                 : 880. 正答率(テスト) = 0.8899
# Generation: 890. 正答率(トレーニング) = 0.9
#                 : 890. 正答率(テスト) = 0.889
# Generation: 900. 正答率(トレーニング) = 0.82
#                 : 900. 正答率(テスト) = 0.8882
# Generation: 910. 正答率(トレーニング) = 0.9
#                 : 910. 正答率(テスト) = 0.8909
# Generation: 920. 正答率(トレーニング) = 0.79
#                 : 920. 正答率(テスト) = 0.8908
# Generation: 930. 正答率(トレーニング) = 0.91
#                 : 930. 正答率(テスト) = 0.8915
# Generation: 940. 正答率(トレーニング) = 0.88
#                 : 940. 正答率(テスト) = 0.8927
# Generation: 950. 正答率(トレーニング) = 0.79
#                 : 950. 正答率(テスト) = 0.8931
# Generation: 960. 正答率(トレーニング) = 0.85
#                 : 960. 正答率(テスト) = 0.8936
# Generation: 970. 正答率(トレーニング) = 0.87
#                 : 970. 正答率(テスト) = 0.8954
# Generation: 980. 正答率(トレーニング) = 0.95
#                 : 980. 正答率(テスト) = 0.8959
# Generation: 990. 正答率(トレーニング) = 0.92
#                 : 990. 正答率(テスト) = 0.8957
# Generation: 1000. 正答率(トレーニング) = 0.9
#                 : 1000. 正答率(テスト) = 0.8973

# %% [markdown]
# sogmoid - Xavier初期化よりも精度向上

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ### ReLU - He初期化 - BatchNormなし
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
# use_batchnorm = True
use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='relu', weight_init_std='He', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.17
#                 : 10. 正答率(テスト) = 0.1549
# Generation: 20. 正答率(トレーニング) = 0.26
#                 : 20. 正答率(テスト) = 0.1874
# Generation: 30. 正答率(トレーニング) = 0.26
#                 : 30. 正答率(テスト) = 0.2428
# Generation: 40. 正答率(トレーニング) = 0.22
#                 : 40. 正答率(テスト) = 0.2667
# Generation: 50. 正答率(トレーニング) = 0.3
#                 : 50. 正答率(テスト) = 0.3054
# Generation: 60. 正答率(トレーニング) = 0.43
#                 : 60. 正答率(テスト) = 0.3444
# Generation: 70. 正答率(トレーニング) = 0.37
#                 : 70. 正答率(テスト) = 0.3629
# Generation: 80. 正答率(トレーニング) = 0.45
#                 : 80. 正答率(テスト) = 0.3829
# Generation: 90. 正答率(トレーニング) = 0.5
#                 : 90. 正答率(テスト) = 0.4071
# Generation: 100. 正答率(トレーニング) = 0.44
#                 : 100. 正答率(テスト) = 0.4376
# Generation: 110. 正答率(トレーニング) = 0.51
#                 : 110. 正答率(テスト) = 0.4551
# Generation: 120. 正答率(トレーニング) = 0.47
#                 : 120. 正答率(テスト) = 0.4802
# Generation: 130. 正答率(トレーニング) = 0.49
#                 : 130. 正答率(テスト) = 0.5042
# Generation: 140. 正答率(トレーニング) = 0.51
#                 : 140. 正答率(テスト) = 0.5229
# Generation: 150. 正答率(トレーニング) = 0.54
#                 : 150. 正答率(テスト) = 0.5496
# Generation: 160. 正答率(トレーニング) = 0.57
#                 : 160. 正答率(テスト) = 0.5709
# Generation: 170. 正答率(トレーニング) = 0.58
#                 : 170. 正答率(テスト) = 0.5836
# Generation: 180. 正答率(トレーニング) = 0.67
#                 : 180. 正答率(テスト) = 0.6146
# Generation: 190. 正答率(トレーニング) = 0.54
#                 : 190. 正答率(テスト) = 0.631
# Generation: 200. 正答率(トレーニング) = 0.72
#                 : 200. 正答率(テスト) = 0.6376
# Generation: 210. 正答率(トレーニング) = 0.7
#                 : 210. 正答率(テスト) = 0.6728
# Generation: 220. 正答率(トレーニング) = 0.67
#                 : 220. 正答率(テスト) = 0.6862
# Generation: 230. 正答率(トレーニング) = 0.71
#                 : 230. 正答率(テスト) = 0.7087
# Generation: 240. 正答率(トレーニング) = 0.7
#                 : 240. 正答率(テスト) = 0.7121
# Generation: 250. 正答率(トレーニング) = 0.77
#                 : 250. 正答率(テスト) = 0.7143
# Generation: 260. 正答率(トレーニング) = 0.7
#                 : 260. 正答率(テスト) = 0.7265
# Generation: 270. 正答率(トレーニング) = 0.71
#                 : 270. 正答率(テスト) = 0.741
# Generation: 280. 正答率(トレーニング) = 0.81
#                 : 280. 正答率(テスト) = 0.7357
# Generation: 290. 正答率(トレーニング) = 0.74
#                 : 290. 正答率(テスト) = 0.7521
# Generation: 300. 正答率(トレーニング) = 0.75
#                 : 300. 正答率(テスト) = 0.7607
# Generation: 310. 正答率(トレーニング) = 0.77
#                 : 310. 正答率(テスト) = 0.7632
# Generation: 320. 正答率(トレーニング) = 0.72
#                 : 320. 正答率(テスト) = 0.7685
# Generation: 330. 正答率(トレーニング) = 0.75
#                 : 330. 正答率(テスト) = 0.7674
# Generation: 340. 正答率(トレーニング) = 0.79
#                 : 340. 正答率(テスト) = 0.7747
# Generation: 350. 正答率(トレーニング) = 0.79
#                 : 350. 正答率(テスト) = 0.7823
# Generation: 360. 正答率(トレーニング) = 0.75
#                 : 360. 正答率(テスト) = 0.7891
# Generation: 370. 正答率(トレーニング) = 0.7
#                 : 370. 正答率(テスト) = 0.7913
# Generation: 380. 正答率(トレーニング) = 0.79
#                 : 380. 正答率(テスト) = 0.7941
# Generation: 390. 正答率(トレーニング) = 0.76
#                 : 390. 正答率(テスト) = 0.7954
# Generation: 400. 正答率(トレーニング) = 0.8
#                 : 400. 正答率(テスト) = 0.7975
# Generation: 410. 正答率(トレーニング) = 0.78
#                 : 410. 正答率(テスト) = 0.8027
# Generation: 420. 正答率(トレーニング) = 0.82
#                 : 420. 正答率(テスト) = 0.804
# Generation: 430. 正答率(トレーニング) = 0.77
#                 : 430. 正答率(テスト) = 0.8091
# Generation: 440. 正答率(トレーニング) = 0.8
#                 : 440. 正答率(テスト) = 0.8104
# Generation: 450. 正答率(トレーニング) = 0.78
#                 : 450. 正答率(テスト) = 0.8101
# Generation: 460. 正答率(トレーニング) = 0.78
#                 : 460. 正答率(テスト) = 0.812
# Generation: 470. 正答率(トレーニング) = 0.76
#                 : 470. 正答率(テスト) = 0.8154
# Generation: 480. 正答率(トレーニング) = 0.81
#                 : 480. 正答率(テスト) = 0.8184
# Generation: 490. 正答率(トレーニング) = 0.84
#                 : 490. 正答率(テスト) = 0.8202
# Generation: 500. 正答率(トレーニング) = 0.78
#                 : 500. 正答率(テスト) = 0.8209
# Generation: 510. 正答率(トレーニング) = 0.83
#                 : 510. 正答率(テスト) = 0.8221
# Generation: 520. 正答率(トレーニング) = 0.82
#                 : 520. 正答率(テスト) = 0.8238
# Generation: 530. 正答率(トレーニング) = 0.8
#                 : 530. 正答率(テスト) = 0.827
# Generation: 540. 正答率(トレーニング) = 0.81
#                 : 540. 正答率(テスト) = 0.8297
# Generation: 550. 正答率(トレーニング) = 0.82
#                 : 550. 正答率(テスト) = 0.831
# Generation: 560. 正答率(トレーニング) = 0.88
#                 : 560. 正答率(テスト) = 0.8295
# Generation: 570. 正答率(トレーニング) = 0.87
#                 : 570. 正答率(テスト) = 0.8347
# Generation: 580. 正答率(トレーニング) = 0.82
#                 : 580. 正答率(テスト) = 0.8363
# Generation: 590. 正答率(トレーニング) = 0.92
#                 : 590. 正答率(テスト) = 0.838
# Generation: 600. 正答率(トレーニング) = 0.89
#                 : 600. 正答率(テスト) = 0.8419
# Generation: 610. 正答率(トレーニング) = 0.86
#                 : 610. 正答率(テスト) = 0.8396
# Generation: 620. 正答率(トレーニング) = 0.82
#                 : 620. 正答率(テスト) = 0.8429
# Generation: 630. 正答率(トレーニング) = 0.79
#                 : 630. 正答率(テスト) = 0.8436
# Generation: 640. 正答率(トレーニング) = 0.92
#                 : 640. 正答率(テスト) = 0.8446
# Generation: 650. 正答率(トレーニング) = 0.84
#                 : 650. 正答率(テスト) = 0.8457
# Generation: 660. 正答率(トレーニング) = 0.86
#                 : 660. 正答率(テスト) = 0.8466
# Generation: 670. 正答率(トレーニング) = 0.87
#                 : 670. 正答率(テスト) = 0.8487
# Generation: 680. 正答率(トレーニング) = 0.88
#                 : 680. 正答率(テスト) = 0.8487
# Generation: 690. 正答率(トレーニング) = 0.87
#                 : 690. 正答率(テスト) = 0.8506
# Generation: 700. 正答率(トレーニング) = 0.84
#                 : 700. 正答率(テスト) = 0.8515
# Generation: 710. 正答率(トレーニング) = 0.85
#                 : 710. 正答率(テスト) = 0.8522
# Generation: 720. 正答率(トレーニング) = 0.82
#                 : 720. 正答率(テスト) = 0.8525
# Generation: 730. 正答率(トレーニング) = 0.9
#                 : 730. 正答率(テスト) = 0.8508
# Generation: 740. 正答率(トレーニング) = 0.91
#                 : 740. 正答率(テスト) = 0.8543
# Generation: 750. 正答率(トレーニング) = 0.89
#                 : 750. 正答率(テスト) = 0.8574
# Generation: 760. 正答率(トレーニング) = 0.84
#                 : 760. 正答率(テスト) = 0.8573
# Generation: 770. 正答率(トレーニング) = 0.91
#                 : 770. 正答率(テスト) = 0.8573
# Generation: 780. 正答率(トレーニング) = 0.9
#                 : 780. 正答率(テスト) = 0.8583
# Generation: 790. 正答率(トレーニング) = 0.84
#                 : 790. 正答率(テスト) = 0.8598
# Generation: 800. 正答率(トレーニング) = 0.86
#                 : 800. 正答率(テスト) = 0.86
# Generation: 810. 正答率(トレーニング) = 0.89
#                 : 810. 正答率(テスト) = 0.8634
# Generation: 820. 正答率(トレーニング) = 0.89
#                 : 820. 正答率(テスト) = 0.8626
# Generation: 830. 正答率(トレーニング) = 0.88
#                 : 830. 正答率(テスト) = 0.8637
# Generation: 840. 正答率(トレーニング) = 0.92
#                 : 840. 正答率(テスト) = 0.8623
# Generation: 850. 正答率(トレーニング) = 0.84
#                 : 850. 正答率(テスト) = 0.8652
# Generation: 860. 正答率(トレーニング) = 0.92
#                 : 860. 正答率(テスト) = 0.8665
# Generation: 870. 正答率(トレーニング) = 0.88
#                 : 870. 正答率(テスト) = 0.8652
# Generation: 880. 正答率(トレーニング) = 0.9
#                 : 880. 正答率(テスト) = 0.8658
# Generation: 890. 正答率(トレーニング) = 0.85
#                 : 890. 正答率(テスト) = 0.8691
# Generation: 900. 正答率(トレーニング) = 0.86
#                 : 900. 正答率(テスト) = 0.8691
# Generation: 910. 正答率(トレーニング) = 0.86
#                 : 910. 正答率(テスト) = 0.869
# Generation: 920. 正答率(トレーニング) = 0.89
#                 : 920. 正答率(テスト) = 0.8697
# Generation: 930. 正答率(トレーニング) = 0.85
#                 : 930. 正答率(テスト) = 0.8715
# Generation: 940. 正答率(トレーニング) = 0.86
#                 : 940. 正答率(テスト) = 0.8715
# Generation: 950. 正答率(トレーニング) = 0.79
#                 : 950. 正答率(テスト) = 0.8733
# Generation: 960. 正答率(トレーニング) = 0.86
#                 : 960. 正答率(テスト) = 0.8747
# Generation: 970. 正答率(トレーニング) = 0.92
#                 : 970. 正答率(テスト) = 0.8737
# Generation: 980. 正答率(トレーニング) = 0.87
#                 : 980. 正答率(テスト) = 0.8759
# Generation: 990. 正答率(トレーニング) = 0.83
#                 : 990. 正答率(テスト) = 0.8776
# Generation: 1000. 正答率(トレーニング) = 0.87
#                 : 1000. 正答率(テスト) = 0.8775

# %% [markdown]
# BatchNorm追加なしの場合、精度やや低下
# BatchNormの有用性を確認
