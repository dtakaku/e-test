# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from data.mnist import load_mnist
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01 # 変更してみよう
#入力層サイズ
input_layer_size = 784 # 変更してみよう
#中間層サイズ
hidden_layer_size = 40 # 変更してみよう
#出力層サイズ
output_layer_size = 10 # 変更してみよう
# 繰り返し数
iters_num = 1000 # 変更してみよう
# ミニバッチサイズ
batch_size = 100 # 変更してみよ
# 学習率
learning_rate = 0.1 # 変更してみよう
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_size)
    network['W2'] = wieght_init * np.random.randn(hidden_layer_size, output_layer_size)
    # 試してみよう_Xavierの初期値
    # network['W1'] = np.random.randn(input_layer_size, hidden_layer_size) / np.sqrt(input_layer_size)
    # network['W2'] = np.random.randn(hidden_layer_size, output_layer_size) / np.sqrt(hidden_layer_size)
    # 試してみよう Heの初期値
    # network['W1'] = np.random.randn(input_layer_size, hidden_layer_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    # network['W2'] = np.random.randn(hidden_layer_size, output_layer_size) / np.sqrt(hidden_layer_size) * np.sqrt(2)

    network['b1'] = np.zeros(hidden_layer_size)
    network['b2'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2 = network['W1'], network['W2']
    b1, b2  = network['b1'], network['b2']
        
    u1 =  np.dot(x, W1) + b1
    z1 = functions.relu(u1)
    u2 =  np.dot(z1, W2) + b2
    y = functions.softmax(u2)
 
    return z1, y

# 誤差逆伝播
def backward(x, d, z1, y):
    grad = {}
    
    W1, W2 = network['W1'], network['W2']
    b1, b2 = network['b1'], network['b2']    
    # 出力層でのデルタ
    delta2 = functions.d_softmax_with_loss(d, y)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * functions.d_relu(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()


accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

    # パラメータに勾配適用
    for key in ('W1', 'W2', 'b1', 'b2'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("Accuracy")
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.12
#                 : 10. 正答率(テスト) = 0.124
# Generation: 20. 正答率(トレーニング) = 0.16
#                 : 20. 正答率(テスト) = 0.1657
# Generation: 30. 正答率(トレーニング) = 0.34
#                 : 30. 正答率(テスト) = 0.3112
# Generation: 40. 正答率(トレーニング) = 0.42
#                 : 40. 正答率(テスト) = 0.353
# Generation: 50. 正答率(トレーニング) = 0.48
#                 : 50. 正答率(テスト) = 0.4597
# Generation: 60. 正答率(トレーニング) = 0.43
#                 : 60. 正答率(テスト) = 0.5245
# Generation: 70. 正答率(トレーニング) = 0.61
#                 : 70. 正答率(テスト) = 0.5913
# Generation: 80. 正答率(トレーニング) = 0.54
#                 : 80. 正答率(テスト) = 0.5971
# Generation: 90. 正答率(トレーニング) = 0.68
#                 : 90. 正答率(テスト) = 0.6607
# Generation: 100. 正答率(トレーニング) = 0.69
#                 : 100. 正答率(テスト) = 0.6743
# Generation: 110. 正答率(トレーニング) = 0.78
#                 : 110. 正答率(テスト) = 0.7404
# Generation: 120. 正答率(トレーニング) = 0.72
#                 : 120. 正答率(テスト) = 0.759
# Generation: 130. 正答率(トレーニング) = 0.71
#                 : 130. 正答率(テスト) = 0.7689
# Generation: 140. 正答率(トレーニング) = 0.8
#                 : 140. 正答率(テスト) = 0.7813
# Generation: 150. 正答率(トレーニング) = 0.79
#                 : 150. 正答率(テスト) = 0.7912
# Generation: 160. 正答率(トレーニング) = 0.86
#                 : 160. 正答率(テスト) = 0.8084
# Generation: 170. 正答率(トレーニング) = 0.88
#                 : 170. 正答率(テスト) = 0.8077
# Generation: 180. 正答率(トレーニング) = 0.82
#                 : 180. 正答率(テスト) = 0.8205
# Generation: 190. 正答率(トレーニング) = 0.85
#                 : 190. 正答率(テスト) = 0.8358
# Generation: 200. 正答率(トレーニング) = 0.85
#                 : 200. 正答率(テスト) = 0.8435
# Generation: 210. 正答率(トレーニング) = 0.87
#                 : 210. 正答率(テスト) = 0.8423
# Generation: 220. 正答率(トレーニング) = 0.85
#                 : 220. 正答率(テスト) = 0.8492
# Generation: 230. 正答率(トレーニング) = 0.81
#                 : 230. 正答率(テスト) = 0.8457
# Generation: 240. 正答率(トレーニング) = 0.84
#                 : 240. 正答率(テスト) = 0.8623
# Generation: 250. 正答率(トレーニング) = 0.89
#                 : 250. 正答率(テスト) = 0.8648
# Generation: 260. 正答率(トレーニング) = 0.83
#                 : 260. 正答率(テスト) = 0.8644
# Generation: 270. 正答率(トレーニング) = 0.84
#                 : 270. 正答率(テスト) = 0.8705
# Generation: 280. 正答率(トレーニング) = 0.94
#                 : 280. 正答率(テスト) = 0.8684
# Generation: 290. 正答率(トレーニング) = 0.85
#                 : 290. 正答率(テスト) = 0.877
# Generation: 300. 正答率(トレーニング) = 0.88
#                 : 300. 正答率(テスト) = 0.8758
# Generation: 310. 正答率(トレーニング) = 0.88
#                 : 310. 正答率(テスト) = 0.8816
# Generation: 320. 正答率(トレーニング) = 0.87
#                 : 320. 正答率(テスト) = 0.8794
# Generation: 330. 正答率(トレーニング) = 0.87
#                 : 330. 正答率(テスト) = 0.8806
# Generation: 340. 正答率(トレーニング) = 0.85
#                 : 340. 正答率(テスト) = 0.8859
# Generation: 350. 正答率(トレーニング) = 0.94
#                 : 350. 正答率(テスト) = 0.8806
# Generation: 360. 正答率(トレーニング) = 0.9
#                 : 360. 正答率(テスト) = 0.8841
# Generation: 370. 正答率(トレーニング) = 0.93
#                 : 370. 正答率(テスト) = 0.8825
# Generation: 380. 正答率(トレーニング) = 0.92
#                 : 380. 正答率(テスト) = 0.8923
# Generation: 390. 正答率(トレーニング) = 0.8
#                 : 390. 正答率(テスト) = 0.8921
# Generation: 400. 正答率(トレーニング) = 0.87
#                 : 400. 正答率(テスト) = 0.8894
# Generation: 410. 正答率(トレーニング) = 0.91
#                 : 410. 正答率(テスト) = 0.892
# Generation: 420. 正答率(トレーニング) = 0.87
#                 : 420. 正答率(テスト) = 0.8935
# Generation: 430. 正答率(トレーニング) = 0.9
#                 : 430. 正答率(テスト) = 0.8935
# Generation: 440. 正答率(トレーニング) = 0.91
#                 : 440. 正答率(テスト) = 0.895
# Generation: 450. 正答率(トレーニング) = 0.92
#                 : 450. 正答率(テスト) = 0.8927
# Generation: 460. 正答率(トレーニング) = 0.95
#                 : 460. 正答率(テスト) = 0.8982
# Generation: 470. 正答率(トレーニング) = 0.86
#                 : 470. 正答率(テスト) = 0.8964
# Generation: 480. 正答率(トレーニング) = 0.83
#                 : 480. 正答率(テスト) = 0.8963
# Generation: 490. 正答率(トレーニング) = 0.85
#                 : 490. 正答率(テスト) = 0.897
# Generation: 500. 正答率(トレーニング) = 0.93
#                 : 500. 正答率(テスト) = 0.8989
# Generation: 510. 正答率(トレーニング) = 0.93
#                 : 510. 正答率(テスト) = 0.9018
# Generation: 520. 正答率(トレーニング) = 0.96
#                 : 520. 正答率(テスト) = 0.8979
# Generation: 530. 正答率(トレーニング) = 0.93
#                 : 530. 正答率(テスト) = 0.9034
# Generation: 540. 正答率(トレーニング) = 0.92
#                 : 540. 正答率(テスト) = 0.8968
# Generation: 550. 正答率(トレーニング) = 0.95
#                 : 550. 正答率(テスト) = 0.8977
# Generation: 560. 正答率(トレーニング) = 0.92
#                 : 560. 正答率(テスト) = 0.9018
# Generation: 570. 正答率(トレーニング) = 0.94
#                 : 570. 正答率(テスト) = 0.903
# Generation: 580. 正答率(トレーニング) = 0.86
#                 : 580. 正答率(テスト) = 0.9006
# Generation: 590. 正答率(トレーニング) = 0.93
#                 : 590. 正答率(テスト) = 0.9062
# Generation: 600. 正答率(トレーニング) = 0.87
#                 : 600. 正答率(テスト) = 0.9019
# Generation: 610. 正答率(トレーニング) = 0.87
#                 : 610. 正答率(テスト) = 0.9074
# Generation: 620. 正答率(トレーニング) = 0.92
#                 : 620. 正答率(テスト) = 0.9049
# Generation: 630. 正答率(トレーニング) = 0.86
#                 : 630. 正答率(テスト) = 0.9066
# Generation: 640. 正答率(トレーニング) = 0.93
#                 : 640. 正答率(テスト) = 0.9071
# Generation: 650. 正答率(トレーニング) = 0.91
#                 : 650. 正答率(テスト) = 0.9068
# Generation: 660. 正答率(トレーニング) = 0.91
#                 : 660. 正答率(テスト) = 0.9062
# Generation: 670. 正答率(トレーニング) = 0.94
#                 : 670. 正答率(テスト) = 0.9049
# Generation: 680. 正答率(トレーニング) = 0.88
#                 : 680. 正答率(テスト) = 0.9102
# Generation: 690. 正答率(トレーニング) = 0.93
#                 : 690. 正答率(テスト) = 0.9109
# Generation: 700. 正答率(トレーニング) = 0.9
#                 : 700. 正答率(テスト) = 0.9078
# Generation: 710. 正答率(トレーニング) = 0.88
#                 : 710. 正答率(テスト) = 0.91
# Generation: 720. 正答率(トレーニング) = 0.9
#                 : 720. 正答率(テスト) = 0.9074
# Generation: 730. 正答率(トレーニング) = 0.88
#                 : 730. 正答率(テスト) = 0.9108
# Generation: 740. 正答率(トレーニング) = 0.94
#                 : 740. 正答率(テスト) = 0.9127
# Generation: 750. 正答率(トレーニング) = 0.88
#                 : 750. 正答率(テスト) = 0.9137
# Generation: 760. 正答率(トレーニング) = 0.9
#                 : 760. 正答率(テスト) = 0.9136
# Generation: 770. 正答率(トレーニング) = 0.93
#                 : 770. 正答率(テスト) = 0.9095
# Generation: 780. 正答率(トレーニング) = 0.9
#                 : 780. 正答率(テスト) = 0.9128
# Generation: 790. 正答率(トレーニング) = 0.94
#                 : 790. 正答率(テスト) = 0.9128
# Generation: 800. 正答率(トレーニング) = 0.9
#                 : 800. 正答率(テスト) = 0.9095
# Generation: 810. 正答率(トレーニング) = 0.86
#                 : 810. 正答率(テスト) = 0.9115
# Generation: 820. 正答率(トレーニング) = 0.93
#                 : 820. 正答率(テスト) = 0.9112
# Generation: 830. 正答率(トレーニング) = 0.91
#                 : 830. 正答率(テスト) = 0.9148
# Generation: 840. 正答率(トレーニング) = 0.9
#                 : 840. 正答率(テスト) = 0.913
# Generation: 850. 正答率(トレーニング) = 0.9
#                 : 850. 正答率(テスト) = 0.9141
# Generation: 860. 正答率(トレーニング) = 0.89
#                 : 860. 正答率(テスト) = 0.914
# Generation: 870. 正答率(トレーニング) = 0.92
#                 : 870. 正答率(テスト) = 0.9126
# Generation: 880. 正答率(トレーニング) = 0.89
#                 : 880. 正答率(テスト) = 0.9165
# Generation: 890. 正答率(トレーニング) = 0.95
#                 : 890. 正答率(テスト) = 0.9176
# Generation: 900. 正答率(トレーニング) = 0.87
#                 : 900. 正答率(テスト) = 0.9166
# Generation: 910. 正答率(トレーニング) = 0.96
#                 : 910. 正答率(テスト) = 0.9168
# Generation: 920. 正答率(トレーニング) = 0.91
#                 : 920. 正答率(テスト) = 0.9193
# Generation: 930. 正答率(トレーニング) = 0.97
#                 : 930. 正答率(テスト) = 0.919
# Generation: 940. 正答率(トレーニング) = 0.94
#                 : 940. 正答率(テスト) = 0.9182
# Generation: 950. 正答率(トレーニング) = 0.91
#                 : 950. 正答率(テスト) = 0.917
# Generation: 960. 正答率(トレーニング) = 0.95
#                 : 960. 正答率(テスト) = 0.916
# Generation: 970. 正答率(トレーニング) = 0.88
#                 : 970. 正答率(テスト) = 0.9191
# Generation: 980. 正答率(トレーニング) = 0.92
#                 : 980. 正答率(テスト) = 0.9158
# Generation: 990. 正答率(トレーニング) = 0.96
#                 : 990. 正答率(テスト) = 0.9178
# Generation: 1000. 正答率(トレーニング) = 0.86
#                 : 1000. 正答率(テスト) = 0.9225

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from data.mnist import load_mnist
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01 # 変更してみよう
#入力層サイズ
input_layer_size = 784 # 変更してみよう
#中間層サイズ
hidden_layer_size = 40 # 変更してみよう
#出力層サイズ
output_layer_size = 10 # 変更してみよう
# 繰り返し数
iters_num = 1000 # 変更してみよう
# ミニバッチサイズ
batch_size = 100 # 変更してみよ
# 学習率
learning_rate = 0.1 # 変更してみよう
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    # network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_size)
    # network['W2'] = wieght_init * np.random.randn(hidden_layer_size, output_layer_size)
    # 試してみよう_Xavierの初期値
    # network['W1'] = np.random.randn(input_layer_size, hidden_layer_size) / np.sqrt(input_layer_size)
    # network['W2'] = np.random.randn(hidden_layer_size, output_layer_size) / np.sqrt(hidden_layer_size)
    # 試してみよう Heの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    network['W2'] = np.random.randn(hidden_layer_size, output_layer_size) / np.sqrt(hidden_layer_size) * np.sqrt(2)

    network['b1'] = np.zeros(hidden_layer_size)
    network['b2'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2 = network['W1'], network['W2']
    b1, b2  = network['b1'], network['b2']
        
    u1 =  np.dot(x, W1) + b1
    z1 = functions.relu(u1)
    u2 =  np.dot(z1, W2) + b2
    y = functions.softmax(u2)
 
    return z1, y

# 誤差逆伝播
def backward(x, d, z1, y):
    grad = {}
    
    W1, W2 = network['W1'], network['W2']
    b1, b2 = network['b1'], network['b2']    
    # 出力層でのデルタ
    delta2 = functions.d_softmax_with_loss(d, y)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * functions.d_relu(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()


accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

    # パラメータに勾配適用
    for key in ('W1', 'W2', 'b1', 'b2'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("Accuracy")
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.47
#                 : 10. 正答率(テスト) = 0.4765
# Generation: 20. 正答率(トレーニング) = 0.7
#                 : 20. 正答率(テスト) = 0.6782
# Generation: 30. 正答率(トレーニング) = 0.74
#                 : 30. 正答率(テスト) = 0.7456
# Generation: 40. 正答率(トレーニング) = 0.75
#                 : 40. 正答率(テスト) = 0.811
# Generation: 50. 正答率(トレーニング) = 0.91
#                 : 50. 正答率(テスト) = 0.8316
# Generation: 60. 正答率(トレーニング) = 0.86
#                 : 60. 正答率(テスト) = 0.841
# Generation: 70. 正答率(トレーニング) = 0.82
#                 : 70. 正答率(テスト) = 0.8548
# Generation: 80. 正答率(トレーニング) = 0.8
#                 : 80. 正答率(テスト) = 0.8615
# Generation: 90. 正答率(トレーニング) = 0.91
#                 : 90. 正答率(テスト) = 0.8605
# Generation: 100. 正答率(トレーニング) = 0.83
#                 : 100. 正答率(テスト) = 0.8769
# Generation: 110. 正答率(トレーニング) = 0.95
#                 : 110. 正答率(テスト) = 0.8827
# Generation: 120. 正答率(トレーニング) = 0.9
#                 : 120. 正答率(テスト) = 0.8835
# Generation: 130. 正答率(トレーニング) = 0.86
#                 : 130. 正答率(テスト) = 0.8873
# Generation: 140. 正答率(トレーニング) = 0.9
#                 : 140. 正答率(テスト) = 0.884
# Generation: 150. 正答率(トレーニング) = 0.91
#                 : 150. 正答率(テスト) = 0.8904
# Generation: 160. 正答率(トレーニング) = 0.88
#                 : 160. 正答率(テスト) = 0.8927
# Generation: 170. 正答率(トレーニング) = 0.85
#                 : 170. 正答率(テスト) = 0.8969
# Generation: 180. 正答率(トレーニング) = 0.87
#                 : 180. 正答率(テスト) = 0.8982
# Generation: 190. 正答率(トレーニング) = 0.9
#                 : 190. 正答率(テスト) = 0.8978
# Generation: 200. 正答率(トレーニング) = 0.93
#                 : 200. 正答率(テスト) = 0.8913
# Generation: 210. 正答率(トレーニング) = 0.89
#                 : 210. 正答率(テスト) = 0.8956
# Generation: 220. 正答率(トレーニング) = 0.92
#                 : 220. 正答率(テスト) = 0.9006
# Generation: 230. 正答率(トレーニング) = 0.93
#                 : 230. 正答率(テスト) = 0.9045
# Generation: 240. 正答率(トレーニング) = 0.9
#                 : 240. 正答率(テスト) = 0.9004
# Generation: 250. 正答率(トレーニング) = 0.9
#                 : 250. 正答率(テスト) = 0.9003
# Generation: 260. 正答率(トレーニング) = 0.92
#                 : 260. 正答率(テスト) = 0.9046
# Generation: 270. 正答率(トレーニング) = 0.9
#                 : 270. 正答率(テスト) = 0.9017
# Generation: 280. 正答率(トレーニング) = 0.94
#                 : 280. 正答率(テスト) = 0.904
# Generation: 290. 正答率(トレーニング) = 0.92
#                 : 290. 正答率(テスト) = 0.9078
# Generation: 300. 正答率(トレーニング) = 0.91
#                 : 300. 正答率(テスト) = 0.907
# Generation: 310. 正答率(トレーニング) = 0.88
#                 : 310. 正答率(テスト) = 0.9076
# Generation: 320. 正答率(トレーニング) = 0.88
#                 : 320. 正答率(テスト) = 0.9054
# Generation: 330. 正答率(トレーニング) = 0.92
#                 : 330. 正答率(テスト) = 0.9083
# Generation: 340. 正答率(トレーニング) = 0.87
#                 : 340. 正答率(テスト) = 0.9123
# Generation: 350. 正答率(トレーニング) = 0.86
#                 : 350. 正答率(テスト) = 0.9107
# Generation: 360. 正答率(トレーニング) = 0.9
#                 : 360. 正答率(テスト) = 0.9112
# Generation: 370. 正答率(トレーニング) = 0.93
#                 : 370. 正答率(テスト) = 0.913
# Generation: 380. 正答率(トレーニング) = 0.93
#                 : 380. 正答率(テスト) = 0.9085
# Generation: 390. 正答率(トレーニング) = 0.89
#                 : 390. 正答率(テスト) = 0.9138
# Generation: 400. 正答率(トレーニング) = 0.93
#                 : 400. 正答率(テスト) = 0.9071
# Generation: 410. 正答率(トレーニング) = 0.92
#                 : 410. 正答率(テスト) = 0.9169
# Generation: 420. 正答率(トレーニング) = 0.91
#                 : 420. 正答率(テスト) = 0.9139
# Generation: 430. 正答率(トレーニング) = 0.95
#                 : 430. 正答率(テスト) = 0.9148
# Generation: 440. 正答率(トレーニング) = 0.94
#                 : 440. 正答率(テスト) = 0.9171
# Generation: 450. 正答率(トレーニング) = 0.94
#                 : 450. 正答率(テスト) = 0.9167
# Generation: 460. 正答率(トレーニング) = 0.95
#                 : 460. 正答率(テスト) = 0.9164
# Generation: 470. 正答率(トレーニング) = 0.91
#                 : 470. 正答率(テスト) = 0.9175
# Generation: 480. 正答率(トレーニング) = 0.88
#                 : 480. 正答率(テスト) = 0.9128
# Generation: 490. 正答率(トレーニング) = 0.87
#                 : 490. 正答率(テスト) = 0.912
# Generation: 500. 正答率(トレーニング) = 0.93
#                 : 500. 正答率(テスト) = 0.9158
# Generation: 510. 正答率(トレーニング) = 0.92
#                 : 510. 正答率(テスト) = 0.9191
# Generation: 520. 正答率(トレーニング) = 0.93
#                 : 520. 正答率(テスト) = 0.9169
# Generation: 530. 正答率(トレーニング) = 0.92
#                 : 530. 正答率(テスト) = 0.9188
# Generation: 540. 正答率(トレーニング) = 0.89
#                 : 540. 正答率(テスト) = 0.9155
# Generation: 550. 正答率(トレーニング) = 0.9
#                 : 550. 正答率(テスト) = 0.9203
# Generation: 560. 正答率(トレーニング) = 0.92
#                 : 560. 正答率(テスト) = 0.9211
# Generation: 570. 正答率(トレーニング) = 0.88
#                 : 570. 正答率(テスト) = 0.9181
# Generation: 580. 正答率(トレーニング) = 0.86
#                 : 580. 正答率(テスト) = 0.9189
# Generation: 590. 正答率(トレーニング) = 0.97
#                 : 590. 正答率(テスト) = 0.9198
# Generation: 600. 正答率(トレーニング) = 0.91
#                 : 600. 正答率(テスト) = 0.9195
# Generation: 610. 正答率(トレーニング) = 0.89
#                 : 610. 正答率(テスト) = 0.9215
# Generation: 620. 正答率(トレーニング) = 0.91
#                 : 620. 正答率(テスト) = 0.9219
# Generation: 630. 正答率(トレーニング) = 0.94
#                 : 630. 正答率(テスト) = 0.9225
# Generation: 640. 正答率(トレーニング) = 0.92
#                 : 640. 正答率(テスト) = 0.9222
# Generation: 650. 正答率(トレーニング) = 0.91
#                 : 650. 正答率(テスト) = 0.9241
# Generation: 660. 正答率(トレーニング) = 0.97
#                 : 660. 正答率(テスト) = 0.9182
# Generation: 670. 正答率(トレーニング) = 0.98
#                 : 670. 正答率(テスト) = 0.9224
# Generation: 680. 正答率(トレーニング) = 0.9
#                 : 680. 正答率(テスト) = 0.9251
# Generation: 690. 正答率(トレーニング) = 0.95
#                 : 690. 正答率(テスト) = 0.9246
# Generation: 700. 正答率(トレーニング) = 0.89
#                 : 700. 正答率(テスト) = 0.9242
# Generation: 710. 正答率(トレーニング) = 0.88
#                 : 710. 正答率(テスト) = 0.9258
# Generation: 720. 正答率(トレーニング) = 0.89
#                 : 720. 正答率(テスト) = 0.9234
# Generation: 730. 正答率(トレーニング) = 0.99
#                 : 730. 正答率(テスト) = 0.9255
# Generation: 740. 正答率(トレーニング) = 0.94
#                 : 740. 正答率(テスト) = 0.9252
# Generation: 750. 正答率(トレーニング) = 0.95
#                 : 750. 正答率(テスト) = 0.9243
# Generation: 760. 正答率(トレーニング) = 0.91
#                 : 760. 正答率(テスト) = 0.9242
# Generation: 770. 正答率(トレーニング) = 0.91
#                 : 770. 正答率(テスト) = 0.9249
# Generation: 780. 正答率(トレーニング) = 0.94
#                 : 780. 正答率(テスト) = 0.9283
# Generation: 790. 正答率(トレーニング) = 0.89
#                 : 790. 正答率(テスト) = 0.9266
# Generation: 800. 正答率(トレーニング) = 0.86
#                 : 800. 正答率(テスト) = 0.9249
# Generation: 810. 正答率(トレーニング) = 0.95
#                 : 810. 正答率(テスト) = 0.9244
# Generation: 820. 正答率(トレーニング) = 0.95
#                 : 820. 正答率(テスト) = 0.9258
# Generation: 830. 正答率(トレーニング) = 0.9
#                 : 830. 正答率(テスト) = 0.9274
# Generation: 840. 正答率(トレーニング) = 0.93
#                 : 840. 正答率(テスト) = 0.9268
# Generation: 850. 正答率(トレーニング) = 0.92
#                 : 850. 正答率(テスト) = 0.926
# Generation: 860. 正答率(トレーニング) = 0.91
#                 : 860. 正答率(テスト) = 0.9294
# Generation: 870. 正答率(トレーニング) = 0.95
#                 : 870. 正答率(テスト) = 0.9309
# Generation: 880. 正答率(トレーニング) = 0.92
#                 : 880. 正答率(テスト) = 0.9291
# Generation: 890. 正答率(トレーニング) = 0.94
#                 : 890. 正答率(テスト) = 0.9285
# Generation: 900. 正答率(トレーニング) = 0.95
#                 : 900. 正答率(テスト) = 0.9312
# Generation: 910. 正答率(トレーニング) = 0.97
#                 : 910. 正答率(テスト) = 0.9297
# Generation: 920. 正答率(トレーニング) = 0.92
#                 : 920. 正答率(テスト) = 0.9305
# Generation: 930. 正答率(トレーニング) = 0.94
#                 : 930. 正答率(テスト) = 0.928
# Generation: 940. 正答率(トレーニング) = 0.89
#                 : 940. 正答率(テスト) = 0.9287
# Generation: 950. 正答率(トレーニング) = 0.92
#                 : 950. 正答率(テスト) = 0.9304
# Generation: 960. 正答率(トレーニング) = 0.96
#                 : 960. 正答率(テスト) = 0.9293
# Generation: 970. 正答率(トレーニング) = 0.92
#                 : 970. 正答率(テスト) = 0.9273
# Generation: 980. 正答率(トレーニング) = 0.93
#                 : 980. 正答率(テスト) = 0.9325
# Generation: 990. 正答率(トレーニング) = 0.9
#                 : 990. 正答率(テスト) = 0.9289
# Generation: 1000. 正答率(トレーニング) = 0.94
#                 : 1000. 正答率(テスト) = 0.931

# %% [markdown]
# 初期化手法のみをHeに変更
# 正解率がやや向上

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from data.mnist import load_mnist
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.1 # 変更してみよう
#入力層サイズ
input_layer_size = 784 # 変更してみよう ->　これを変えると動かない...
#中間層サイズ
hidden_layer_size = 20 # 変更してみよう
#出力層サイズ
output_layer_size = 10 # 変更してみよう
# 繰り返し数
iters_num = 2000 # 変更してみよう
# ミニバッチサイズ
batch_size = 10 # 変更してみよ
# 学習率
learning_rate = 0.01 # 変更してみよう
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    # network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_size)
    # network['W2'] = wieght_init * np.random.randn(hidden_layer_size, output_layer_size)
    # 試してみよう_Xavierの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_size) / np.sqrt(input_layer_size)
    network['W2'] = np.random.randn(hidden_layer_size, output_layer_size) / np.sqrt(hidden_layer_size)
    # 試してみよう Heの初期値
    # network['W1'] = np.random.randn(input_layer_size, hidden_layer_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    # network['W2'] = np.random.randn(hidden_layer_size, output_layer_size) / np.sqrt(hidden_layer_size) * np.sqrt(2)

    network['b1'] = np.zeros(hidden_layer_size)
    network['b2'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2 = network['W1'], network['W2']
    b1, b2  = network['b1'], network['b2']
        
    u1 =  np.dot(x, W1) + b1
    z1 = functions.relu(u1)
    u2 =  np.dot(z1, W2) + b2
    y = functions.softmax(u2)
 
    return z1, y

# 誤差逆伝播
def backward(x, d, z1, y):
    grad = {}
    
    W1, W2 = network['W1'], network['W2']
    b1, b2 = network['b1'], network['b2']    
    # 出力層でのデルタ
    delta2 = functions.d_softmax_with_loss(d, y)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * functions.d_relu(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()


accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

    # パラメータに勾配適用
    for key in ('W1', 'W2', 'b1', 'b2'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("Accuracy")
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.1
#                 : 10. 正答率(テスト) = 0.2045
# Generation: 20. 正答率(トレーニング) = 0.5
#                 : 20. 正答率(テスト) = 0.2706
# Generation: 30. 正答率(トレーニング) = 0.3
#                 : 30. 正答率(テスト) = 0.325
# Generation: 40. 正答率(トレーニング) = 0.2
#                 : 40. 正答率(テスト) = 0.3552
# Generation: 50. 正答率(トレーニング) = 0.3
#                 : 50. 正答率(テスト) = 0.3558
# Generation: 60. 正答率(トレーニング) = 0.5
#                 : 60. 正答率(テスト) = 0.3904
# Generation: 70. 正答率(トレーニング) = 0.5
#                 : 70. 正答率(テスト) = 0.4261
# Generation: 80. 正答率(トレーニング) = 0.4
#                 : 80. 正答率(テスト) = 0.4545
# Generation: 90. 正答率(トレーニング) = 0.4
#                 : 90. 正答率(テスト) = 0.4934
# Generation: 100. 正答率(トレーニング) = 0.4
#                 : 100. 正答率(テスト) = 0.5114
# Generation: 110. 正答率(トレーニング) = 0.7
#                 : 110. 正答率(テスト) = 0.5146
# Generation: 120. 正答率(トレーニング) = 0.4
#                 : 120. 正答率(テスト) = 0.5386
# Generation: 130. 正答率(トレーニング) = 0.5
#                 : 130. 正答率(テスト) = 0.553
# Generation: 140. 正答率(トレーニング) = 0.6
#                 : 140. 正答率(テスト) = 0.5728
# Generation: 150. 正答率(トレーニング) = 0.8
#                 : 150. 正答率(テスト) = 0.5867
# Generation: 160. 正答率(トレーニング) = 0.5
#                 : 160. 正答率(テスト) = 0.5933
# Generation: 170. 正答率(トレーニング) = 0.5
#                 : 170. 正答率(テスト) = 0.6192
# Generation: 180. 正答率(トレーニング) = 0.8
#                 : 180. 正答率(テスト) = 0.6199
# Generation: 190. 正答率(トレーニング) = 0.5
#                 : 190. 正答率(テスト) = 0.6162
# Generation: 200. 正答率(トレーニング) = 0.7
#                 : 200. 正答率(テスト) = 0.6108
# Generation: 210. 正答率(トレーニング) = 0.6
#                 : 210. 正答率(テスト) = 0.6301
# Generation: 220. 正答率(トレーニング) = 0.7
#                 : 220. 正答率(テスト) = 0.636
# Generation: 230. 正答率(トレーニング) = 0.7
#                 : 230. 正答率(テスト) = 0.6636
# Generation: 240. 正答率(トレーニング) = 0.7
#                 : 240. 正答率(テスト) = 0.6771
# Generation: 250. 正答率(トレーニング) = 0.7
#                 : 250. 正答率(テスト) = 0.6804
# Generation: 260. 正答率(トレーニング) = 0.7
#                 : 260. 正答率(テスト) = 0.6898
# Generation: 270. 正答率(トレーニング) = 0.5
#                 : 270. 正答率(テスト) = 0.7023
# Generation: 280. 正答率(トレーニング) = 0.7
#                 : 280. 正答率(テスト) = 0.7365
# Generation: 290. 正答率(トレーニング) = 0.7
#                 : 290. 正答率(テスト) = 0.7338
# Generation: 300. 正答率(トレーニング) = 0.9
#                 : 300. 正答率(テスト) = 0.7387
# Generation: 310. 正答率(トレーニング) = 0.9
#                 : 310. 正答率(テスト) = 0.745
# Generation: 320. 正答率(トレーニング) = 0.7
#                 : 320. 正答率(テスト) = 0.7524
# Generation: 330. 正答率(トレーニング) = 0.5
#                 : 330. 正答率(テスト) = 0.7468
# Generation: 340. 正答率(トレーニング) = 0.6
#                 : 340. 正答率(テスト) = 0.7514
# Generation: 350. 正答率(トレーニング) = 0.4
#                 : 350. 正答率(テスト) = 0.7144
# Generation: 360. 正答率(トレーニング) = 0.8
#                 : 360. 正答率(テスト) = 0.7349
# Generation: 370. 正答率(トレーニング) = 0.6
#                 : 370. 正答率(テスト) = 0.7319
# Generation: 380. 正答率(トレーニング) = 0.5
#                 : 380. 正答率(テスト) = 0.7521
# Generation: 390. 正答率(トレーニング) = 1.0
#                 : 390. 正答率(テスト) = 0.7683
# Generation: 400. 正答率(トレーニング) = 0.6
#                 : 400. 正答率(テスト) = 0.7761
# Generation: 410. 正答率(トレーニング) = 0.5
#                 : 410. 正答率(テスト) = 0.7591
# Generation: 420. 正答率(トレーニング) = 0.7
#                 : 420. 正答率(テスト) = 0.7835
# Generation: 430. 正答率(トレーニング) = 0.8
#                 : 430. 正答率(テスト) = 0.7988
# Generation: 440. 正答率(トレーニング) = 0.9
#                 : 440. 正答率(テスト) = 0.8066
# Generation: 450. 正答率(トレーニング) = 0.9
#                 : 450. 正答率(テスト) = 0.7826
# Generation: 460. 正答率(トレーニング) = 0.9
#                 : 460. 正答率(テスト) = 0.781
# Generation: 470. 正答率(トレーニング) = 0.9
#                 : 470. 正答率(テスト) = 0.7789
# Generation: 480. 正答率(トレーニング) = 0.8
#                 : 480. 正答率(テスト) = 0.7947
# Generation: 490. 正答率(トレーニング) = 0.9
#                 : 490. 正答率(テスト) = 0.8007
# Generation: 500. 正答率(トレーニング) = 0.8
#                 : 500. 正答率(テスト) = 0.8015
# Generation: 510. 正答率(トレーニング) = 0.8
#                 : 510. 正答率(テスト) = 0.8081
# Generation: 520. 正答率(トレーニング) = 0.8
#                 : 520. 正答率(テスト) = 0.8149
# Generation: 530. 正答率(トレーニング) = 0.9
#                 : 530. 正答率(テスト) = 0.8153
# Generation: 540. 正答率(トレーニング) = 0.8
#                 : 540. 正答率(テスト) = 0.8154
# Generation: 550. 正答率(トレーニング) = 0.9
#                 : 550. 正答率(テスト) = 0.825
# Generation: 560. 正答率(トレーニング) = 0.8
#                 : 560. 正答率(テスト) = 0.8274
# Generation: 570. 正答率(トレーニング) = 0.8
#                 : 570. 正答率(テスト) = 0.8317
# Generation: 580. 正答率(トレーニング) = 0.8
#                 : 580. 正答率(テスト) = 0.8369
# Generation: 590. 正答率(トレーニング) = 0.6
#                 : 590. 正答率(テスト) = 0.8134
# Generation: 600. 正答率(トレーニング) = 0.9
#                 : 600. 正答率(テスト) = 0.8349
# Generation: 610. 正答率(トレーニング) = 0.7
#                 : 610. 正答率(テスト) = 0.8262
# Generation: 620. 正答率(トレーニング) = 0.9
#                 : 620. 正答率(テスト) = 0.838
# Generation: 630. 正答率(トレーニング) = 0.8
#                 : 630. 正答率(テスト) = 0.8393
# Generation: 640. 正答率(トレーニング) = 1.0
#                 : 640. 正答率(テスト) = 0.8397
# Generation: 650. 正答率(トレーニング) = 0.7
#                 : 650. 正答率(テスト) = 0.8441
# Generation: 660. 正答率(トレーニング) = 0.6
#                 : 660. 正答率(テスト) = 0.849
# Generation: 670. 正答率(トレーニング) = 0.9
#                 : 670. 正答率(テスト) = 0.8508
# Generation: 680. 正答率(トレーニング) = 0.7
#                 : 680. 正答率(テスト) = 0.8496
# Generation: 690. 正答率(トレーニング) = 0.8
#                 : 690. 正答率(テスト) = 0.8375
# Generation: 700. 正答率(トレーニング) = 0.9
#                 : 700. 正答率(テスト) = 0.8544
# Generation: 710. 正答率(トレーニング) = 0.8
#                 : 710. 正答率(テスト) = 0.8585
# Generation: 720. 正答率(トレーニング) = 0.8
#                 : 720. 正答率(テスト) = 0.8516
# Generation: 730. 正答率(トレーニング) = 0.8
#                 : 730. 正答率(テスト) = 0.8566
# Generation: 740. 正答率(トレーニング) = 0.8
#                 : 740. 正答率(テスト) = 0.8501
# Generation: 750. 正答率(トレーニング) = 0.5
#                 : 750. 正答率(テスト) = 0.8555
# Generation: 760. 正答率(トレーニング) = 0.7
#                 : 760. 正答率(テスト) = 0.856
# Generation: 770. 正答率(トレーニング) = 0.8
#                 : 770. 正答率(テスト) = 0.85
# Generation: 780. 正答率(トレーニング) = 1.0
#                 : 780. 正答率(テスト) = 0.8565
# Generation: 790. 正答率(トレーニング) = 0.8
#                 : 790. 正答率(テスト) = 0.8591
# Generation: 800. 正答率(トレーニング) = 0.8
#                 : 800. 正答率(テスト) = 0.8594
# Generation: 810. 正答率(トレーニング) = 0.8
#                 : 810. 正答率(テスト) = 0.86
# Generation: 820. 正答率(トレーニング) = 1.0
#                 : 820. 正答率(テスト) = 0.8555
# Generation: 830. 正答率(トレーニング) = 0.9
#                 : 830. 正答率(テスト) = 0.8555
# Generation: 840. 正答率(トレーニング) = 0.9
#                 : 840. 正答率(テスト) = 0.8543
# Generation: 850. 正答率(トレーニング) = 0.7
#                 : 850. 正答率(テスト) = 0.8523
# Generation: 860. 正答率(トレーニング) = 0.9
#                 : 860. 正答率(テスト) = 0.8514
# Generation: 870. 正答率(トレーニング) = 0.9
#                 : 870. 正答率(テスト) = 0.8629
# Generation: 880. 正答率(トレーニング) = 0.8
#                 : 880. 正答率(テスト) = 0.8525
# Generation: 890. 正答率(トレーニング) = 1.0
#                 : 890. 正答率(テスト) = 0.8634
# Generation: 900. 正答率(トレーニング) = 0.8
#                 : 900. 正答率(テスト) = 0.8523
# Generation: 910. 正答率(トレーニング) = 0.9
#                 : 910. 正答率(テスト) = 0.8615
# Generation: 920. 正答率(トレーニング) = 1.0
#                 : 920. 正答率(テスト) = 0.8631
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.8601
# Generation: 940. 正答率(トレーニング) = 0.8
#                 : 940. 正答率(テスト) = 0.8611
# Generation: 950. 正答率(トレーニング) = 0.8
#                 : 950. 正答率(テスト) = 0.8645
# Generation: 960. 正答率(トレーニング) = 1.0
#                 : 960. 正答率(テスト) = 0.8625
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.8693
# Generation: 980. 正答率(トレーニング) = 0.9
#                 : 980. 正答率(テスト) = 0.8642
# Generation: 990. 正答率(トレーニング) = 0.8
#                 : 990. 正答率(テスト) = 0.8683
# Generation: 1000. 正答率(トレーニング) = 0.7
#                 : 1000. 正答率(テスト) = 0.865
# Generation: 1010. 正答率(トレーニング) = 0.7
#                 : 1010. 正答率(テスト) = 0.8669
# Generation: 1020. 正答率(トレーニング) = 0.7
#                 : 1020. 正答率(テスト) = 0.8666
# Generation: 1030. 正答率(トレーニング) = 0.8
#                 : 1030. 正答率(テスト) = 0.8655
# Generation: 1040. 正答率(トレーニング) = 0.9
#                 : 1040. 正答率(テスト) = 0.8684
# Generation: 1050. 正答率(トレーニング) = 1.0
#                 : 1050. 正答率(テスト) = 0.8667
# Generation: 1060. 正答率(トレーニング) = 0.9
#                 : 1060. 正答率(テスト) = 0.8716
# Generation: 1070. 正答率(トレーニング) = 0.9
#                 : 1070. 正答率(テスト) = 0.8705
# Generation: 1080. 正答率(トレーニング) = 0.8
#                 : 1080. 正答率(テスト) = 0.8711
# Generation: 1090. 正答率(トレーニング) = 1.0
#                 : 1090. 正答率(テスト) = 0.8683
# Generation: 1100. 正答率(トレーニング) = 0.7
#                 : 1100. 正答率(テスト) = 0.869
# Generation: 1110. 正答率(トレーニング) = 0.9
#                 : 1110. 正答率(テスト) = 0.8729
# Generation: 1120. 正答率(トレーニング) = 0.8
#                 : 1120. 正答率(テスト) = 0.8704
# Generation: 1130. 正答率(トレーニング) = 0.8
#                 : 1130. 正答率(テスト) = 0.8612
# Generation: 1140. 正答率(トレーニング) = 0.9
#                 : 1140. 正答率(テスト) = 0.8729
# Generation: 1150. 正答率(トレーニング) = 0.8
#                 : 1150. 正答率(テスト) = 0.8747
# Generation: 1160. 正答率(トレーニング) = 0.8
#                 : 1160. 正答率(テスト) = 0.8741
# Generation: 1170. 正答率(トレーニング) = 0.7
#                 : 1170. 正答率(テスト) = 0.8752
# Generation: 1180. 正答率(トレーニング) = 0.8
#                 : 1180. 正答率(テスト) = 0.8726
# Generation: 1190. 正答率(トレーニング) = 0.9
#                 : 1190. 正答率(テスト) = 0.8736
# Generation: 1200. 正答率(トレーニング) = 0.9
#                 : 1200. 正答率(テスト) = 0.8706
# Generation: 1210. 正答率(トレーニング) = 0.9
#                 : 1210. 正答率(テスト) = 0.8738
# Generation: 1220. 正答率(トレーニング) = 0.6
#                 : 1220. 正答率(テスト) = 0.8723
# Generation: 1230. 正答率(トレーニング) = 0.8
#                 : 1230. 正答率(テスト) = 0.8774
# Generation: 1240. 正答率(トレーニング) = 0.9
#                 : 1240. 正答率(テスト) = 0.8751
# Generation: 1250. 正答率(トレーニング) = 0.8
#                 : 1250. 正答率(テスト) = 0.8803
# Generation: 1260. 正答率(トレーニング) = 0.7
#                 : 1260. 正答率(テスト) = 0.8808
# Generation: 1270. 正答率(トレーニング) = 0.9
#                 : 1270. 正答率(テスト) = 0.8801
# Generation: 1280. 正答率(トレーニング) = 0.8
#                 : 1280. 正答率(テスト) = 0.875
# Generation: 1290. 正答率(トレーニング) = 0.9
#                 : 1290. 正答率(テスト) = 0.8798
# Generation: 1300. 正答率(トレーニング) = 1.0
#                 : 1300. 正答率(テスト) = 0.8804
# Generation: 1310. 正答率(トレーニング) = 0.9
#                 : 1310. 正答率(テスト) = 0.8805
# Generation: 1320. 正答率(トレーニング) = 1.0
#                 : 1320. 正答率(テスト) = 0.8823
# Generation: 1330. 正答率(トレーニング) = 1.0
#                 : 1330. 正答率(テスト) = 0.8804
# Generation: 1340. 正答率(トレーニング) = 1.0
#                 : 1340. 正答率(テスト) = 0.8839
# Generation: 1350. 正答率(トレーニング) = 0.8
#                 : 1350. 正答率(テスト) = 0.8771
# Generation: 1360. 正答率(トレーニング) = 0.9
#                 : 1360. 正答率(テスト) = 0.8769
# Generation: 1370. 正答率(トレーニング) = 0.9
#                 : 1370. 正答率(テスト) = 0.8796
# Generation: 1380. 正答率(トレーニング) = 1.0
#                 : 1380. 正答率(テスト) = 0.8814
# Generation: 1390. 正答率(トレーニング) = 0.6
#                 : 1390. 正答率(テスト) = 0.8799
# Generation: 1400. 正答率(トレーニング) = 1.0
#                 : 1400. 正答率(テスト) = 0.8809
# Generation: 1410. 正答率(トレーニング) = 0.8
#                 : 1410. 正答率(テスト) = 0.8837
# Generation: 1420. 正答率(トレーニング) = 0.9
#                 : 1420. 正答率(テスト) = 0.884
# Generation: 1430. 正答率(トレーニング) = 0.7
#                 : 1430. 正答率(テスト) = 0.8864
# Generation: 1440. 正答率(トレーニング) = 0.9
#                 : 1440. 正答率(テスト) = 0.8821
# Generation: 1450. 正答率(トレーニング) = 0.9
#                 : 1450. 正答率(テスト) = 0.8844
# Generation: 1460. 正答率(トレーニング) = 0.7
#                 : 1460. 正答率(テスト) = 0.886
# Generation: 1470. 正答率(トレーニング) = 1.0
#                 : 1470. 正答率(テスト) = 0.886
# Generation: 1480. 正答率(トレーニング) = 1.0
#                 : 1480. 正答率(テスト) = 0.8852
# Generation: 1490. 正答率(トレーニング) = 0.8
#                 : 1490. 正答率(テスト) = 0.8852
# Generation: 1500. 正答率(トレーニング) = 0.9
#                 : 1500. 正答率(テスト) = 0.886
# Generation: 1510. 正答率(トレーニング) = 0.8
#                 : 1510. 正答率(テスト) = 0.8764
# Generation: 1520. 正答率(トレーニング) = 0.8
#                 : 1520. 正答率(テスト) = 0.8786
# Generation: 1530. 正答率(トレーニング) = 1.0
#                 : 1530. 正答率(テスト) = 0.8828
# Generation: 1540. 正答率(トレーニング) = 0.9
#                 : 1540. 正答率(テスト) = 0.8847
# Generation: 1550. 正答率(トレーニング) = 1.0
#                 : 1550. 正答率(テスト) = 0.8874
# Generation: 1560. 正答率(トレーニング) = 0.8
#                 : 1560. 正答率(テスト) = 0.8868
# Generation: 1570. 正答率(トレーニング) = 0.9
#                 : 1570. 正答率(テスト) = 0.8876
# Generation: 1580. 正答率(トレーニング) = 0.8
#                 : 1580. 正答率(テスト) = 0.8892
# Generation: 1590. 正答率(トレーニング) = 0.9
#                 : 1590. 正答率(テスト) = 0.8878
# Generation: 1600. 正答率(トレーニング) = 0.8
#                 : 1600. 正答率(テスト) = 0.8878
# Generation: 1610. 正答率(トレーニング) = 0.9
#                 : 1610. 正答率(テスト) = 0.8878
# Generation: 1620. 正答率(トレーニング) = 1.0
#                 : 1620. 正答率(テスト) = 0.8831
# Generation: 1630. 正答率(トレーニング) = 1.0
#                 : 1630. 正答率(テスト) = 0.8884
# Generation: 1640. 正答率(トレーニング) = 1.0
#                 : 1640. 正答率(テスト) = 0.8893
# Generation: 1650. 正答率(トレーニング) = 0.9
#                 : 1650. 正答率(テスト) = 0.8875
# Generation: 1660. 正答率(トレーニング) = 0.9
#                 : 1660. 正答率(テスト) = 0.8893
# Generation: 1670. 正答率(トレーニング) = 1.0
#                 : 1670. 正答率(テスト) = 0.8893
# Generation: 1680. 正答率(トレーニング) = 1.0
#                 : 1680. 正答率(テスト) = 0.8868
# Generation: 1690. 正答率(トレーニング) = 0.8
#                 : 1690. 正答率(テスト) = 0.8853
# Generation: 1700. 正答率(トレーニング) = 0.9
#                 : 1700. 正答率(テスト) = 0.8867
# Generation: 1710. 正答率(トレーニング) = 0.7
#                 : 1710. 正答率(テスト) = 0.8894
# Generation: 1720. 正答率(トレーニング) = 0.8
#                 : 1720. 正答率(テスト) = 0.8889
# Generation: 1730. 正答率(トレーニング) = 0.8
#                 : 1730. 正答率(テスト) = 0.8882
# Generation: 1740. 正答率(トレーニング) = 0.9
#                 : 1740. 正答率(テスト) = 0.8895
# Generation: 1750. 正答率(トレーニング) = 0.7
#                 : 1750. 正答率(テスト) = 0.8915
# Generation: 1760. 正答率(トレーニング) = 0.9
#                 : 1760. 正答率(テスト) = 0.8914
# Generation: 1770. 正答率(トレーニング) = 0.9
#                 : 1770. 正答率(テスト) = 0.8887
# Generation: 1780. 正答率(トレーニング) = 0.9
#                 : 1780. 正答率(テスト) = 0.8907
# Generation: 1790. 正答率(トレーニング) = 0.9
#                 : 1790. 正答率(テスト) = 0.89
# Generation: 1800. 正答率(トレーニング) = 0.9
#                 : 1800. 正答率(テスト) = 0.8883
# Generation: 1810. 正答率(トレーニング) = 0.9
#                 : 1810. 正答率(テスト) = 0.8882
# Generation: 1820. 正答率(トレーニング) = 1.0
#                 : 1820. 正答率(テスト) = 0.8886
# Generation: 1830. 正答率(トレーニング) = 0.8
#                 : 1830. 正答率(テスト) = 0.8871
# Generation: 1840. 正答率(トレーニング) = 0.9
#                 : 1840. 正答率(テスト) = 0.8885
# Generation: 1850. 正答率(トレーニング) = 0.8
#                 : 1850. 正答率(テスト) = 0.8904
# Generation: 1860. 正答率(トレーニング) = 0.9
#                 : 1860. 正答率(テスト) = 0.8859
# Generation: 1870. 正答率(トレーニング) = 1.0
#                 : 1870. 正答率(テスト) = 0.8915
# Generation: 1880. 正答率(トレーニング) = 1.0
#                 : 1880. 正答率(テスト) = 0.8908
# Generation: 1890. 正答率(トレーニング) = 0.8
#                 : 1890. 正答率(テスト) = 0.8875
# Generation: 1900. 正答率(トレーニング) = 0.9
#                 : 1900. 正答率(テスト) = 0.8882
# Generation: 1910. 正答率(トレーニング) = 1.0
#                 : 1910. 正答率(テスト) = 0.8875
# Generation: 1920. 正答率(トレーニング) = 0.9
#                 : 1920. 正答率(テスト) = 0.8844
# Generation: 1930. 正答率(トレーニング) = 0.9
#                 : 1930. 正答率(テスト) = 0.889
# Generation: 1940. 正答率(トレーニング) = 0.9
#                 : 1940. 正答率(テスト) = 0.8888
# Generation: 1950. 正答率(トレーニング) = 0.6
#                 : 1950. 正答率(テスト) = 0.8882
# Generation: 1960. 正答率(トレーニング) = 0.9
#                 : 1960. 正答率(テスト) = 0.8892
# Generation: 1970. 正答率(トレーニング) = 1.0
#                 : 1970. 正答率(テスト) = 0.8926
# Generation: 1980. 正答率(トレーニング) = 0.8
#                 : 1980. 正答率(テスト) = 0.8918
# Generation: 1990. 正答率(トレーニング) = 0.8
#                 : 1990. 正答率(テスト) = 0.8933
# Generation: 2000. 正答率(トレーニング) = 0.8
#                 : 2000. 正答率(テスト) = 0.8913

# %% [markdown]
# Xavier初期化、中間層ノード数の削減など
# トレーニングデータに対する正解率がちょいちょい100%になっている&ブレが大きい
# テストデータに対する正解率も低下
